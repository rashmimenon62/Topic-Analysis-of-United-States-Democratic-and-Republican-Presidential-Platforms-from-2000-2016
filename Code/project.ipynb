# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/airadomingo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#import packages
import re
import numpy as np
import pandas as pd
from pprint import pprint

import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

import spacy

import pyLDAvis
import pyLDAvis.gensim
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#load spacy model
nlp = spacy.load("en_core_web_sm")
# spacy Stop words
from spacy.lang.en.stop_words import STOP_WORDS

stopwords = spacy.lang.en.stop_words.STOP_WORDS
nlp.Defaults.stop_words |= {"america", "-pron-", 'american', 'americans', 'democrats', 'support', 'strengthen', 'end', 'republican', 'people', 'donald', 'democratic', 'president', 'republicans', 'year', 'states', 'national', 'believe', 'preamble'}

# %%
#create dataframe
df = pd.DataFrame(columns=['party', 'year', 'manifesto', 'tokens'])

# %%
#print dataframe
print(df)
# Out:
# Empty DataFrame
# Columns: [party, year, manifesto, tokens]
# Index: []

# %%
#OPEN DOCUMENT
def read_file(filename):
    input_file_text = open(filename, encoding = 'utf-8').read()
    return input_file_text

# %%
#PREPROCESSING/CLEANING
def preprocess(document):
    analyzed_doc = nlp(document) #spacy model on document
    
    tokens_list =[]
    
    for token in analyzed_doc:
        # excludes tokens that are punctuations, numbers, and white spaces
            if token.is_stop == False and token.is_punct == False and token.is_digit == False and token.like_num == False and token.is_space == False: 
                token = token.lemma_ #gets token lemma
                tokens_list.append(token.lower()) #adds lowercase of token lemma to tokens_list

    for token in tokens_list:
        #removes '-pron-' from lemmatization and stop words
        if token in stopwords:
            tokens_list.remove(token)
        elif token == '-pron-':
            tokens_list.remove(token)       
    return tokens_list

# %%
#CREATE BAG Of WORDS
def create_bag_words(preprocessed_data):
    bag_dictionary = corpora.Dictionary(preprocessed_data)
    return bag_dictionary

# %%
#CREATE TERM DOCUMENT MATRIX CORPUS
def create_term_doc_mat(dictionary, preprocessed_data):
    matrix_corpus = [dictionary.doc2bow(doc) for doc in preprocessed_data]
    return matrix_corpus

# %%
#BUILD TOPIC MODEL
lda_model = gensim.models.ldamodel.LdaModel

def build_lda_model(new_corpus,dictionary):
    new_lda_model = lda_model(corpus = new_corpus,
                                        id2word = dictionary,
                                        num_topics=80, 
                                        random_state=100,
                                        update_every=100,
                                        chunksize=100,
                                        passes=100,
                                        alpha='auto',
                                        eta='auto',
                                        iterations=100,
                                        eval_every=None,
                                        per_word_topics=False)
    return new_lda_model

# %%
def print_topics(model):
    for idx, topic in model.show_topics(num_topics=10, formatted=False, num_words=10):
        print('Topic: {} \tWords: {}'.format(idx, '|'.join([w[0] for w in topic])))

# %%
# Compute Coherence Score
def comp_coherence(model, corpus, dictionary):
    coherence_model= CoherenceModel(model=model, texts=texts, 
                                               dictionary=dictionary, coherence='c_v')
    coherence = coherence_model.get_coherence()
    print('\nCoherence Score: ', coherence)

# %%
#ADD DOCUMENTS TO DF AND PREPROCESS EACH DOCUMENT
demo_2000 = read_file('/Users/airadomingo/Documents/Documents/NLP/txt_data/Democratic/61320_200011.txt')
clean_demo_2000 = preprocess(demo_2000)
df = df.append({'party':'democratic', 'year': '2000', 'manifesto': demo_2000, 'tokens': clean_demo_2000},ignore_index=True)

repub_2000 = read_file('/Users/airadomingo/Documents/Documents/NLP/txt_data/Republican/61620_200011.txt')
clean_repub_2000 = preprocess(repub_2000)
df = df.append({'party':'republican', 'year': '2000', 'manifesto': repub_2000, 'tokens': clean_repub_2000},ignore_index=True)

demo_2004 = read_file('/Users/airadomingo/Documents/Documents/NLP/txt_data/Democratic/61320_200411.txt')
clean_demo_2004 = preprocess(demo_2004)
df = df.append({'party':'democratic', 'year': '2004', 'manifesto': demo_2004, 'tokens': clean_demo_2004},ignore_index=True)

repub_2004 = read_file('/Users/airadomingo/Documents/Documents/NLP/txt_data/Republican/61620_200411.txt')
clean_repub_2004 = preprocess(repub_2004)
df = df.append({'party':'republican', 'year': '2004', 'manifesto': repub_2004, 'tokens': clean_repub_2004},ignore_index=True)

demo_2008 = read_file('/Users/airadomingo/Documents/Documents/NLP/txt_data/Democratic/61320_200811.txt')
clean_demo_2008 = preprocess(demo_2008)
df = df.append({'party':'democratic', 'year': '2008', 'manifesto': demo_2008, 'tokens': clean_demo_2008},ignore_index=True)

repub_2008 = read_file('/Users/airadomingo/Documents/Documents/NLP/txt_data/Republican/61620_200811.txt')
clean_repub_2008 = preprocess(repub_2008)
df = df.append({'party':'republican', 'year': '2008', 'manifesto': repub_2008, 'tokens': clean_repub_2008},ignore_index=True)

demo_2012 = read_file('/Users/airadomingo/Documents/Documents/NLP/txt_data/Democratic/61320_201211.txt')
clean_demo_2012 = preprocess(demo_2012)
df = df.append({'party':'democratic', 'year': '2012', 'manifesto': demo_2012, 'tokens': clean_demo_2012},ignore_index=True)
               
repub_2012 = read_file('/Users/airadomingo/Documents/Documents/NLP/txt_data/Republican/61620_201211.txt')
clean_repub_2012 = preprocess(repub_2012)
df = df.append({'party':'republican', 'year': '2012', 'manifesto': repub_2012, 'tokens': clean_repub_2012},ignore_index=True)

demo_2016 = read_file('/Users/airadomingo/Documents/Documents/NLP/txt_data/Democratic/61320_201611.txt')
clean_demo_2016 = preprocess(demo_2016)
df = df.append({'party':'democratic', 'year': '2016', 'manifesto': demo_2016, 'tokens': clean_demo_2016},ignore_index=True)
               
repub_2016 = read_file('/Users/airadomingo/Documents/Documents/NLP/txt_data/Republican/61620_201611.txt')
clean_repub_2016 = preprocess(repub_2016)
df = df.append({'party':'republican', 'year': '2016', 'manifesto': repub_2016, 'tokens': clean_repub_2016},ignore_index=True)

# %%
#CREATE PANDAS SERIES OF PREPROCESSED TOKENS FOR EACH DOCUMENT
texts = df['tokens']

# %%
#PRINT PREVIEW OF TEXTS
texts
# Out:
# 0    [platform, prosperity, progress, peace, adopt,...
# 1    [platform, renewing, purpose, meet, remarkable...
# 2    [come, declare, vision, mindful, challenge, ti...
# 3    [introduction, preambleone, ago, gather, prote...
# 4    [come, defining, moment, history, nation, nati...
# 5    [defend, nation, heroes, secure, peacethree, d...
# 6    [forward, platformmoving, forwardfour, ago, in...
# 7    [americathis, platform, dedicate, appreciation...
# 8    [preamblein, meet, philadelphia, basic, belief...
# 9    [preamblewith, platform, party, reaffirm, prin...
# Name: tokens, dtype: object

# %%
#call create_bag_words on preprocessed data

platforms_dict = create_bag_words(texts)

#call create_term_doc_mat using created bag of words and preprocessed data

platforms_mat_corpus = create_term_doc_mat(platforms_dict, texts)

# %%
#lda model using all documents
model_all = build_lda_model(platforms_mat_corpus, platforms_dict)

pprint(model_all.print_topics())

# Compute Coherence Score
all_coherence= comp_coherence(model_all, platforms_mat_corpus, platforms_dict)
# Out:
# [(56,
#   '0.000*"government" + 0.000*"care" + 0.000*"family" + 0.000*"law" + '
#   '0.000*"health" + 0.000*"new" + 0.000*"work" + 0.000*"security" + '
#   '0.000*"administration" + 0.000*"federal"'),
#  (42,
#   '0.000*"government" + 0.000*"health" + 0.000*"law" + 0.000*"right" + '
#   '0.000*"program" + 0.000*"work" + 0.000*"federal" + 0.000*"administration" + '
#   '0.000*"economic" + 0.000*"country"'),
#  (71,
#   '0.000*"government" + 0.000*"world" + 0.000*"nation" + 0.000*"new" + '
#   '0.000*"right" + 0.000*"federal" + 0.000*"need" + 0.000*"work" + '
#   '0.000*"administration" + 0.000*"education"'),
#  (75,
#   '0.000*"family" + 0.000*"right" + 0.000*"need" + 0.000*"new" + 0.000*"law" + '
#   '0.000*"government" + 0.000*"health" + 0.000*"country" + 0.000*"child" + '
#   '0.000*"world"'),
#  (40,
#   '0.000*"government" + 0.000*"family" + 0.000*"new" + 0.000*"federal" + '
#   '0.000*"health" + 0.000*"work" + 0.000*"program" + 0.000*"need" + '
#   '0.000*"right" + 0.000*"public"'),
#  (49,
#   '0.000*"health" + 0.000*"government" + 0.000*"work" + 0.000*"world" + '
#   '0.000*"law" + 0.000*"help" + 0.000*"right" + 0.000*"new" + 0.000*"need" + '
#   '0.000*"family"'),
#  (17,
#   '0.000*"government" + 0.000*"health" + 0.000*"work" + 0.000*"care" + '
#   '0.000*"new" + 0.000*"law" + 0.000*"tax" + 0.000*"security" + 0.000*"family" '
#   '+ 0.000*"federal"'),
#  (58,
#   '0.000*"health" + 0.000*"work" + 0.000*"country" + 0.000*"care" + '
#   '0.000*"need" + 0.000*"government" + 0.000*"ensure" + 0.000*"united" + '
#   '0.000*"federal" + 0.000*"nation"'),
#  (63,
#   '0.000*"need" + 0.000*"health" + 0.000*"government" + 0.000*"child" + '
#   '0.000*"family" + 0.000*"federal" + 0.000*"administration" + 0.000*"new" + '
#   '0.000*"security" + 0.000*"work"'),
#  (34,
#   '0.000*"health" + 0.000*"work" + 0.000*"need" + 0.000*"family" + '
#   '0.000*"country" + 0.000*"new" + 0.000*"government" + 0.000*"world" + '
#   '0.000*"program" + 0.000*"community"'),
#  (7,
#   '0.000*"new" + 0.000*"government" + 0.000*"work" + 0.000*"country" + '
#   '0.000*"family" + 0.000*"nation" + 0.000*"federal" + 0.000*"security" + '
#   '0.000*"child" + 0.000*"need"'),
#  (54,
#   '0.000*"new" + 0.000*"government" + 0.000*"work" + 0.000*"health" + '
#   '0.000*"need" + 0.000*"federal" + 0.000*"ensure" + 0.000*"program" + '
#   '0.000*"family" + 0.000*"right"'),
#  (57,
#   '0.000*"right" + 0.000*"work" + 0.000*"government" + 0.000*"federal" + '
#   '0.000*"family" + 0.000*"health" + 0.000*"community" + 0.000*"nation" + '
#   '0.000*"law" + 0.000*"new"'),
#  (52,
#   '0.000*"right" + 0.000*"health" + 0.000*"work" + 0.000*"nation" + '
#   '0.000*"security" + 0.000*"family" + 0.000*"community" + 0.000*"help" + '
#   '0.000*"government" + 0.000*"law"'),
#  (60,
#   '0.000*"new" + 0.000*"government" + 0.000*"need" + 0.000*"health" + '
#   '0.000*"work" + 0.000*"right" + 0.000*"nation" + 0.000*"family" + '
#   '0.000*"world" + 0.000*"administration"'),
#  (21,
#   '0.000*"health" + 0.000*"new" + 0.000*"government" + 0.000*"work" + '
#   '0.000*"care" + 0.000*"nation" + 0.000*"need" + 0.000*"help" + '
#   '0.000*"congress" + 0.000*"bush"'),
#  (62,
#   '0.110*"bush" + 0.048*"applaud" + 0.044*"congress" + 0.025*"provide" + '
#   '0.021*"terrorist" + 0.020*"terror" + 0.019*"effort" + 0.018*"pass" + '
#   '0.015*"hiv" + 0.014*"endorse"'),
#  (37,
#   '0.011*"government" + 0.009*"federal" + 0.007*"right" + 0.006*"law" + '
#   '0.005*"program" + 0.005*"current" + 0.005*"country" + 0.004*"public" + '
#   '0.004*"state" + 0.004*"nation"'),
#  (3,
#   '0.009*"new" + 0.009*"health" + 0.007*"work" + 0.006*"care" + '
#   '0.006*"government" + 0.006*"nation" + 0.006*"united" + 0.006*"world" + '
#   '0.005*"administration" + 0.005*"child"'),
#  (66,
#   '0.011*"work" + 0.007*"health" + 0.007*"right" + 0.007*"community" + '
#   '0.007*"new" + 0.007*"job" + 0.006*"need" + 0.006*"family" + '
#   '0.006*"continue" + 0.006*"worker"')]
#
# Coherence Score:  0.24436185505055744

# %%
## DEMOCRATIC 2000
corpus_demo_2000 = platforms_mat_corpus[0] #term document matrix of only democratic 2000

model_demo_2000 = build_lda_model([corpus_demo_2000], platforms_dict)

pprint(model_demo_2000.print_topics())

# Compute Coherence Score
demo_2000_coherence = comp_coherence(model_demo_2000, [corpus_demo_2000], platforms_dict)
# Out:
# [(4,
#   '0.000*"unchecked" + 0.000*"undemocratic" + 0.000*"tribes" + '
#   '0.000*"tropical" + 0.000*"trustworthy" + 0.000*"turbine" + 0.000*"turning" '
#   '+ 0.000*"unavailable" + 0.000*"traumatic" + 0.000*"unconditional"'),
#  (33,
#   '0.000*"work" + 0.000*"security" + 0.000*"help" + 0.000*"child" + '
#   '0.000*"gore" + 0.000*"prosperity" + 0.000*"family" + 0.000*"time" + '
#   '0.000*"new" + 0.000*"public"'),
#  (41,
#   '0.000*"new" + 0.000*"child" + 0.000*"school" + 0.000*"world" + '
#   '0.000*"worker" + 0.000*"high" + 0.000*"effort" + 0.000*"education" + '
#   '0.000*"economy" + 0.000*"economic"'),
#  (28,
#   '0.000*"work" + 0.000*"child" + 0.000*"new" + 0.000*"need" + 0.000*"right" + '
#   '0.000*"school" + 0.000*"gore" + 0.000*"continue" + 0.000*"worker" + '
#   '0.000*"expand"'),
#  (58,
#   '0.000*"gore" + 0.000*"work" + 0.000*"new" + 0.000*"school" + 0.000*"worker" '
#   '+ 0.000*"need" + 0.000*"child" + 0.000*"include" + 0.000*"home" + '
#   '0.000*"nation"'),
#  (43,
#   '0.000*"new" + 0.000*"need" + 0.000*"worker" + 0.000*"work" + 0.000*"al" + '
#   '0.000*"school" + 0.000*"include" + 0.000*"nation" + 0.000*"peace" + '
#   '0.000*"progress"'),
#  (19,
#   '0.000*"gore" + 0.000*"need" + 0.000*"new" + 0.000*"school" + 0.000*"al" + '
#   '0.000*"work" + 0.000*"party" + 0.000*"expand" + 0.000*"world" + '
#   '0.000*"worker"'),
#  (34,
#   '0.000*"new" + 0.000*"gore" + 0.000*"need" + 0.000*"work" + 0.000*"include" '
#   '+ 0.000*"world" + 0.000*"economy" + 0.000*"government" + 0.000*"provide" + '
#   '0.000*"ensure"'),
#  (61,
#   '0.000*"work" + 0.000*"school" + 0.000*"al" + 0.000*"prosperity" + '
#   '0.000*"public" + 0.000*"need" + 0.000*"help" + 0.000*"community" + '
#   '0.000*"ensure" + 0.000*"health"'),
#  (56,
#   '0.000*"gore" + 0.000*"help" + 0.000*"family" + 0.000*"worker" + '
#   '0.000*"work" + 0.000*"community" + 0.000*"need" + 0.000*"party" + '
#   '0.000*"time" + 0.000*"al"'),
#  (30,
#   '0.000*"gore" + 0.000*"work" + 0.000*"new" + 0.000*"school" + 0.000*"child" '
#   '+ 0.000*"security" + 0.000*"party" + 0.000*"right" + 0.000*"al" + '
#   '0.000*"continue"'),
#  (52,
#   '0.000*"new" + 0.000*"school" + 0.000*"al" + 0.000*"work" + 0.000*"child" + '
#   '0.000*"gore" + 0.000*"help" + 0.000*"need" + 0.000*"right" + '
#   '0.000*"continue"'),
#  (37,
#   '0.000*"new" + 0.000*"child" + 0.000*"school" + 0.000*"work" + '
#   '0.000*"worker" + 0.000*"gore" + 0.000*"right" + 0.000*"need" + '
#   '0.000*"continue" + 0.000*"al"'),
#  (10,
#   '0.000*"need" + 0.000*"new" + 0.000*"work" + 0.000*"gore" + 0.000*"child" + '
#   '0.000*"school" + 0.000*"worker" + 0.000*"party" + 0.000*"family" + '
#   '0.000*"security"'),
#  (62,
#   '0.000*"new" + 0.000*"work" + 0.000*"worker" + 0.000*"gore" + 0.000*"need" + '
#   '0.000*"al" + 0.000*"school" + 0.000*"continue" + 0.000*"child" + '
#   '0.000*"help"'),
#  (7,
#   '0.000*"new" + 0.000*"child" + 0.000*"work" + 0.000*"need" + 0.000*"school" '
#   '+ 0.000*"gore" + 0.000*"continue" + 0.000*"party" + 0.000*"al" + '
#   '0.000*"family"'),
#  (68,
#   '0.000*"work" + 0.000*"new" + 0.000*"need" + 0.000*"child" + 0.000*"gore" + '
#   '0.000*"al" + 0.000*"worker" + 0.000*"school" + 0.000*"family" + '
#   '0.000*"right"'),
#  (16,
#   '0.000*"new" + 0.000*"school" + 0.000*"work" + 0.000*"child" + 0.000*"need" '
#   '+ 0.000*"gore" + 0.000*"worker" + 0.000*"help" + 0.000*"government" + '
#   '0.000*"al"'),
#  (74,
#   '0.000*"work" + 0.000*"need" + 0.000*"new" + 0.000*"gore" + 0.000*"child" + '
#   '0.000*"al" + 0.000*"school" + 0.000*"worker" + 0.000*"help" + '
#   '0.000*"nation"'),
#  (66,
#   '0.013*"new" + 0.011*"work" + 0.009*"need" + 0.009*"gore" + 0.009*"school" + '
#   '0.009*"child" + 0.008*"al" + 0.007*"worker" + 0.007*"continue" + '
#   '0.007*"help"')]
#
# Coherence Score:  0.32449232619400414

# %%
## REPUBLICAN 2000
corpus_repub_2000 = platforms_mat_corpus[1]

model_repub_2000 = build_lda_model([corpus_repub_2000], platforms_dict)

pprint(model_repub_2000.print_topics())

repub_2000_coherence = comp_coherence(model_repub_2000,[corpus_repub_2000], platforms_dict)
# Out:
# [(28,
#   '0.000*"health" + 0.000*"government" + 0.000*"administration" + '
#   '0.000*"market" + 0.000*"high" + 0.000*"time" + 0.000*"country" + '
#   '0.000*"right" + 0.000*"rule" + 0.000*"encourage"'),
#  (33,
#   '0.000*"federal" + 0.000*"government" + 0.000*"current" + 0.000*"party" + '
#   '0.000*"change" + 0.000*"nation" + 0.000*"private" + 0.000*"work" + '
#   '0.000*"community" + 0.000*"economic"'),
#  (58,
#   '0.000*"health" + 0.000*"need" + 0.000*"united" + 0.000*"government" + '
#   '0.000*"care" + 0.000*"federal" + 0.000*"child" + 0.000*"reform" + '
#   '0.000*"u.s." + 0.000*"system"'),
#  (34,
#   '0.000*"government" + 0.000*"health" + 0.000*"new" + 0.000*"encourage" + '
#   '0.000*"time" + 0.000*"threat" + 0.000*"market" + 0.000*"country" + '
#   '0.000*"local" + 0.000*"right"'),
#  (41,
#   '0.000*"government" + 0.000*"administration" + 0.000*"care" + '
#   '0.000*"program" + 0.000*"federal" + 0.000*"united" + 0.000*"new" + '
#   '0.000*"family" + 0.000*"encourage" + 0.000*"trade"'),
#  (19,
#   '0.000*"federal" + 0.000*"administration" + 0.000*"government" + '
#   '0.000*"need" + 0.000*"system" + 0.000*"program" + 0.000*"health" + '
#   '0.000*"family" + 0.000*"tax" + 0.000*"nation"'),
#  (13,
#   '0.000*"federal" + 0.000*"new" + 0.000*"government" + 0.000*"work" + '
#   '0.000*"health" + 0.000*"administration" + 0.000*"tax" + 0.000*"world" + '
#   '0.000*"system" + 0.000*"need"'),
#  (4,
#   '0.000*"government" + 0.000*"health" + 0.000*"federal" + 0.000*"care" + '
#   '0.000*"family" + 0.000*"new" + 0.000*"united" + 0.000*"world" + '
#   '0.000*"encourage" + 0.000*"individual"'),
#  (24,
#   '0.000*"new" + 0.000*"government" + 0.000*"administration" + 0.000*"care" + '
#   '0.000*"health" + 0.000*"nation" + 0.000*"program" + 0.000*"need" + '
#   '0.000*"federal" + 0.000*"policy"'),
#  (56,
#   '0.000*"government" + 0.000*"administration" + 0.000*"new" + 0.000*"system" '
#   '+ 0.000*"economic" + 0.000*"program" + 0.000*"time" + 0.000*"security" + '
#   '0.000*"child" + 0.000*"tax"'),
#  (77,
#   '0.000*"government" + 0.000*"new" + 0.000*"care" + 0.000*"need" + '
#   '0.000*"administration" + 0.000*"united" + 0.000*"federal" + 0.000*"health" '
#   '+ 0.000*"family" + 0.000*"work"'),
#  (30,
#   '0.000*"health" + 0.000*"government" + 0.000*"administration" + 0.000*"new" '
#   '+ 0.000*"federal" + 0.000*"care" + 0.000*"security" + 0.000*"program" + '
#   '0.000*"work" + 0.000*"family"'),
#  (62,
#   '0.000*"health" + 0.000*"government" + 0.000*"administration" + 0.000*"new" '
#   '+ 0.000*"federal" + 0.000*"united" + 0.000*"nation" + 0.000*"care" + '
#   '0.000*"work" + 0.000*"program"'),
#  (74,
#   '0.000*"government" + 0.000*"new" + 0.000*"need" + 0.000*"care" + '
#   '0.000*"health" + 0.000*"federal" + 0.000*"administration" + 0.000*"united" '
#   '+ 0.000*"work" + 0.000*"nation"'),
#  (26,
#   '0.000*"new" + 0.000*"administration" + 0.000*"government" + 0.000*"health" '
#   '+ 0.000*"federal" + 0.000*"united" + 0.000*"care" + 0.000*"need" + '
#   '0.000*"system" + 0.000*"nation"'),
#  (7,
#   '0.000*"new" + 0.000*"government" + 0.000*"united" + 0.000*"federal" + '
#   '0.000*"health" + 0.000*"administration" + 0.000*"family" + 0.000*"system" + '
#   '0.000*"care" + 0.000*"country"'),
#  (37,
#   '0.000*"government" + 0.000*"administration" + 0.000*"federal" + 0.000*"new" '
#   '+ 0.000*"care" + 0.000*"world" + 0.000*"tax" + 0.000*"reform" + '
#   '0.000*"child" + 0.000*"health"'),
#  (16,
#   '0.000*"government" + 0.000*"new" + 0.000*"care" + 0.000*"administration" + '
#   '0.000*"united" + 0.000*"program" + 0.000*"health" + 0.000*"work" + '
#   '0.000*"federal" + 0.000*"child"'),
#  (3,
#   '0.014*"dangerous" + 0.009*"chemical" + 0.009*"facility" + 0.009*"voluntary" '
#   '+ 0.009*"rely" + 0.009*"major" + 0.008*"ladder" + 0.008*"operate" + '
#   '0.008*"look" + 0.008*"arm"'),
#  (68,
#   '0.010*"government" + 0.009*"new" + 0.008*"health" + 0.008*"administration" '
#   '+ 0.007*"federal" + 0.006*"united" + 0.006*"need" + 0.006*"care" + '
#   '0.005*"family" + 0.005*"program"')]
#
# Coherence Score:  0.2230145903000293

# %%
##DEMOCRATIC 2004
corpus_demo_2004 = platforms_mat_corpus[2]

model_demo_2004 = build_lda_model([corpus_demo_2004], platforms_dict)

pprint(model_demo_2004.print_topics())

# Compute Coherence Score
demo_2004_coherence = comp_coherence(model_demo_2004, [corpus_demo_2004], platforms_dict)
# Out:
# [(71,
#   '0.000*"unchecked" + 0.000*"undemocratic" + 0.000*"tribes" + '
#   '0.000*"tropical" + 0.000*"trustworthy" + 0.000*"turbine" + 0.000*"turning" '
#   '+ 0.000*"unavailable" + 0.000*"traumatic" + 0.000*"unconditional"'),
#  (79,
#   '0.000*"unchecked" + 0.000*"undemocratic" + 0.000*"tribes" + '
#   '0.000*"tropical" + 0.000*"trustworthy" + 0.000*"turbine" + 0.000*"turning" '
#   '+ 0.000*"unavailable" + 0.000*"traumatic" + 0.000*"unconditional"'),
#  (70,
#   '0.000*"unchecked" + 0.000*"undemocratic" + 0.000*"tribes" + '
#   '0.000*"tropical" + 0.000*"trustworthy" + 0.000*"turbine" + 0.000*"turning" '
#   '+ 0.000*"unavailable" + 0.000*"traumatic" + 0.000*"unconditional"'),
#  (58,
#   '0.000*"unchecked" + 0.000*"undemocratic" + 0.000*"tribes" + '
#   '0.000*"tropical" + 0.000*"trustworthy" + 0.000*"turbine" + 0.000*"turning" '
#   '+ 0.000*"unavailable" + 0.000*"traumatic" + 0.000*"unconditional"'),
#  (33,
#   '0.000*"work" + 0.000*"undemocratic" + 0.000*"underemployment" + '
#   '0.000*"trustworthy" + 0.000*"turbine" + 0.000*"turning" + '
#   '0.000*"unavailable" + 0.000*"unchecked" + 0.000*"unconditional" + '
#   '0.000*"tribes"'),
#  (34,
#   '0.000*"work" + 0.000*"family" + 0.000*"health" + 0.000*"unchecked" + '
#   '0.000*"undemocratic" + 0.000*"trustworthy" + 0.000*"turbine" + '
#   '0.000*"turning" + 0.000*"unavailable" + 0.000*"tribes"'),
#  (41,
#   '0.000*"world" + 0.000*"security" + 0.000*"child" + 0.000*"family" + '
#   '0.000*"care" + 0.000*"administration" + 0.000*"work" + 0.000*"job" + '
#   '0.000*"new" + 0.000*"health"'),
#  (19,
#   '0.000*"job" + 0.000*"john" + 0.000*"health" + 0.000*"nation" + 0.000*"work" '
#   '+ 0.000*"family" + 0.000*"good" + 0.000*"administration" + 0.000*"school" + '
#   '0.000*"high"'),
#  (28,
#   '0.000*"health" + 0.000*"john" + 0.000*"good" + 0.000*"time" + '
#   '0.000*"family" + 0.000*"build" + 0.000*"world" + 0.000*"weapon" + '
#   '0.000*"opportunity" + 0.000*"need"'),
#  (61,
#   '0.000*"terrorist" + 0.000*"ensure" + 0.000*"security" + 0.000*"health" + '
#   '0.000*"strong" + 0.000*"school" + 0.000*"help" + 0.000*"world" + '
#   '0.000*"family" + 0.000*"right"'),
#  (26,
#   '0.000*"new" + 0.000*"health" + 0.000*"work" + 0.000*"strong" + '
#   '0.000*"administration" + 0.000*"world" + 0.000*"need" + 0.000*"family" + '
#   '0.000*"care" + 0.000*"good"'),
#  (37,
#   '0.000*"world" + 0.000*"work" + 0.000*"new" + 0.000*"create" + '
#   '0.000*"health" + 0.000*"family" + 0.000*"security" + 0.000*"job" + '
#   '0.000*"strong" + 0.000*"administration"'),
#  (14,
#   '0.000*"work" + 0.000*"job" + 0.000*"family" + 0.000*"new" + 0.000*"child" + '
#   '0.000*"health" + 0.000*"community" + 0.000*"good" + 0.000*"bush" + '
#   '0.000*"strong"'),
#  (30,
#   '0.000*"health" + 0.000*"work" + 0.000*"security" + 0.000*"strong" + '
#   '0.000*"administration" + 0.000*"new" + 0.000*"job" + 0.000*"care" + '
#   '0.000*"create" + 0.000*"family"'),
#  (77,
#   '0.000*"strong" + 0.000*"work" + 0.000*"world" + 0.000*"need" + '
#   '0.000*"family" + 0.000*"new" + 0.000*"care" + 0.000*"job" + 0.000*"health" '
#   '+ 0.000*"help"'),
#  (62,
#   '0.000*"health" + 0.000*"work" + 0.000*"new" + 0.000*"job" + 0.000*"strong" '
#   '+ 0.000*"bush" + 0.000*"security" + 0.000*"nation" + 0.000*"need" + '
#   '0.000*"care"'),
#  (68,
#   '0.000*"work" + 0.000*"health" + 0.000*"family" + 0.000*"need" + 0.000*"job" '
#   '+ 0.000*"new" + 0.000*"child" + 0.000*"strong" + 0.000*"world" + '
#   '0.000*"government"'),
#  (74,
#   '0.000*"work" + 0.000*"job" + 0.000*"need" + 0.000*"strong" + 0.000*"health" '
#   '+ 0.000*"care" + 0.000*"world" + 0.000*"new" + 0.000*"security" + '
#   '0.000*"family"'),
#  (16,
#   '0.000*"work" + 0.000*"new" + 0.000*"job" + 0.000*"strong" + 0.000*"care" + '
#   '0.000*"world" + 0.000*"john" + 0.000*"protect" + 0.000*"school" + '
#   '0.000*"child"'),
#  (15,
#   '0.010*"work" + 0.009*"new" + 0.009*"health" + 0.008*"strong" + '
#   '0.008*"family" + 0.007*"job" + 0.007*"security" + 0.007*"world" + '
#   '0.007*"need" + 0.006*"care"')]
#
# Coherence Score:  0.3256641216328393

# %%
## REPUBLICAN 2004
corpus_repub_2004 = platforms_mat_corpus[3]

model_repub_2004 = build_lda_model([corpus_repub_2004], platforms_dict)

pprint(model_repub_2004.print_topics())

repub_2004_coherence = comp_coherence(model_repub_2004,[corpus_repub_2004], platforms_dict)
# Out:
# [(28,
#   '0.000*"health" + 0.000*"bush" + 0.000*"child" + 0.000*"nation" + '
#   '0.000*"continue" + 0.000*"increase" + 0.000*"effort" + 0.000*"work" + '
#   '0.000*"congress" + 0.000*"world"'),
#  (33,
#   '0.000*"bush" + 0.000*"work" + 0.000*"effort" + 0.000*"nation" + '
#   '0.000*"commitment" + 0.000*"world" + 0.000*"party" + 0.000*"pass" + '
#   '0.000*"strong" + 0.000*"economy"'),
#  (19,
#   '0.000*"congress" + 0.000*"bush" + 0.000*"work" + 0.000*"united" + '
#   '0.000*"nation" + 0.000*"provide" + 0.000*"effort" + 0.000*"health" + '
#   '0.000*"improve" + 0.000*"respect"'),
#  (34,
#   '0.000*"bush" + 0.000*"help" + 0.000*"world" + 0.000*"nation" + '
#   '0.000*"provide" + 0.000*"work" + 0.000*"health" + 0.000*"new" + '
#   '0.000*"agreement" + 0.000*"include"'),
#  (56,
#   '0.000*"bush" + 0.000*"government" + 0.000*"time" + 0.000*"family" + '
#   '0.000*"reform" + 0.000*"congress" + 0.000*"leadership" + 0.000*"protect" + '
#   '0.000*"trade" + 0.000*"terrorist"'),
#  (41,
#   '0.000*"bush" + 0.000*"united" + 0.000*"congress" + 0.000*"nation" + '
#   '0.000*"care" + 0.000*"world" + 0.000*"work" + 0.000*"help" + 0.000*"tax" + '
#   '0.000*"child"'),
#  (58,
#   '0.000*"bush" + 0.000*"health" + 0.000*"united" + 0.000*"nation" + '
#   '0.000*"effort" + 0.000*"work" + 0.000*"care" + 0.000*"new" + 0.000*"child" '
#   '+ 0.000*"country"'),
#  (61,
#   '0.000*"bush" + 0.000*"health" + 0.000*"government" + 0.000*"nation" + '
#   '0.000*"tax" + 0.000*"congress" + 0.000*"help" + 0.000*"work" + '
#   '0.000*"security" + 0.000*"war"'),
#  (63,
#   '0.000*"bush" + 0.000*"health" + 0.000*"nation" + 0.000*"child" + '
#   '0.000*"effort" + 0.000*"congress" + 0.000*"government" + 0.000*"world" + '
#   '0.000*"provide" + 0.000*"need"'),
#  (24,
#   '0.000*"bush" + 0.000*"nation" + 0.000*"health" + 0.000*"congress" + '
#   '0.000*"new" + 0.000*"effort" + 0.000*"care" + 0.000*"work" + '
#   '0.000*"provide" + 0.000*"child"'),
#  (26,
#   '0.000*"new" + 0.000*"bush" + 0.000*"health" + 0.000*"congress" + '
#   '0.000*"nation" + 0.000*"world" + 0.000*"government" + 0.000*"effort" + '
#   '0.000*"care" + 0.000*"united"'),
#  (52,
#   '0.000*"nation" + 0.000*"help" + 0.000*"bush" + 0.000*"health" + '
#   '0.000*"congress" + 0.000*"trade" + 0.000*"effort" + 0.000*"work" + '
#   '0.000*"tax" + 0.000*"new"'),
#  (77,
#   '0.000*"bush" + 0.000*"help" + 0.000*"work" + 0.000*"nation" + '
#   '0.000*"congress" + 0.000*"world" + 0.000*"care" + 0.000*"government" + '
#   '0.000*"provide" + 0.000*"effort"'),
#  (7,
#   '0.000*"bush" + 0.000*"nation" + 0.000*"new" + 0.000*"effort" + '
#   '0.000*"united" + 0.000*"work" + 0.000*"child" + 0.000*"help" + '
#   '0.000*"health" + 0.000*"congress"'),
#  (53,
#   '0.000*"bush" + 0.000*"health" + 0.000*"congress" + 0.000*"work" + '
#   '0.000*"world" + 0.000*"effort" + 0.000*"new" + 0.000*"nation" + '
#   '0.000*"government" + 0.000*"help"'),
#  (37,
#   '0.000*"bush" + 0.000*"world" + 0.000*"government" + 0.000*"congress" + '
#   '0.000*"nation" + 0.000*"care" + 0.000*"effort" + 0.000*"new" + 0.000*"tax" '
#   '+ 0.000*"applaud"'),
#  (68,
#   '0.000*"bush" + 0.000*"health" + 0.000*"work" + 0.000*"congress" + '
#   '0.000*"government" + 0.000*"new" + 0.000*"nation" + 0.000*"child" + '
#   '0.000*"provide" + 0.000*"united"'),
#  (74,
#   '0.000*"bush" + 0.000*"nation" + 0.000*"work" + 0.000*"health" + '
#   '0.000*"care" + 0.000*"congress" + 0.000*"help" + 0.000*"increase" + '
#   '0.000*"effort" + 0.000*"world"'),
#  (16,
#   '0.000*"bush" + 0.000*"new" + 0.000*"work" + 0.000*"care" + '
#   '0.000*"government" + 0.000*"nation" + 0.000*"help" + 0.000*"effort" + '
#   '0.000*"congress" + 0.000*"united"'),
#  (62,
#   '0.013*"bush" + 0.008*"health" + 0.007*"nation" + 0.007*"work" + '
#   '0.007*"congress" + 0.007*"new" + 0.006*"government" + 0.006*"effort" + '
#   '0.006*"world" + 0.006*"help"')]
#
# Coherence Score:  0.252882473294321

# %%
##DEMOCRATIC 2008
corpus_demo_2008 = platforms_mat_corpus[4]

model_demo_2008 = build_lda_model([corpus_demo_2008], platforms_dict)

pprint(model_demo_2008.print_topics())

# Compute Coherence Score
demo_2008_coherence = comp_coherence(model_demo_2008, [corpus_demo_2008], platforms_dict)
# Out:
# [(56,
#   '0.000*"government" + 0.000*"unconditional" + 0.000*"underemployment" + '
#   '0.000*"tropical" + 0.000*"trustworthy" + 0.000*"turbine" + 0.000*"turning" '
#   '+ 0.000*"unavailable" + 0.000*"unchecked" + 0.000*"treatable"'),
#  (33,
#   '0.000*"work" + 0.000*"policy" + 0.000*"include" + 0.000*"provide" + '
#   '0.000*"need" + 0.000*"help" + 0.000*"ensure" + 0.000*"nation" + 0.000*"job" '
#   '+ 0.000*"education"'),
#  (19,
#   '0.000*"nation" + 0.000*"job" + 0.000*"security" + 0.000*"need" + '
#   '0.000*"provide" + 0.000*"country" + 0.000*"help" + 0.000*"community" + '
#   '0.000*"ensure" + 0.000*"family"'),
#  (28,
#   '0.000*"right" + 0.000*"work" + 0.000*"health" + 0.000*"lead" + '
#   '0.000*"restore" + 0.000*"increase" + 0.000*"law" + 0.000*"leadership" + '
#   '0.000*"include" + 0.000*"weapon"'),
#  (41,
#   '0.000*"work" + 0.000*"care" + 0.000*"business" + 0.000*"school" + '
#   '0.000*"provide" + 0.000*"woman" + 0.000*"public" + 0.000*"reform" + '
#   '0.000*"new" + 0.000*"good"'),
#  (63,
#   '0.000*"ensure" + 0.000*"family" + 0.000*"provide" + 0.000*"care" + '
#   '0.000*"new" + 0.000*"need" + 0.000*"time" + 0.000*"create" + '
#   '0.000*"security" + 0.000*"country"'),
#  (4,
#   '0.000*"help" + 0.000*"world" + 0.000*"need" + 0.000*"provide" + '
#   '0.000*"health" + 0.000*"country" + 0.000*"protect" + 0.000*"family" + '
#   '0.000*"community" + 0.000*"worker"'),
#  (34,
#   '0.000*"country" + 0.000*"work" + 0.000*"provide" + 0.000*"health" + '
#   '0.000*"u.s." + 0.000*"nation" + 0.000*"include" + 0.000*"law" + '
#   '0.000*"military" + 0.000*"long"'),
#  (58,
#   '0.000*"care" + 0.000*"country" + 0.000*"work" + 0.000*"health" + '
#   '0.000*"ensure" + 0.000*"need" + 0.000*"government" + 0.000*"child" + '
#   '0.000*"world" + 0.000*"time"'),
#  (43,
#   '0.000*"new" + 0.000*"security" + 0.000*"work" + 0.000*"care" + '
#   '0.000*"health" + 0.000*"government" + 0.000*"country" + 0.000*"time" + '
#   '0.000*"increase" + 0.000*"worker"'),
#  (14,
#   '0.000*"work" + 0.000*"health" + 0.000*"family" + 0.000*"care" + 0.000*"job" '
#   '+ 0.000*"provide" + 0.000*"community" + 0.000*"government" + 0.000*"world" '
#   '+ 0.000*"ensure"'),
#  (26,
#   '0.000*"health" + 0.000*"new" + 0.000*"work" + 0.000*"ensure" + '
#   '0.000*"provide" + 0.000*"right" + 0.000*"care" + 0.000*"government" + '
#   '0.000*"need" + 0.000*"world"'),
#  (62,
#   '0.000*"work" + 0.000*"health" + 0.000*"provide" + 0.000*"ensure" + '
#   '0.000*"care" + 0.000*"new" + 0.000*"need" + 0.000*"nation" + 0.000*"worker" '
#   '+ 0.000*"government"'),
#  (30,
#   '0.000*"health" + 0.000*"work" + 0.000*"security" + 0.000*"provide" + '
#   '0.000*"care" + 0.000*"government" + 0.000*"right" + 0.000*"new" + '
#   '0.000*"ensure" + 0.000*"program"'),
#  (77,
#   '0.000*"work" + 0.000*"provide" + 0.000*"help" + 0.000*"care" + '
#   '0.000*"government" + 0.000*"health" + 0.000*"new" + 0.000*"family" + '
#   '0.000*"world" + 0.000*"need"'),
#  (74,
#   '0.000*"work" + 0.000*"care" + 0.000*"health" + 0.000*"new" + 0.000*"need" + '
#   '0.000*"security" + 0.000*"provide" + 0.000*"job" + 0.000*"family" + '
#   '0.000*"help"'),
#  (37,
#   '0.000*"work" + 0.000*"care" + 0.000*"ensure" + 0.000*"government" + '
#   '0.000*"world" + 0.000*"right" + 0.000*"provide" + 0.000*"security" + '
#   '0.000*"new" + 0.000*"education"'),
#  (68,
#   '0.000*"work" + 0.000*"health" + 0.000*"government" + 0.000*"provide" + '
#   '0.000*"new" + 0.000*"right" + 0.000*"need" + 0.000*"country" + '
#   '0.000*"family" + 0.000*"ensure"'),
#  (16,
#   '0.000*"work" + 0.000*"new" + 0.000*"care" + 0.000*"government" + '
#   '0.000*"ensure" + 0.000*"provide" + 0.000*"health" + 0.000*"program" + '
#   '0.000*"job" + 0.000*"help"'),
#  (66,
#   '0.011*"work" + 0.009*"health" + 0.008*"new" + 0.007*"government" + '
#   '0.007*"care" + 0.007*"provide" + 0.007*"ensure" + 0.006*"right" + '
#   '0.006*"country" + 0.006*"security"')]
#
# Coherence Score:  0.29856766065075613

# %%
## REPUBLICAN 2008
corpus_repub_2008 = platforms_mat_corpus[5]

model_repub_2008 = build_lda_model([corpus_repub_2008], platforms_dict)

pprint(model_repub_2008.print_topics())

repub_2008_coherence = comp_coherence(model_repub_2008,[corpus_repub_2008], platforms_dict)
# Out:
# [(33,
#   '0.000*"government" + 0.000*"unconditional" + 0.000*"underemployment" + '
#   '0.000*"tropical" + 0.000*"trustworthy" + 0.000*"turbine" + 0.000*"turning" '
#   '+ 0.000*"unavailable" + 0.000*"unchecked" + 0.000*"treatable"'),
#  (34,
#   '0.000*"health" + 0.000*"care" + 0.000*"family" + 0.000*"right" + '
#   '0.000*"need" + 0.000*"federal" + 0.000*"system" + 0.000*"government" + '
#   '0.000*"undemocratic" + 0.000*"unchecked"'),
#  (28,
#   '0.000*"right" + 0.000*"health" + 0.000*"system" + 0.000*"need" + '
#   '0.000*"care" + 0.000*"federal" + 0.000*"government" + 0.000*"commitment" + '
#   '0.000*"treatment" + 0.000*"community"'),
#  (63,
#   '0.000*"federal" + 0.000*"care" + 0.000*"right" + 0.000*"family" + '
#   '0.000*"government" + 0.000*"health" + 0.000*"need" + 0.000*"nation" + '
#   '0.000*"work" + 0.000*"change"'),
#  (19,
#   '0.000*"health" + 0.000*"government" + 0.000*"nation" + 0.000*"care" + '
#   '0.000*"federal" + 0.000*"need" + 0.000*"individual" + 0.000*"party" + '
#   '0.000*"remain" + 0.000*"new"'),
#  (58,
#   '0.000*"care" + 0.000*"government" + 0.000*"health" + 0.000*"need" + '
#   '0.000*"system" + 0.000*"tax" + 0.000*"ensure" + 0.000*"law" + '
#   '0.000*"federal" + 0.000*"business"'),
#  (41,
#   '0.000*"care" + 0.000*"government" + 0.000*"family" + 0.000*"law" + '
#   '0.000*"child" + 0.000*"country" + 0.000*"right" + 0.000*"federal" + '
#   '0.000*"business" + 0.000*"education"'),
#  (4,
#   '0.000*"health" + 0.000*"care" + 0.000*"government" + 0.000*"nation" + '
#   '0.000*"need" + 0.000*"country" + 0.000*"good" + 0.000*"protect" + '
#   '0.000*"effort" + 0.000*"child"'),
#  (13,
#   '0.000*"federal" + 0.000*"care" + 0.000*"government" + 0.000*"health" + '
#   '0.000*"right" + 0.000*"business" + 0.000*"system" + 0.000*"program" + '
#   '0.000*"energy" + 0.000*"world"'),
#  (24,
#   '0.000*"care" + 0.000*"government" + 0.000*"right" + 0.000*"health" + '
#   '0.000*"need" + 0.000*"tax" + 0.000*"nation" + 0.000*"law" + 0.000*"energy" '
#   '+ 0.000*"increase"'),
#  (52,
#   '0.000*"right" + 0.000*"government" + 0.000*"tax" + 0.000*"health" + '
#   '0.000*"federal" + 0.000*"care" + 0.000*"system" + 0.000*"program" + '
#   '0.000*"nation" + 0.000*"education"'),
#  (26,
#   '0.000*"care" + 0.000*"government" + 0.000*"health" + 0.000*"right" + '
#   '0.000*"federal" + 0.000*"need" + 0.000*"energy" + 0.000*"nation" + '
#   '0.000*"system" + 0.000*"family"'),
#  (53,
#   '0.000*"government" + 0.000*"health" + 0.000*"care" + 0.000*"law" + '
#   '0.000*"federal" + 0.000*"system" + 0.000*"right" + 0.000*"family" + '
#   '0.000*"need" + 0.000*"world"'),
#  (30,
#   '0.000*"health" + 0.000*"care" + 0.000*"right" + 0.000*"government" + '
#   '0.000*"federal" + 0.000*"high" + 0.000*"law" + 0.000*"family" + '
#   '0.000*"state" + 0.000*"security"'),
#  (68,
#   '0.000*"government" + 0.000*"health" + 0.000*"right" + 0.000*"federal" + '
#   '0.000*"tax" + 0.000*"need" + 0.000*"care" + 0.000*"energy" + 0.000*"law" + '
#   '0.000*"child"'),
#  (62,
#   '0.000*"health" + 0.000*"care" + 0.000*"government" + 0.000*"federal" + '
#   '0.000*"nation" + 0.000*"right" + 0.000*"law" + 0.000*"business" + '
#   '0.000*"family" + 0.000*"need"'),
#  (7,
#   '0.000*"government" + 0.000*"care" + 0.000*"federal" + 0.000*"family" + '
#   '0.000*"health" + 0.000*"nation" + 0.000*"right" + 0.000*"need" + '
#   '0.000*"law" + 0.000*"tax"'),
#  (74,
#   '0.000*"care" + 0.000*"government" + 0.000*"right" + 0.000*"health" + '
#   '0.000*"need" + 0.000*"tax" + 0.000*"federal" + 0.000*"nation" + '
#   '0.000*"family" + 0.000*"law"'),
#  (16,
#   '0.000*"care" + 0.000*"government" + 0.000*"right" + 0.000*"program" + '
#   '0.000*"health" + 0.000*"federal" + 0.000*"tax" + 0.000*"child" + '
#   '0.000*"nation" + 0.000*"education"'),
#  (37,
#   '0.010*"government" + 0.010*"care" + 0.009*"health" + 0.008*"right" + '
#   '0.007*"federal" + 0.006*"tax" + 0.006*"family" + 0.006*"law" + 0.006*"need" '
#   '+ 0.005*"nation"')]
#
# Coherence Score:  0.29139007694954033

# %%
##DEMOCRATIC 2012
corpus_demo_2012 = platforms_mat_corpus[6]

model_demo_2012 = build_lda_model([corpus_demo_2012], platforms_dict)

pprint(model_demo_2012.print_topics())

# Compute Coherence Score
demo_2012_coherence = comp_coherence(model_demo_2012, [corpus_demo_2012], platforms_dict)
# Out:
# [(79,
#   '0.000*"unchecked" + 0.000*"undemocratic" + 0.000*"tribes" + '
#   '0.000*"tropical" + 0.000*"trustworthy" + 0.000*"turbine" + 0.000*"turning" '
#   '+ 0.000*"unavailable" + 0.000*"traumatic" + 0.000*"unconditional"'),
#  (41,
#   '0.000*"continue" + 0.000*"community" + 0.000*"work" + 0.000*"help" + '
#   '0.000*"job" + 0.000*"administration" + 0.000*"middle" + 0.000*"build" + '
#   '0.000*"effort" + 0.000*"ensure"'),
#  (19,
#   '0.000*"work" + 0.000*"include" + 0.000*"effort" + 0.000*"help" + '
#   '0.000*"ensure" + 0.000*"economy" + 0.000*"nation" + 0.000*"job" + '
#   '0.000*"economic" + 0.000*"build"'),
#  (56,
#   '0.000*"party" + 0.000*"work" + 0.000*"government" + 0.000*"economic" + '
#   '0.000*"family" + 0.000*"administration" + 0.000*"continue" + 0.000*"health" '
#   '+ 0.000*"obama" + 0.000*"security"'),
#  (58,
#   '0.000*"obama" + 0.000*"work" + 0.000*"united" + 0.000*"health" + '
#   '0.000*"continue" + 0.000*"economy" + 0.000*"country" + 0.000*"job" + '
#   '0.000*"worker" + 0.000*"world"'),
#  (4,
#   '0.000*"build" + 0.000*"family" + 0.000*"government" + 0.000*"work" + '
#   '0.000*"economy" + 0.000*"economic" + 0.000*"country" + 0.000*"world" + '
#   '0.000*"create" + 0.000*"continue"'),
#  (34,
#   '0.000*"job" + 0.000*"obama" + 0.000*"continue" + 0.000*"work" + '
#   '0.000*"build" + 0.000*"time" + 0.000*"provide" + 0.000*"new" + '
#   '0.000*"reform" + 0.000*"act"'),
#  (33,
#   '0.000*"work" + 0.000*"continue" + 0.000*"obama" + 0.000*"job" + '
#   '0.000*"family" + 0.000*"country" + 0.000*"economy" + 0.000*"help" + '
#   '0.000*"rural" + 0.000*"policy"'),
#  (28,
#   '0.000*"work" + 0.000*"obama" + 0.000*"continue" + 0.000*"health" + '
#   '0.000*"job" + 0.000*"right" + 0.000*"effort" + 0.000*"community" + '
#   '0.000*"administration" + 0.000*"government"'),
#  (43,
#   '0.000*"work" + 0.000*"obama" + 0.000*"continue" + 0.000*"family" + '
#   '0.000*"administration" + 0.000*"care" + 0.000*"economy" + 0.000*"job" + '
#   '0.000*"help" + 0.000*"security"'),
#  (74,
#   '0.000*"work" + 0.000*"obama" + 0.000*"job" + 0.000*"country" + '
#   '0.000*"security" + 0.000*"continue" + 0.000*"family" + 0.000*"party" + '
#   '0.000*"law" + 0.000*"great"'),
#  (26,
#   '0.000*"continue" + 0.000*"obama" + 0.000*"work" + 0.000*"health" + '
#   '0.000*"administration" + 0.000*"new" + 0.000*"job" + 0.000*"include" + '
#   '0.000*"commit" + 0.000*"world"'),
#  (7,
#   '0.000*"obama" + 0.000*"work" + 0.000*"continue" + 0.000*"country" + '
#   '0.000*"security" + 0.000*"job" + 0.000*"family" + 0.000*"include" + '
#   '0.000*"help" + 0.000*"economy"'),
#  (52,
#   '0.000*"obama" + 0.000*"continue" + 0.000*"work" + 0.000*"security" + '
#   '0.000*"right" + 0.000*"help" + 0.000*"family" + 0.000*"health" + '
#   '0.000*"administration" + 0.000*"build"'),
#  (68,
#   '0.000*"work" + 0.000*"obama" + 0.000*"job" + 0.000*"continue" + '
#   '0.000*"family" + 0.000*"economy" + 0.000*"build" + 0.000*"health" + '
#   '0.000*"country" + 0.000*"right"'),
#  (37,
#   '0.000*"obama" + 0.000*"continue" + 0.000*"work" + 0.000*"job" + '
#   '0.000*"security" + 0.000*"right" + 0.000*"country" + 0.000*"administration" '
#   '+ 0.000*"world" + 0.000*"government"'),
#  (30,
#   '0.000*"obama" + 0.000*"work" + 0.000*"continue" + 0.000*"job" + '
#   '0.000*"security" + 0.000*"health" + 0.000*"administration" + 0.000*"right" '
#   '+ 0.000*"party" + 0.000*"create"'),
#  (16,
#   '0.000*"work" + 0.000*"obama" + 0.000*"job" + 0.000*"continue" + '
#   '0.000*"care" + 0.000*"new" + 0.000*"economy" + 0.000*"country" + '
#   '0.000*"government" + 0.000*"economic"'),
#  (62,
#   '0.009*"argue" + 0.009*"legal" + 0.009*"northern" + 0.009*"communities" + '
#   '0.009*"bush" + 0.009*"size" + 0.009*"coalition" + 0.009*"destroy" + '
#   '0.009*"osama" + 0.009*"mercury"'),
#  (66,
#   '0.012*"work" + 0.011*"obama" + 0.010*"continue" + 0.008*"job" + '
#   '0.006*"family" + 0.006*"country" + 0.006*"health" + 0.006*"economic" + '
#   '0.006*"administration" + 0.006*"security"')]
#
# Coherence Score:  0.31088342146166215

# %%
## REPUBLICAN 2012
corpus_repub_2012 = platforms_mat_corpus[7]

model_repub_2012 = build_lda_model([corpus_repub_2012], platforms_dict)

pprint(model_repub_2012.print_topics())

repub_2012_coherence = comp_coherence(model_repub_2012,[corpus_repub_2012], platforms_dict)
# Out:
# [(28,
#   '0.000*"government" + 0.000*"right" + 0.000*"federal" + 0.000*"future" + '
#   '0.000*"protect" + 0.000*"act" + 0.000*"education" + 0.000*"reform" + '
#   '0.000*"great" + 0.000*"public"'),
#  (34,
#   '0.000*"nation" + 0.000*"world" + 0.000*"need" + 0.000*"public" + '
#   '0.000*"administration" + 0.000*"country" + 0.000*"u.s." + 0.000*"family" + '
#   '0.000*"right" + 0.000*"job"'),
#  (33,
#   '0.000*"current" + 0.000*"law" + 0.000*"government" + 0.000*"public" + '
#   '0.000*"federal" + 0.000*"life" + 0.000*"encourage" + 0.000*"party" + '
#   '0.000*"security" + 0.000*"future"'),
#  (41,
#   '0.000*"government" + 0.000*"federal" + 0.000*"program" + 0.000*"right" + '
#   '0.000*"policy" + 0.000*"current" + 0.000*"nation" + 0.000*"need" + '
#   '0.000*"private" + 0.000*"country"'),
#  (19,
#   '0.000*"federal" + 0.000*"government" + 0.000*"program" + 0.000*"need" + '
#   '0.000*"service" + 0.000*"u.s." + 0.000*"administration" + 0.000*"job" + '
#   '0.000*"nation" + 0.000*"law"'),
#  (56,
#   '0.000*"government" + 0.000*"way" + 0.000*"especially" + 0.000*"work" + '
#   '0.000*"job" + 0.000*"time" + 0.000*"need" + 0.000*"great" + 0.000*"public" '
#   '+ 0.000*"child"'),
#  (24,
#   '0.000*"government" + 0.000*"law" + 0.000*"nation" + 0.000*"federal" + '
#   '0.000*"right" + 0.000*"administration" + 0.000*"policy" + 0.000*"economic" '
#   '+ 0.000*"new" + 0.000*"current"'),
#  (58,
#   '0.000*"federal" + 0.000*"government" + 0.000*"service" + 0.000*"u.s." + '
#   '0.000*"country" + 0.000*"current" + 0.000*"need" + 0.000*"reform" + '
#   '0.000*"economic" + 0.000*"law"'),
#  (4,
#   '0.000*"government" + 0.000*"job" + 0.000*"advance" + 0.000*"need" + '
#   '0.000*"policy" + 0.000*"work" + 0.000*"party" + 0.000*"family" + '
#   '0.000*"country" + 0.000*"public"'),
#  (63,
#   '0.000*"federal" + 0.000*"government" + 0.000*"administration" + '
#   '0.000*"current" + 0.000*"law" + 0.000*"nation" + 0.000*"public" + '
#   '0.000*"right" + 0.000*"program" + 0.000*"need"'),
#  (52,
#   '0.000*"federal" + 0.000*"right" + 0.000*"government" + '
#   '0.000*"administration" + 0.000*"program" + 0.000*"nation" + 0.000*"u.s." + '
#   '0.000*"law" + 0.000*"current" + 0.000*"service"'),
#  (77,
#   '0.000*"government" + 0.000*"federal" + 0.000*"current" + 0.000*"right" + '
#   '0.000*"need" + 0.000*"law" + 0.000*"public" + 0.000*"nation" + '
#   '0.000*"program" + 0.000*"administration"'),
#  (26,
#   '0.000*"government" + 0.000*"federal" + 0.000*"administration" + '
#   '0.000*"right" + 0.000*"program" + 0.000*"u.s." + 0.000*"nation" + '
#   '0.000*"energy" + 0.000*"state" + 0.000*"ensure"'),
#  (30,
#   '0.000*"government" + 0.000*"federal" + 0.000*"right" + 0.000*"program" + '
#   '0.000*"administration" + 0.000*"u.s." + 0.000*"law" + 0.000*"security" + '
#   '0.000*"current" + 0.000*"job"'),
#  (7,
#   '0.000*"government" + 0.000*"federal" + 0.000*"nation" + 0.000*"law" + '
#   '0.000*"service" + 0.000*"country" + 0.000*"current" + 0.000*"program" + '
#   '0.000*"military" + 0.000*"system"'),
#  (68,
#   '0.000*"government" + 0.000*"federal" + 0.000*"current" + 0.000*"law" + '
#   '0.000*"right" + 0.000*"program" + 0.000*"need" + 0.000*"job" + '
#   '0.000*"administration" + 0.000*"service"'),
#  (62,
#   '0.000*"government" + 0.000*"federal" + 0.000*"nation" + 0.000*"law" + '
#   '0.000*"program" + 0.000*"current" + 0.000*"administration" + 0.000*"job" + '
#   '0.000*"public" + 0.000*"right"'),
#  (74,
#   '0.000*"government" + 0.000*"federal" + 0.000*"nation" + 0.000*"need" + '
#   '0.000*"right" + 0.000*"program" + 0.000*"public" + 0.000*"job" + '
#   '0.000*"current" + 0.000*"law"'),
#  (16,
#   '0.000*"government" + 0.000*"current" + 0.000*"program" + 0.000*"federal" + '
#   '0.000*"job" + 0.000*"right" + 0.000*"administration" + 0.000*"protect" + '
#   '0.000*"u.s." + 0.000*"nation"'),
#  (37,
#   '0.011*"government" + 0.008*"federal" + 0.006*"current" + 0.006*"right" + '
#   '0.006*"program" + 0.006*"law" + 0.006*"administration" + 0.005*"nation" + '
#   '0.005*"need" + 0.005*"job"')]
#
# Coherence Score:  0.2593281936880058

# %%
##DEMOCRATIC 2016
corpus_demo_2016 = platforms_mat_corpus[8]

model_demo_2016 = build_lda_model([corpus_demo_2016], platforms_dict)

pprint(model_demo_2016.print_topics())

# Compute Coherence Score
demo_2016_coherence = comp_coherence(model_demo_2016, [corpus_demo_2016], platforms_dict)
# Out:
# [(56,
#   '0.000*"unchecked" + 0.000*"undemocratic" + 0.000*"tribes" + '
#   '0.000*"tropical" + 0.000*"trustworthy" + 0.000*"turbine" + 0.000*"turning" '
#   '+ 0.000*"unavailable" + 0.000*"traumatic" + 0.000*"unconditional"'),
#  (41,
#   '0.000*"build" + 0.000*"high" + 0.000*"security" + 0.000*"public" + '
#   '0.000*"create" + 0.000*"live" + 0.000*"provide" + 0.000*"family" + '
#   '0.000*"strong" + 0.000*"indian"'),
#  (34,
#   '0.000*"ensure" + 0.000*"job" + 0.000*"family" + 0.000*"student" + '
#   '0.000*"access" + 0.000*"public" + 0.000*"provide" + 0.000*"help" + '
#   '0.000*"need" + 0.000*"expand"'),
#  (19,
#   '0.000*"health" + 0.000*"good" + 0.000*"pay" + 0.000*"housing" + '
#   '0.000*"indian" + 0.000*"provide" + 0.000*"build" + 0.000*"public" + '
#   '0.000*"new" + 0.000*"right"'),
#  (58,
#   '0.000*"health" + 0.000*"country" + 0.000*"work" + 0.000*"need" + '
#   '0.000*"ensure" + 0.000*"education" + 0.000*"community" + 0.000*"service" + '
#   '0.000*"right" + 0.000*"protect"'),
#  (33,
#   '0.000*"work" + 0.000*"family" + 0.000*"need" + 0.000*"ensure" + '
#   '0.000*"country" + 0.000*"community" + 0.000*"health" + 0.000*"fight" + '
#   '0.000*"continue" + 0.000*"public"'),
#  (43,
#   '0.000*"country" + 0.000*"community" + 0.000*"health" + 0.000*"work" + '
#   '0.000*"pay" + 0.000*"family" + 0.000*"need" + 0.000*"expand" + 0.000*"care" '
#   '+ 0.000*"worker"'),
#  (61,
#   '0.000*"health" + 0.000*"ensure" + 0.000*"work" + 0.000*"community" + '
#   '0.000*"program" + 0.000*"include" + 0.000*"increase" + 0.000*"country" + '
#   '0.000*"address" + 0.000*"income"'),
#  (28,
#   '0.000*"health" + 0.000*"right" + 0.000*"continue" + 0.000*"work" + '
#   '0.000*"public" + 0.000*"country" + 0.000*"fight" + 0.000*"ensure" + '
#   '0.000*"community" + 0.000*"education"'),
#  (79,
#   '0.000*"unchecked" + 0.000*"undemocratic" + 0.000*"tribes" + '
#   '0.000*"tropical" + 0.000*"trustworthy" + 0.000*"turbine" + 0.000*"turning" '
#   '+ 0.000*"unavailable" + 0.000*"traumatic" + 0.000*"unconditional"'),
#  (77,
#   '0.000*"health" + 0.000*"community" + 0.000*"right" + 0.000*"public" + '
#   '0.000*"work" + 0.000*"protect" + 0.000*"country" + 0.000*"need" + '
#   '0.000*"care" + 0.000*"family"'),
#  (53,
#   '0.000*"health" + 0.000*"country" + 0.000*"community" + 0.000*"work" + '
#   '0.000*"world" + 0.000*"provide" + 0.000*"right" + 0.000*"federal" + '
#   '0.000*"public" + 0.000*"care"'),
#  (30,
#   '0.000*"health" + 0.000*"community" + 0.000*"work" + 0.000*"right" + '
#   '0.000*"country" + 0.000*"job" + 0.000*"public" + 0.000*"create" + '
#   '0.000*"federal" + 0.000*"care"'),
#  (52,
#   '0.000*"health" + 0.000*"right" + 0.000*"community" + 0.000*"student" + '
#   '0.000*"expand" + 0.000*"work" + 0.000*"public" + 0.000*"include" + '
#   '0.000*"pay" + 0.000*"fight"'),
#  (74,
#   '0.000*"work" + 0.000*"health" + 0.000*"community" + 0.000*"public" + '
#   '0.000*"right" + 0.000*"protect" + 0.000*"country" + 0.000*"need" + '
#   '0.000*"job" + 0.000*"student"'),
#  (16,
#   '0.000*"work" + 0.000*"care" + 0.000*"health" + 0.000*"ensure" + 0.000*"job" '
#   '+ 0.000*"right" + 0.000*"public" + 0.000*"include" + 0.000*"pay" + '
#   '0.000*"program"'),
#  (68,
#   '0.000*"health" + 0.000*"work" + 0.000*"community" + 0.000*"right" + '
#   '0.000*"country" + 0.000*"need" + 0.000*"public" + 0.000*"pay" + '
#   '0.000*"access" + 0.000*"service"'),
#  (37,
#   '0.011*"familiesdemocrats" + 0.011*"laboratory" + 0.011*"allegation" + '
#   '0.011*"inflation" + 0.011*"tuition" + 0.011*"guantánamo" + 0.011*"body" + '
#   '0.011*"claw" + 0.011*"pledge" + 0.011*"abolish"'),
#  (66,
#   '0.019*"korea" + 0.012*"medicine" + 0.012*"outdoors" + 0.012*"track" + '
#   '0.012*"certain" + 0.012*"duty" + 0.012*"walk" + 0.012*"veterans" + '
#   '0.012*"simple" + 0.012*"away"'),
#  (62,
#   '0.011*"health" + 0.009*"community" + 0.008*"work" + 0.008*"right" + '
#   '0.007*"country" + 0.007*"public" + 0.006*"ensure" + 0.006*"include" + '
#   '0.006*"protect" + 0.006*"fight"')]
#
# Coherence Score:  0.32101714706267553

# %%
## REPUBLICAN 2016
corpus_repub_2016 = platforms_mat_corpus[9]

model_repub_2016 = build_lda_model([corpus_repub_2016], platforms_dict)

pprint(model_repub_2016.print_topics())

repub_2016_coherence = comp_coherence(model_repub_2016,[corpus_repub_2016], platforms_dict)
# Out:
# Coherence Score:  0.2496199104851365

# %%
print_topics(model_all)
# Out:
# Topic: 71 	Words: government|world|nation|new|right|federal|need|work|administration|education
# Topic: 44 	Words: government|work|family|right|federal|community|country|program|provide|health
# Topic: 33 	Words: work|country|government|need|law|public|family|nation|federal|ensure
# Topic: 60 	Words: new|government|need|health|work|right|nation|family|world|administration
# Topic: 8 	Words: government|health|right|country|federal|care|protect|work|family|community
# Topic: 21 	Words: health|new|government|work|care|nation|need|help|congress|bush
# Topic: 62 	Words: bush|applaud|congress|provide|terrorist|terror|effort|pass|hiv|endorse
# Topic: 37 	Words: government|federal|right|law|program|current|country|public|state|nation
# Topic: 3 	Words: new|health|work|care|government|nation|united|world|administration|child
# Topic: 66 	Words: work|health|right|community|new|job|need|family|continue|worker

# %%
print_topics(model_demo_2000)
# Out:
# Topic: 44 	Words: new|economy|worker|provide|need|help|prosperity|high|child|world
# Topic: 73 	Words: gore|new|work|need|unchecked|unconditional|undemocratic|underperform|unavailable|turbine
# Topic: 4 	Words: unchecked|undemocratic|tribes|tropical|trustworthy|turbine|turning|unavailable|traumatic|unconditional
# Topic: 36 	Words: new|gore|time|job|help|need|provide|public|community|security
# Topic: 42 	Words: unchecked|undemocratic|tribes|tropical|trustworthy|turbine|turning|unavailable|traumatic|unconditional
# Topic: 59 	Words: work|new|need|school|gore|child|worker|security|right|al
# Topic: 5 	Words: new|work|school|need|continue|gore|worker|right|al|help
# Topic: 1 	Words: work|gore|school|new|al|right|need|worker|continue|help
# Topic: 64 	Words: new|child|school|work|need|gore|right|al|worker|continue
# Topic: 66 	Words: new|work|need|gore|school|child|al|worker|continue|help

# %%
print_topics(model_repub_2000)
# Out:
# Topic: 79 	Words: new|health|government|administration|federal|governor|individual|country|right|increase
# Topic: 70 	Words: administration|government|need|care|health|new|federal|unavailable|undemocratic|turning
# Topic: 71 	Words: system|congress|administration|law|economic|policy|world|health|right|public
# Topic: 32 	Words: government|health|new|governor|country|administration|u.s.|threat|promote|individual
# Topic: 12 	Words: government|health|new|administration|care|united|need|nation|federal|law
# Topic: 26 	Words: new|administration|government|health|federal|united|care|need|system|nation
# Topic: 20 	Words: government|federal|health|administration|new|united|family|need|tax|program
# Topic: 37 	Words: government|administration|federal|new|care|world|tax|reform|child|health
# Topic: 3 	Words: dangerous|chemical|facility|voluntary|rely|major|ladder|operate|look|arm
# Topic: 68 	Words: government|new|health|administration|federal|united|need|care|family|program

# %%
print_topics(model_demo_2004)
# Out:
# Topic: 71 	Words: unchecked|undemocratic|tribes|tropical|trustworthy|turbine|turning|unavailable|traumatic|unconditional
# Topic: 79 	Words: unchecked|undemocratic|tribes|tropical|trustworthy|turbine|turning|unavailable|traumatic|unconditional
# Topic: 70 	Words: unchecked|undemocratic|tribes|tropical|trustworthy|turbine|turning|unavailable|traumatic|unconditional
# Topic: 58 	Words: unchecked|undemocratic|tribes|tropical|trustworthy|turbine|turning|unavailable|traumatic|unconditional
# Topic: 36 	Words: family|work|world|administration|health|new|turning|underemployment|unconditional|unchecked
# Topic: 68 	Words: work|health|family|need|job|new|child|strong|world|government
# Topic: 16 	Words: work|new|job|strong|care|world|john|protect|school|child
# Topic: 66 	Words: work|world|new|job|strong|family|need|security|government|care
# Topic: 5 	Words: work|new|health|john|need|job|administration|strong|good|security
# Topic: 15 	Words: work|new|health|strong|family|job|security|world|need|care

# %%
print_topics(model_repub_2004)
# Out:
# Topic: 79 	Words: bush|provide|law|terrorist|high|opportunity|world|child|act|congress
# Topic: 70 	Words: new|bush|health|care|unconditional|trustworthy|turbine|turning|unavailable|unchecked
# Topic: 8 	Words: bush|health|world|care|work|nation|effort|tax|government|congress
# Topic: 36 	Words: bush|health|work|world|nation|help|congress|united|new|child
# Topic: 31 	Words: bush|congress|care|trade|effort|government|help|work|health|world
# Topic: 6 	Words: bush|nation|effort|work|provide|health|congress|united|new|help
# Topic: 20 	Words: bush|congress|work|health|nation|world|help|government|united|provide
# Topic: 5 	Words: bush|effort|congress|health|nation|work|new|provide|government|help
# Topic: 37 	Words: bush|world|government|congress|nation|care|effort|new|tax|applaud
# Topic: 62 	Words: bush|health|nation|work|congress|new|government|effort|world|help

# %%
print_topics(model_demo_2008)
# Out:
# Topic: 71 	Words: unchecked|undemocratic|tribes|tropical|trustworthy|turbine|turning|unavailable|traumatic|unconditional
# Topic: 79 	Words: unchecked|undemocratic|tribes|tropical|trustworthy|turbine|turning|unavailable|traumatic|unconditional
# Topic: 56 	Words: government|unconditional|underemployment|tropical|trustworthy|turbine|turning|unavailable|unchecked|treatable
# Topic: 36 	Words: community|education|need|service|security|change|country|protect|help|family
# Topic: 32 	Words: world|worker|family|need|health|provide|help|education|energy|ensure
# Topic: 11 	Words: work|ensure|provide|health|government|new|right|family|country|care
# Topic: 68 	Words: work|health|government|provide|new|right|need|country|family|ensure
# Topic: 5 	Words: work|health|provide|new|care|right|government|ensure|country|need
# Topic: 37 	Words: work|care|ensure|government|world|right|provide|security|new|education
# Topic: 66 	Words: work|health|new|government|care|provide|ensure|right|country|security

# %%
print_topics(model_repub_2008)
# Out:
# Topic: 79 	Words: government|need|right|care|law|health|federal|unconditional|undemocratic|unavailable
# Topic: 71 	Words: unchecked|undemocratic|tribes|tropical|trustworthy|turbine|turning|unavailable|traumatic|unconditional
# Topic: 70 	Words: government|care|undemocratic|underpayment|trustworthy|turbine|turning|unavailable|unchecked|unconditional
# Topic: 32 	Words: family|right|tax|need|government|health|care|undemocratic|underpayment|unchecked
# Topic: 12 	Words: government|care|health|education|federal|nation|high|tax|protect|system
# Topic: 26 	Words: care|government|health|right|federal|need|energy|nation|system|family
# Topic: 5 	Words: government|health|care|right|federal|nation|tax|system|need|energy
# Topic: 20 	Words: care|federal|government|right|family|law|tax|health|system|nation
# Topic: 66 	Words: government|care|right|need|family|federal|world|health|system|state
# Topic: 37 	Words: government|care|health|right|federal|tax|family|law|need|nation

# %%
print_topics(model_demo_2012)
# Out:
# Topic: 79 	Words: unchecked|undemocratic|tribes|tropical|trustworthy|turbine|turning|unavailable|traumatic|unconditional
# Topic: 71 	Words: unchecked|undemocratic|tribes|tropical|trustworthy|turbine|turning|unavailable|traumatic|unconditional
# Topic: 36 	Words: obama|continue|work|trustworthy|turbine|turning|unavailable|unchecked|unconditional|undemocratic
# Topic: 56 	Words: party|work|government|economic|family|administration|continue|health|obama|security
# Topic: 12 	Words: work|obama|health|economy|economic|continue|government|administration|job|protect
# Topic: 26 	Words: continue|obama|work|health|administration|new|job|include|commit|world
# Topic: 37 	Words: obama|continue|work|job|security|right|country|administration|world|government
# Topic: 5 	Words: obama|continue|work|administration|job|health|effort|economy|economic|country
# Topic: 62 	Words: argue|legal|northern|communities|bush|size|coalition|destroy|osama|mercury
# Topic: 66 	Words: work|obama|continue|job|family|country|health|economic|administration|security

# %%
print_topics(model_repub_2012)
# Out:
# Topic: 79 	Words: federal|government|party|private|current|program|service|work|include|world
# Topic: 70 	Words: federal|government|unconditional|underpayment|tropical|trustworthy|turbine|turning|unavailable|unchecked
# Topic: 32 	Words: government|federal|program|right|turning|unconditional|unchecked|underemployment|underperforming|unavailable
# Topic: 71 	Words: law|nation|administration|current|economic|public|security|policy|service|federal
# Topic: 36 	Words: federal|government|nation|current|lead|law|program|administration|include|service
# Topic: 26 	Words: government|federal|administration|right|program|u.s.|nation|energy|state|ensure
# Topic: 16 	Words: government|current|program|federal|job|right|administration|protect|u.s.|nation
# Topic: 66 	Words: government|federal|right|world|job|service|need|current|program|public
# Topic: 20 	Words: federal|government|program|right|law|administration|country|job|system|nation
# Topic: 37 	Words: government|federal|current|right|program|law|administration|nation|need|job

# %%
print_topics(model_demo_2016)
# Out:
# Topic: 79 	Words: unchecked|undemocratic|tribes|tropical|trustworthy|turbine|turning|unavailable|traumatic|unconditional
# Topic: 71 	Words: unchecked|undemocratic|tribes|tropical|trustworthy|turbine|turning|unavailable|traumatic|unconditional
# Topic: 56 	Words: unchecked|undemocratic|tribes|tropical|trustworthy|turbine|turning|unavailable|traumatic|unconditional
# Topic: 32 	Words: right|health|underemployment|turbine|turning|unavailable|unchecked|unconditional|undemocratic|tropical
# Topic: 36 	Words: pay|work|provide|protect|public|need|family|worker|service|health
# Topic: 5 	Words: health|work|public|community|right|protect|continue|ensure|provide|country
# Topic: 68 	Words: health|work|community|right|country|need|public|pay|access|service
# Topic: 37 	Words: familiesdemocrats|laboratory|allegation|inflation|tuition|guantánamo|body|claw|pledge|abolish
# Topic: 66 	Words: korea|medicine|outdoors|track|certain|duty|walk|veterans|simple|away
# Topic: 62 	Words: health|community|work|right|country|public|ensure|include|protect|fight

# %%
print_topics(model_repub_2016)
# Out:
# Topic: 28 	Words: government|country|federal|right|growth|protect|advance|market|u.s.|security
# Topic: 34 	Words: government|new|time|provide|amendment|public|act|create|protect|family
# Topic: 58 	Words: federal|country|government|policy|congress|party|nation|protect|right|administration
# Topic: 33 	Words: country|federal|government|law|nation|administration|need|right|state|public
# Topic: 24 	Words: government|right|country|federal|policy|administration|state|nation|law|congress
# Topic: 7 	Words: federal|government|country|law|right|state|nation|congress|religious|security
# Topic: 68 	Words: government|federal|right|law|administration|state|congress|country|need|public
# Topic: 74 	Words: government|federal|right|protect|law|policy|public|state|need|nation
# Topic: 16 	Words: government|federal|right|current|country|protect|administration|new|congress|public
# Topic: 37 	Words: government|federal|right|law|country|congress|administration|state|protect|public

# %% [markdown]
# # Republican Economy 2000

# %%
term_dictionary = []

# %%
text = read_file('C:/Users/Place Holder/Downloads/Republican/61620_200011.txt')

# %%
term_dictionary.append("economy")

num_docs = len(text)

contexts = []

analyzed = nlp(text)

lemmas = [token.lemma_.lower() for token in analyzed]
intersect = set(lemmas).intersection(set(term_dictionary))
if len(intersect) > 0:
    context_sentences = [token.sent.as_doc() for token in analyzed if token.lemma_.lower() in term_dictionary ]
    contexts.extend(context_sentences)
        #print(context_sentences)

# %%
patterns = []

def pattern_creator(context):
    print("create pattern")
    pattern = [(token.pos_, token.lemma_.lower()) for token in context]
    print(pattern)

for sentence in contexts:
    for token in sentence:
        if token.lemma_.lower() in term_dictionary:
            #print(token.text, token.i, " - ", token.pos_)
            start_token = token.i - 3
            end_token = token.i + 3
            context = sentence[start_token:end_token]
            print(" -> ", context)
            try:
                new_pattern = pattern_creator(context.as_doc())
            except Exception as e:
                print(e)
            print("*" * 25)
# Out:
#  ->
# division by zero
# *************************
#  ->  For The New Economy
# create pattern
# [('ADP', 'for'), ('DET', 'the'), ('PROPN', 'new'), ('PROPN', 'economy')]
# *************************
#  ->  Even though our economy, and
# create pattern
# [('ADV', 'even'), ('ADP', 'though'), ('DET', '-pron-'), ('NOUN', 'economy'), ('PUNCT', ','), ('CCONJ', 'and')]
# *************************
#  ->  ago, the economy was in
# create pattern
# [('ADV', 'ago'), ('PUNCT', ','), ('DET', 'the'), ('NOUN', 'economy'), ('VERB', 'be'), ('ADP', 'in')]
# *************************
#  ->  called the New Economy: the
# create pattern
# [('VERB', 'call'), ('DET', 'the'), ('PROPN', 'new'), ('NOUN', 'economy'), ('PUNCT', ':'), ('DET', 'the')]
# *************************
#  ->  in America's economy becomes the
# create pattern
# [('ADP', 'in'), ('PROPN', 'america'), ('PART', "'s"), ('NOUN', 'economy'), ('VERB', 'become'), ('DET', 'the')]
# *************************
#  ->  surpluses, the economy is far
# create pattern
# [('NOUN', 'surplus'), ('PUNCT', ','), ('DET', 'the'), ('NOUN', 'economy'), ('VERB', 'be'), ('ADV', 'far')]
# *************************
#  ->  essence of our economy.
# create pattern
# [('NOUN', 'essence'), ('ADP', 'of'), ('DET', '-pron-'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  in an opportunity economy.
# create pattern
# [('ADP', 'in'), ('DET', 'an'), ('NOUN', 'opportunity'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  today's global economy of open
# create pattern
# [('NOUN', 'today'), ('PART', "'s"), ('ADJ', 'global'), ('NOUN', 'economy'), ('ADP', 'of'), ('ADJ', 'open')]
# *************************
#  ->  of a global economy without limits
# create pattern
# [('ADP', 'of'), ('DET', 'a'), ('ADJ', 'global'), ('NOUN', 'economy'), ('ADP', 'without'), ('NOUN', 'limit')]
# *************************
#  ->  in the New Economy by preventing
# create pattern
# [('ADP', 'in'), ('DET', 'the'), ('PROPN', 'new'), ('PROPN', 'economy'), ('ADP', 'by'), ('VERB', 'prevent')]
# *************************
#  ->  And The New Economy:
# create pattern
# [('CCONJ', 'and'), ('DET', 'the'), ('PROPN', 'new'), ('NOUN', 'economy'), ('PUNCT', ':')]
# *************************
#  ->  of our New Economy has become
# create pattern
# [('ADP', 'of'), ('DET', '-pron-'), ('PROPN', 'new'), ('PROPN', 'economy'), ('VERB', 'have'), ('VERB', 'become')]
# *************************
#  ->  in the New Economy is to
# create pattern
# [('ADP', 'in'), ('DET', 'the'), ('PROPN', 'new'), ('PROPN', 'economy'), ('VERB', 'be'), ('PART', 'to')]
# *************************
#  ->  of the new economy and our
# create pattern
# [('ADP', 'of'), ('DET', 'the'), ('ADJ', 'new'), ('NOUN', 'economy'), ('CCONJ', 'and'), ('DET', '-pron-')]
# *************************
#  ->  in the new economy.
# create pattern
# [('ADP', 'in'), ('DET', 'the'), ('ADJ', 'new'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  of our New Economy provides unprecedented
# create pattern
# [('ADP', 'of'), ('DET', '-pron-'), ('PROPN', 'new'), ('PROPN', 'economy'), ('VERB', 'provide'), ('ADJ', 'unprecedented')]
# *************************
#  ->  in the global economy require us
# create pattern
# [('ADP', 'in'), ('DET', 'the'), ('ADJ', 'global'), ('NOUN', 'economy'), ('VERB', 'require'), ('PRON', '-pron-')]
# *************************
#  ->  maintain the expanding economy that
# create pattern
# [('VERB', 'maintain'), ('DET', 'the'), ('VERB', 'expand'), ('NOUN', 'economy'), ('ADP', 'that'), ('SPACE', '    ')]
# *************************
#  ->  they strengthen our economy, enrich
# create pattern
# [('PRON', '-pron-'), ('VERB', 'strengthen'), ('DET', '-pron-'), ('NOUN', 'economy'), ('PUNCT', ','), ('VERB', 'enrich')]
# *************************
#  ->      our expanding economy, a
# create pattern
# [('SPACE', '    '), ('DET', '-pron-'), ('VERB', 'expand'), ('NOUN', 'economy'), ('PUNCT', ','), ('DET', 'a')]
# *************************
#  ->  the American     economy.
# create pattern
# [('DET', 'the'), ('ADJ', 'american'), ('SPACE', '    '), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  the entire American economy.
# create pattern
# [('DET', 'the'), ('ADJ', 'entire'), ('ADJ', 'american'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  of our free economy has thus
# create pattern
# [('ADP', 'of'), ('DET', '-pron-'), ('ADJ', 'free'), ('NOUN', 'economy'), ('VERB', 'have'), ('ADV', 'thus')]
# *************************
#  ->  plays in our economy, particularly
# create pattern
# [('VERB', 'play'), ('ADP', 'in'), ('DET', '-pron-'), ('NOUN', 'economy'), ('PUNCT', ','), ('ADV', 'particularly')]
# *************************
#  ->  in the Global Economy Agriculture is
# create pattern
# [('ADP', 'in'), ('DET', 'the'), ('PROPN', 'global'), ('PROPN', 'economy'), ('PROPN', 'agriculture'), ('VERB', 'be')]
# *************************
#  ->  of the U.S. economy.
# create pattern
# [('ADP', 'of'), ('DET', 'the'), ('PROPN', 'u.s.'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  in the Global Economy Agriculture is
# create pattern
# [('ADP', 'in'), ('DET', 'the'), ('PROPN', 'global'), ('PROPN', 'economy'), ('PROPN', 'agriculture'), ('VERB', 'be')]
# *************************
#  ->  of the U.S. economy.
# create pattern
# [('ADP', 'of'), ('DET', 'the'), ('PROPN', 'u.s.'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  nation's New Economy, which
# create pattern
# [('NOUN', 'nation'), ('PART', "'s"), ('PROPN', 'new'), ('PROPN', 'economy'), ('PUNCT', ','), ('DET', 'which')]
# *************************
#  ->  create the New Economy.
# create pattern
# [('VERB', 'create'), ('DET', 'the'), ('PROPN', 'new'), ('PROPN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  , the entire economy could be
# create pattern
# [('PUNCT', ','), ('DET', 'the'), ('ADJ', 'entire'), ('NOUN', 'economy'), ('VERB', 'could'), ('VERB', 'be')]
# *************************
#  ->  lifeblood of our economy, and
# create pattern
# [('NOUN', 'lifeblood'), ('ADP', 'of'), ('DET', '-pron-'), ('NOUN', 'economy'), ('PUNCT', ','), ('CCONJ', 'and')]
# *************************
#  ->  transport, the economy withers away
# create pattern
# [('NOUN', 'transport'), ('PUNCT', ','), ('DET', 'the'), ('NOUN', 'economy'), ('VERB', 'wither'), ('ADV', 'away')]
# *************************
#  ->  cornerstone of the economy and,
# create pattern
# [('NOUN', 'cornerstone'), ('ADP', 'of'), ('DET', 'the'), ('NOUN', 'economy'), ('CCONJ', 'and'), ('PUNCT', ',')]
# *************************
#  ->  for efficiency, economy, and
# create pattern
# [('ADP', 'for'), ('NOUN', 'efficiency'), ('PUNCT', ','), ('NOUN', 'economy'), ('PUNCT', ','), ('CCONJ', 'and')]
# *************************
#  ->  an Information Age economy.
# create pattern
# [('DET', 'an'), ('PROPN', 'information'), ('PROPN', 'age'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  opening the world economy.
# create pattern
# [('VERB', 'open'), ('DET', 'the'), ('NOUN', 'world'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  , about political economy and free
# create pattern
# [('PUNCT', ','), ('ADP', 'about'), ('ADJ', 'political'), ('NOUN', 'economy'), ('CCONJ', 'and'), ('ADJ', 'free')]
# *************************
#  ->  Africa accept freer economies, they
# create pattern
# [('PROPN', 'africa'), ('VERB', 'accept'), ('ADJ', 'free'), ('NOUN', 'economy'), ('PUNCT', ','), ('PRON', '-pron-')]
# *************************
#  ->  As the one economy with truly
# create pattern
# [('ADP', 'as'), ('DET', 'the'), ('NUM', 'one'), ('NOUN', 'economy'), ('ADP', 'with'), ('ADV', 'truly')]
# *************************
#  ->  more interdependent global economy, one
# create pattern
# [('ADV', 'more'), ('ADJ', 'interdependent'), ('ADJ', 'global'), ('NOUN', 'economy'), ('PUNCT', ','), ('NUM', 'one')]
# *************************
#  ->  in its sputtering economy, not
# create pattern
# [('ADP', 'in'), ('DET', '-pron-'), ('NOUN', 'sputtering'), ('NOUN', 'economy'), ('PUNCT', ','), ('ADV', 'not')]
# *************************
#  ->  new globalized information economy provokes a
# create pattern
# [('ADJ', 'new'), ('ADJ', 'globalized'), ('NOUN', 'information'), ('NOUN', 'economy'), ('VERB', 'provoke'), ('DET', 'a')]
# *************************
#  ->  in the global economy, we
# create pattern
# [('ADP', 'in'), ('DET', 'the'), ('ADJ', 'global'), ('NOUN', 'economy'), ('PUNCT', ','), ('PRON', '-pron-')]
# *************************
#  ->  developing the market economies and democratic
# create pattern
# [('VERB', 'develop'), ('DET', 'the'), ('NOUN', 'market'), ('NOUN', 'economy'), ('CCONJ', 'and'), ('ADJ', 'democratic')]
# *************************
#  ->  and free market economies should continue
# create pattern
# [('CCONJ', 'and'), ('ADJ', 'free'), ('NOUN', 'market'), ('NOUN', 'economy'), ('VERB', 'should'), ('VERB', 'continue')]
# *************************
#  ->  - change in economies, societies
# create pattern
# [('PUNCT', '-'), ('NOUN', 'change'), ('ADP', 'in'), ('NOUN', 'economy'), ('PUNCT', ','), ('NOUN', 'society')]
# *************************

# %%
patterns = [
[('DET'),('ADJ', 'global'), ('NOUN','economy'),('PUNCT','.')],
      [('DET'), ('ADJ', 'global'), ('NOUN', 'economy'), ('CCONJ', 'and')],
    [('DET'), ('ADJ','global'), ('NOUN', 'economy'), ('ADP',"***") ]
]
print(patterns)
# Out:
# [['DET', ('ADJ', 'global'), ('NOUN', 'economy'), ('PUNCT', '.')], ['DET', ('ADJ', 'global'), ('NOUN', 'economy'), ('CCONJ', 'and')], ['DET', ('ADJ', 'global'), ('NOUN', 'economy'), ('ADP', '***')]]

# %%
text1 = read_file('C:/Users/Place Holder/Downloads/Republican/61620_200011.txt')

# %%
new_contexts = []

analyzed = nlp(text1)
lemmas = [token.lemma_.lower() for token in analyzed]
intersect = set(lemmas).intersection(set(term_dictionary))
if len(intersect) > 0:
    for pattern in patterns:
        in_machine = 0
        pattern_pos = 0
        pattern_find = []
        finds = []
        for token in analyzed:
            if in_machine == 0 and token.pos_ == pattern[pattern_pos] :
                in_machine = 1
                pattern_pos += 1
                pattern_find.append(token)
            elif in_machine == 1:
                if pattern_pos == len(pattern):
                    print("FOUND MATCH")
                    print(pattern_find)
                    print(pattern_find[0].sent)
                    finds.append(pattern_find)
                    in_machine = 0
                    pattern_pos = 0
                    pattern_find = []
                if pattern[pattern_pos][1] == "***":
                    if token.pos_ == pattern[pattern_pos][0]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
                elif pattern[pattern_pos][0] != "NOUN":
                    if token.pos_ == pattern[pattern_pos][0]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
                else:
                    if token.pos_ == pattern[pattern_pos][0] and token.lemma_ == pattern[pattern_pos][1]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
        
        
                    
        if len(finds) > 0:
            print(finds)
# Out:
# FOUND MATCH
# [the, new, economy, .]
# The old liberal approach - using the threat of stifling regulations to redistribute wealth and opportunity - will work no better than it ever has, and perhaps much worse, in the new economy.
# FOUND MATCH
# [the, global, economy, ,]
# In recognition of its growing importance in the global economy, we support Taiwan's accession to the World Trade Organization, as well as its participation in the World Health Organization and other multilateral institutions.
# [[the, new, economy, .], [the, global, economy, ,]]
# FOUND MATCH
# [the, new, economy, and]
# These initiatives are grounded in a steadfast commitment to open markets, to minimal regulations, and to reducing taxes that snuff out innovation - principles at the heart of the new economy and our party.
# [[the, new, economy, and]]
# FOUND MATCH
# [a, global, economy, without]
# Now we will bring it to completion: U.S. leadership of a global economy without limits to growth.
# [[a, global, economy, without]]

# %% [markdown]
# # Democrat Energy 2000

# %%
term_dictionary = []

text = read_file('C:/Users/Place Holder/Downloads/Democrat/61320_200011.txt')

term_dictionary.append("energy")

num_docs = len(text)

contexts = []

analyzed = nlp(text)

lemmas = [token.lemma_.lower() for token in analyzed]
intersect = set(lemmas).intersection(set(term_dictionary))
if len(intersect) > 0:
    context_sentences = [token.sent.as_doc() for token in analyzed if token.lemma_.lower() in term_dictionary ]
    contexts.extend(context_sentences)
        #print(context_sentences)

# %%
patterns = []

def pattern_creator(context):
    print("create pattern")
    pattern = [(token.pos_, token.lemma_.lower()) for token in context]
    print(pattern)

for sentence in contexts:
    for token in sentence:
        if token.lemma_.lower() in term_dictionary:
            #print(token.text, token.i, " - ", token.pos_)
            start_token = token.i - 3
            end_token = token.i + 3
            context = sentence[start_token:end_token]
            print(" -> ", context)
            try:
                new_pattern = pattern_creator(context.as_doc())
            except Exception as e:
                print(e)
            print("*" * 25)
# Out:
#  ->  best ideas and energies of the
# create pattern
# [('ADJ', 'good'), ('NOUN', 'idea'), ('CCONJ', 'and'), ('NOUN', 'energy'), ('ADP', 'of'), ('DET', 'the')]
# *************************
#  ->  living in more energy-efficient
# create pattern
# [('VERB', 'live'), ('ADP', 'in'), ('ADJ', 'more'), ('NOUN', 'energy'), ('PUNCT', '-'), ('ADJ', 'efficient')]
# *************************
#  ->  changes in the energy sector promote
# create pattern
# [('NOUN', 'change'), ('ADP', 'in'), ('DET', 'the'), ('NOUN', 'energy'), ('NOUN', 'sector'), ('VERB', 'promote')]
# *************************
#  ->  deployment of clean energy technologies,
# create pattern
# [('NOUN', 'deployment'), ('ADP', 'of'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'technology'), ('PUNCT', ',')]
# *************************
#  ->  make all our energy sources cleaner
# create pattern
# [('VERB', 'make'), ('DET', 'all'), ('DET', '-pron-'), ('NOUN', 'energy'), ('NOUN', 'source'), ('ADV', 'cleaner')]
# *************************
#  ->  deployment of clean energy technologies,
# create pattern
# [('NOUN', 'deployment'), ('ADP', 'of'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'technology'), ('PUNCT', ',')]
# *************************
#  ->  make all our energy sources cleaner
# create pattern
# [('VERB', 'make'), ('DET', 'all'), ('DET', '-pron-'), ('NOUN', 'energy'), ('NOUN', 'source'), ('ADV', 'cleaner')]
# *************************
#  ->  the Tactical High Energy Laser.
# create pattern
# [('DET', 'the'), ('PROPN', 'tactical'), ('PROPN', 'high'), ('PROPN', 'energy'), ('PROPN', 'laser'), ('PUNCT', '.')]
# *************************

# %%
patterns = [
      
[('NOUN'),('ADP','of'), ('ADJ',"***"),('NOUN','energy')],
      [('NOUN'), ('ADP', "****"), ('PART', 'energy'), ('NOUN','health')],
      [('VERB'), ('DET', "****"), ('DET', "****"), ('NOUN','energy')]   
]

print (patterns)
# Out:
# [['NOUN', ('ADP', 'of'), ('ADJ', '***'), ('NOUN', 'energy')], ['NOUN', ('ADP', '****'), ('PART', 'energy'), ('NOUN', 'health')], ['VERB', ('DET', '****'), ('DET', '****'), ('NOUN', 'energy')]]

# %%
new_contexts = []

analyzed = nlp(text)
lemmas = [token.lemma_.lower() for token in analyzed]
intersect = set(lemmas).intersection(set(term_dictionary))
if len(intersect) > 0:
    for pattern in patterns:
        in_machine = 0
        pattern_pos = 0
        pattern_find = []
        finds = []
        for token in analyzed:
            if in_machine == 0 and token.pos_ == pattern[pattern_pos] :
                in_machine = 1
                pattern_pos += 1
                pattern_find.append(token)
            elif in_machine == 1:
                if pattern_pos == len(pattern):
                    print("FOUND MATCH")
                    print(pattern_find)
                    print(pattern_find[0].sent)
                    finds.append(pattern_find)
                    in_machine = 0
                    pattern_pos = 0
                    pattern_find = []
                if pattern[pattern_pos][1] == "***":
                    if token.pos_ == pattern[pattern_pos][0]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
                elif pattern[pattern_pos][0] != "NOUN":
                    if token.pos_ == pattern[pattern_pos][0]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
                else:
                    if token.pos_ == pattern[pattern_pos][0] and token.lemma_ == pattern[pattern_pos][1]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
        
        
                    
        if len(finds) > 0:
            print(finds)
# Out:
# FOUND MATCH
# [deployment, of, clean, energy]
# Democrats believe that with the right incentives to encourage the development and deployment of clean energy technologies, we can make all our energy sources cleaner, safer, and healthier for our children.
# [[deployment, of, clean, energy]]

# %% [markdown]
# # Democrat Health 2008

# %%
term_dictionary = []

text = read_file('C:/Users/Place Holder/Downloads/Democrat/61320_200811.txt')


term_dictionary.append("health")

num_docs = len(text)

contexts = []

analyzed = nlp(text)

lemmas = [token.lemma_.lower() for token in analyzed]
intersect = set(lemmas).intersection(set(term_dictionary))
if len(intersect) > 0:
    context_sentences = [token.sent.as_doc() for token in analyzed if token.lemma_.lower() in term_dictionary ]
    contexts.extend(context_sentences)
        #print(context_sentences)

# %%
patterns = []

def pattern_creator(context):
    print("create pattern")
    pattern = [(token.pos_, token.lemma_.lower()) for token in context]
    print(pattern)

for sentence in contexts:
    for token in sentence:
        if token.lemma_.lower() in term_dictionary:
            #print(token.text, token.i, " - ", token.pos_)
            start_token = token.i - 3
            end_token = token.i + 3
            context = sentence[start_token:end_token]
            print(" -> ", context)
            try:
                new_pattern = pattern_creator(context.as_doc())
            except Exception as e:
                print(e)
            print("*" * 25)
# Out:
#  ->  quality and affordable health care is
# create pattern
# [('NOUN', 'quality'), ('CCONJ', 'and'), ('ADJ', 'affordable'), ('NOUN', 'health'), ('NOUN', 'care'), ('VERB', 'be')]
# *************************
#  ->  citizens have no health insurance while
# create pattern
# [('NOUN', 'citizen'), ('VERB', 'have'), ('DET', 'no'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('ADP', 'while')]
# *************************
#  ->  , and denied health insurance to
# create pattern
# [('PUNCT', ','), ('CCONJ', 'and'), ('VERB', 'deny'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('ADP', 'to')]
# *************************
#  ->  unaffordable, unavailable health care,
# create pattern
# [('ADJ', 'unaffordable'), ('PUNCT', ','), ('ADJ', 'unavailable'), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', ',')]
# *************************
#  ->
# division by zero
# *************************
#  ->  same time, health costs have
# create pattern
# [('ADJ', 'same'), ('NOUN', 'time'), ('PUNCT', ','), ('NOUN', 'health'), ('NOUN', 'cost'), ('VERB', 'have')]
# *************************
#  ->  companies have shed health insurance coverage
# create pattern
# [('NOUN', 'company'), ('VERB', 'have'), ('VERB', 'shed'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('NOUN', 'coverage')]
# *************************
#  ->  same time, health costs have
# create pattern
# [('ADJ', 'same'), ('NOUN', 'time'), ('PUNCT', ','), ('NOUN', 'health'), ('NOUN', 'cost'), ('VERB', 'have')]
# *************************
#  ->  companies have shed health insurance coverage
# create pattern
# [('NOUN', 'company'), ('VERB', 'have'), ('VERB', 'shed'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('NOUN', 'coverage')]
# *************************
#  ->  of Americans without health insurance and
# create pattern
# [('ADP', 'of'), ('PROPN', 'americans'), ('ADP', 'without'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('CCONJ', 'and')]
# *************************
#  ->  new economy with health care,
# create pattern
# [('ADJ', 'new'), ('NOUN', 'economy'), ('ADP', 'with'), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', ',')]
# *************************
#  ->  like education, health care,
# create pattern
# [('ADP', 'like'), ('NOUN', 'education'), ('PUNCT', ','), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', ',')]
# *************************
#  ->  rising cost of health care,
# create pattern
# [('VERB', 'rise'), ('NOUN', 'cost'), ('ADP', 'of'), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', ',')]
# *************************
#  ->  a family, health insurance,
# create pattern
# [('DET', 'a'), ('NOUN', 'family'), ('PUNCT', ','), ('NOUN', 'health'), ('NOUN', 'insurance'), ('PUNCT', ',')]
# *************************
#  ->
# division by zero
# *************************
#  ->  Affordable, Quality Health Care Coverage
# create pattern
# [('ADJ', 'affordable'), ('PUNCT', ','), ('PROPN', 'quality'), ('PROPN', 'health'), ('PROPN', 'care'), ('NOUN', 'coverage')]
# *************************
#  ->  outrage with a health care crisis
# create pattern
# [('NOUN', 'outrage'), ('ADP', 'with'), ('DET', 'a'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'crisis')]
# *************************
#  ->  children–without health insurance and
# create pattern
# [('NOUN', 'child'), ('PUNCT', '–'), ('ADP', 'without'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('CCONJ', 'and')]
# *************************
#  ->  outrage with a health care crisis
# create pattern
# [('NOUN', 'outrage'), ('ADP', 'with'), ('DET', 'a'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'crisis')]
# *************************
#  ->  children–without health insurance and
# create pattern
# [('NOUN', 'child'), ('PUNCT', '–'), ('ADP', 'without'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('CCONJ', 'and')]
# *************************
#  ->  spend more on health care than
# create pattern
# [('VERB', 'spend'), ('ADJ', 'more'), ('ADP', 'on'), ('NOUN', 'health'), ('NOUN', 'care'), ('ADP', 'than')]
# *************************
#  ->  cents of every health care
# create pattern
# [('NOUN', 'cent'), ('ADP', 'of'), ('DET', 'every'), ('NOUN', 'health'), ('NOUN', 'care'), ('SPACE', ' ')]
# *************************
#  ->  prevention and public health.
# create pattern
# [('NOUN', 'prevention'), ('CCONJ', 'and'), ('ADJ', 'public'), ('NOUN', 'health'), ('PUNCT', '.')]
# *************************
#  ->  cents of every health care
# create pattern
# [('NOUN', 'cent'), ('ADP', 'of'), ('DET', 'every'), ('NOUN', 'health'), ('NOUN', 'care'), ('SPACE', ' ')]
# *************************
#  ->  prevention and public health.
# create pattern
# [('NOUN', 'prevention'), ('CCONJ', 'and'), ('ADJ', 'public'), ('NOUN', 'health'), ('PUNCT', '.')]
# *************************
#  ->  understand that good health is the
# create pattern
# [('VERB', 'understand'), ('ADP', 'that'), ('ADJ', 'good'), ('NOUN', 'health'), ('VERB', 'be'), ('DET', 'the')]
# *************************
#  ->  quality, affordable health care for
# create pattern
# [('NOUN', 'quality'), ('PUNCT', ','), ('ADJ', 'affordable'), ('NOUN', 'health'), ('NOUN', 'care'), ('ADP', 'for')]
# *************************
#  ->  to making our health system workable
# create pattern
# [('ADP', 'to'), ('VERB', 'make'), ('DET', '-pron-'), ('NOUN', 'health'), ('NOUN', 'system'), ('ADJ', 'workable')]
# *************************
#  ->  , help eliminate health care disparities
# create pattern
# [('PUNCT', ','), ('VERB', 'help'), ('VERB', 'eliminate'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'disparity')]
# *************************
#  ->  strengthened and improved health care system
# create pattern
# [('VERB', 'strengthen'), ('CCONJ', 'and'), ('ADJ', 'improved'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'system')]
# *************************
#  ->  Choices of Affordable Health Insurance Options
# create pattern
# [('PROPN', 'choices'), ('ADP', 'of'), ('PROPN', 'affordable'), ('PROPN', 'health'), ('PROPN', 'insurance'), ('PROPN', 'options')]
# *************************
#  ->  strengthened and improved health care system
# create pattern
# [('VERB', 'strengthen'), ('CCONJ', 'and'), ('ADJ', 'improved'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'system')]
# *************************
#  ->  Choices of Affordable Health Insurance Options
# create pattern
# [('PROPN', 'choices'), ('ADP', 'of'), ('PROPN', 'affordable'), ('PROPN', 'health'), ('PROPN', 'insurance'), ('PROPN', 'options')]
# *************************
#  ->  wide array of health insurance plans
# create pattern
# [('ADJ', 'wide'), ('NOUN', 'array'), ('ADP', 'of'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('NOUN', 'plan')]
# *************************
#  ->  including many private health insurance options
# create pattern
# [('VERB', 'include'), ('ADJ', 'many'), ('ADJ', 'private'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('NOUN', 'option')]
# *************************
#  ->  wide array of health insurance plans
# create pattern
# [('ADJ', 'wide'), ('NOUN', 'array'), ('ADP', 'of'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('NOUN', 'plan')]
# *************************
#  ->  including many private health insurance options
# create pattern
# [('VERB', 'include'), ('ADJ', 'many'), ('ADJ', 'private'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('NOUN', 'option')]
# *************************
#  ->
# division by zero
# *************************
#  ->  should ensure that health insurance is
# create pattern
# [('VERB', 'should'), ('VERB', 'ensure'), ('ADP', 'that'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('VERB', 'be')]
# *************************
#  ->  individuals should purchase health insurance and
# create pattern
# [('NOUN', 'individual'), ('VERB', 'should'), ('VERB', 'purchase'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('CCONJ', 'and')]
# *************************
#  ->
# division by zero
# *************************
#  ->  cost of providing health care and
# create pattern
# [('NOUN', 'cost'), ('ADP', 'of'), ('VERB', 'provide'), ('NOUN', 'health'), ('NOUN', 'care'), ('CCONJ', 'and')]
# *************************
#  ->  worry about losing health coverage if
# create pattern
# [('VERB', 'worry'), ('ADP', 'about'), ('VERB', 'lose'), ('NOUN', 'health'), ('NOUN', 'coverage'), ('ADP', 'if')]
# *************************
#  ->  Families should have health insurance coverage
# create pattern
# [('NOUN', 'family'), ('VERB', 'should'), ('VERB', 'have'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('NOUN', 'coverage')]
# *************************
#  ->  -overdue mental health and addiction
# create pattern
# [('PUNCT', '-'), ('ADJ', 'overdue'), ('ADJ', 'mental'), ('NOUN', 'health'), ('CCONJ', 'and'), ('NOUN', 'addiction')]
# *************************
#  ->  nation’s overall health care spending
# create pattern
# [('NOUN', 'nation'), ('PROPN', '’s'), ('ADJ', 'overall'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'spending')]
# *************************
#  ->  management especially with health promotion programs
# create pattern
# [('NOUN', 'management'), ('ADV', 'especially'), ('ADP', 'with'), ('NOUN', 'health'), ('NOUN', 'promotion'), ('NOUN', 'program')]
# *************************
#  ->  care and behavioral health management should
# create pattern
# [('NOUN', 'care'), ('CCONJ', 'and'), ('ADJ', 'behavioral'), ('NOUN', 'health'), ('NOUN', 'management'), ('VERB', 'should')]
# *************************
#  ->  those with mental health and substance
# create pattern
# [('DET', 'those'), ('ADP', 'with'), ('ADJ', 'mental'), ('NOUN', 'health'), ('CCONJ', 'and'), ('NOUN', 'substance')]
# *************************
#  ->  struggle with increasing health care costs
# create pattern
# [('VERB', 'struggle'), ('ADP', 'with'), ('VERB', 'increase'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'cost')]
# *************************
#  ->  waste from our health system,
# create pattern
# [('NOUN', 'waste'), ('ADP', 'from'), ('DET', '-pron-'), ('NOUN', 'health'), ('NOUN', 'system'), ('PUNCT', ',')]
# *************************
#  ->  the-art health information technology
# create pattern
# [('DET', 'the'), ('PUNCT', '-'), ('NOUN', 'art'), ('NOUN', 'health'), ('NOUN', 'information'), ('NOUN', 'technology')]
# *************************
#  ->
# division by zero
# *************************
#  ->  of Disparities in Health Care.
# create pattern
# [('ADP', 'of'), ('PROPN', 'disparities'), ('ADP', 'in'), ('PROPN', 'health'), ('PROPN', 'care'), ('PUNCT', '.')]
# *************************
#  ->  We must end health care disparities
# create pattern
# [('PRON', '-pron-'), ('VERB', 'must'), ('VERB', 'end'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'disparity')]
# *************************
#  ->  community-based health centers.
# create pattern
# [('NOUN', 'community'), ('PUNCT', '-'), ('VERB', 'base'), ('NOUN', 'health'), ('NOUN', 'center'), ('PUNCT', '.')]
# *************************
#  ->  We must end health care disparities
# create pattern
# [('PRON', '-pron-'), ('VERB', 'must'), ('VERB', 'end'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'disparity')]
# *************************
#  ->  community-based health centers.
# create pattern
# [('NOUN', 'community'), ('PUNCT', '-'), ('VERB', 'base'), ('NOUN', 'health'), ('NOUN', 'center'), ('PUNCT', '.')]
# *************************
#  ->  will make our health care system
# create pattern
# [('VERB', 'will'), ('VERB', 'make'), ('DET', '-pron-'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'system')]
# *************************
#  ->  that diversify the health are workforce
# create pattern
# [('DET', 'that'), ('VERB', 'diversify'), ('DET', 'the'), ('NOUN', 'health'), ('VERB', 'be'), ('VERB', 'workforce')]
# *************************
#  ->  determinants that fuel health disparities,
# create pattern
# [('NOUN', 'determinant'), ('DET', 'that'), ('NOUN', 'fuel'), ('NOUN', 'health'), ('NOUN', 'disparity'), ('PUNCT', ',')]
# *************************
#  ->  by the Indian Health Service.
# create pattern
# [('ADP', 'by'), ('DET', 'the'), ('PROPN', 'indian'), ('PROPN', 'health'), ('PROPN', 'service'), ('PUNCT', '.')]
# *************************
#  ->  Research
# create pattern
# [('PROPN', 'research')]
# *************************
#  ->
# division by zero
# *************************
#  ->  medical and public health workforce and
# create pattern
# [('ADJ', 'medical'), ('CCONJ', 'and'), ('ADJ', 'public'), ('NOUN', 'health'), ('NOUN', 'workforce'), ('CCONJ', 'and')]
# *************************
#  ->
# division by zero
# *************************
#  ->  medical and public health workforce and
# create pattern
# [('ADJ', 'medical'), ('CCONJ', 'and'), ('ADJ', 'public'), ('NOUN', 'health'), ('NOUN', 'workforce'), ('CCONJ', 'and')]
# *************************
#  ->
# division by zero
# *************************
#  ->  cost-effective health care.
# create pattern
# [('NOUN', 'cost'), ('PUNCT', '-'), ('ADJ', 'effective'), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', '.')]
# *************************
#  ->
# division by zero
# *************************
#  ->  cost-effective health care.
# create pattern
# [('NOUN', 'cost'), ('PUNCT', '-'), ('ADJ', 'effective'), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', '.')]
# *************************
#  ->  National Institutes of Health, the
# create pattern
# [('PROPN', 'national'), ('PROPN', 'institutes'), ('ADP', 'of'), ('PROPN', 'health'), ('PUNCT', ','), ('DET', 'the')]
# *************************
#  ->  considerable progress in health care delivery
# create pattern
# [('ADJ', 'considerable'), ('NOUN', 'progress'), ('ADP', 'in'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'delivery')]
# *************************
#  ->
# division by zero
# *************************
#  ->  , and public health infrastructure to
# create pattern
# [('PUNCT', ','), ('CCONJ', 'and'), ('ADJ', 'public'), ('NOUN', 'health'), ('NOUN', 'infrastructure'), ('PART', 'to')]
# *************************
#  ->
# division by zero
# *************************
#  ->  , and public health infrastructure to
# create pattern
# [('PUNCT', ','), ('CCONJ', 'and'), ('ADJ', 'public'), ('NOUN', 'health'), ('NOUN', 'infrastructure'), ('PART', 'to')]
# *************************
#  ->  Care.
# create pattern
# [('PROPN', 'care'), ('PUNCT', '.')]
# *************************
#  ->  and obtain reproductive health care,
# create pattern
# [('CCONJ', 'and'), ('VERB', 'obtain'), ('ADJ', 'reproductive'), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', ',')]
# *************************
#  ->  We will end health insurance discrimination
# create pattern
# [('PRON', '-pron-'), ('VERB', 'will'), ('VERB', 'end'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('NOUN', 'discrimination')]
# *************************
#  ->  above women’s health Fiscal Responsibility
# create pattern
# [('ADP', 'above'), ('NOUN', 'woman'), ('PROPN', '’s'), ('NOUN', 'health'), ('PROPN', 'fiscal'), ('PROPN', 'responsibility')]
# *************************
#  ->  and strengthen our health care system
# create pattern
# [('CCONJ', 'and'), ('VERB', 'strengthen'), ('DET', '-pron-'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'system')]
# *************************
#  ->  worry about high health care and
# create pattern
# [('VERB', 'worry'), ('ADP', 'about'), ('ADJ', 'high'), ('NOUN', 'health'), ('NOUN', 'care'), ('CCONJ', 'and')]
# *************************
#  ->  Occupational Safety and Health Administration will
# create pattern
# [('PROPN', 'occupational'), ('PROPN', 'safety'), ('CCONJ', 'and'), ('PROPN', 'health'), ('PROPN', 'administration'), ('VERB', 'will')]
# *************************
#  ->  American has affordable health care that
# create pattern
# [('PROPN', 'american'), ('VERB', 'have'), ('ADJ', 'affordable'), ('NOUN', 'health'), ('NOUN', 'care'), ('DET', 'that')]
# *************************
#  ->  physical and mental health outcomes for
# create pattern
# [('ADJ', 'physical'), ('CCONJ', 'and'), ('ADJ', 'mental'), ('NOUN', 'health'), ('NOUN', 'outcome'), ('ADP', 'for')]
# *************************
#  ->  and to the health of our
# create pattern
# [('CCONJ', 'and'), ('ADP', 'to'), ('DET', 'the'), ('NOUN', 'health'), ('ADP', 'of'), ('DET', '-pron-')]
# *************************
#  ->  energy technologies and health IT and
# create pattern
# [('NOUN', 'energy'), ('NOUN', 'technology'), ('CCONJ', 'and'), ('NOUN', 'health'), ('NOUN', 'it'), ('CCONJ', 'and')]
# *************************
#  ->  economic leadership, health well-
# create pattern
# [('ADJ', 'economic'), ('NOUN', 'leadership'), ('PUNCT', ','), ('NOUN', 'health'), ('ADV', 'well'), ('PUNCT', '-')]
# *************************
#  ->  net, with health care,
# create pattern
# [('NOUN', 'net'), ('PUNCT', ','), ('ADP', 'with'), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', ',')]
# *************************
#  ->  , energy, health care,
# create pattern
# [('PUNCT', ','), ('NOUN', 'energy'), ('PUNCT', ','), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', ',')]
# *************************
#  ->  tax credit for health insurance.
# create pattern
# [('NOUN', 'tax'), ('NOUN', 'credit'), ('ADP', 'for'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('PUNCT', '.')]
# *************************
#  ->  that offer quality health insurance to
# create pattern
# [('DET', 'that'), ('VERB', 'offer'), ('NOUN', 'quality'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('ADP', 'to')]
# *************************
#  ->  to invest in health care and
# create pattern
# [('PART', 'to'), ('VERB', 'invest'), ('ADP', 'in'), ('NOUN', 'health'), ('NOUN', 'care'), ('CCONJ', 'and')]
# *************************
#  ->  , or the health of its
# create pattern
# [('PUNCT', ','), ('CCONJ', 'or'), ('DET', 'the'), ('NOUN', 'health'), ('ADP', 'of'), ('DET', '-pron-')]
# *************************
#  ->  access to affordable health insurance and
# create pattern
# [('NOUN', 'access'), ('ADP', 'to'), ('ADJ', 'affordable'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('CCONJ', 'and')]
# *************************
#  ->  improve TAA’s health care benefits
# create pattern
# [('VERB', 'improve'), ('PROPN', 'taa'), ('PROPN', '’s'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'benefit')]
# *************************
#  ->  access to affordable health insurance and
# create pattern
# [('NOUN', 'access'), ('ADP', 'to'), ('ADJ', 'affordable'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('CCONJ', 'and')]
# *************************
#  ->  improve TAA’s health care benefits
# create pattern
# [('VERB', 'improve'), ('PROPN', 'taa'), ('PROPN', '’s'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'benefit')]
# *************************
#  ->  rising spending on health care,
# create pattern
# [('VERB', 'rise'), ('NOUN', 'spending'), ('ADP', 'on'), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', ',')]
# *************************
#  ->  the cost of health care and
# create pattern
# [('DET', 'the'), ('NOUN', 'cost'), ('ADP', 'of'), ('NOUN', 'health'), ('NOUN', 'care'), ('CCONJ', 'and')]
# *************************
#  ->  supplies; and health care,
# create pattern
# [('NOUN', 'supply'), ('PUNCT', ';'), ('CCONJ', 'and'), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', ',')]
# *************************
#  ->  access to quality health care for
# create pattern
# [('NOUN', 'access'), ('ADP', 'to'), ('NOUN', 'quality'), ('NOUN', 'health'), ('NOUN', 'care'), ('ADP', 'for')]
# *************************
#  ->  will require that health professionals screen
# create pattern
# [('VERB', 'will'), ('VERB', 'require'), ('ADP', 'that'), ('NOUN', 'health'), ('NOUN', 'professional'), ('VERB', 'screen')]
# *************************
#  ->  access to quality health care for
# create pattern
# [('NOUN', 'access'), ('ADP', 'to'), ('NOUN', 'quality'), ('NOUN', 'health'), ('NOUN', 'care'), ('ADP', 'for')]
# *************************
#  ->  will require that health professionals screen
# create pattern
# [('VERB', 'will'), ('VERB', 'require'), ('ADP', 'that'), ('NOUN', 'health'), ('NOUN', 'professional'), ('VERB', 'screen')]
# *************************
#  ->  to employment, health, education
# create pattern
# [('ADP', 'to'), ('NOUN', 'employment'), ('PUNCT', ','), ('NOUN', 'health'), ('PUNCT', ','), ('NOUN', 'education')]
# *************************
#  ->  , and build health-care
# create pattern
# [('PUNCT', ','), ('CCONJ', 'and'), ('VERB', 'build'), ('NOUN', 'health'), ('PUNCT', '-'), ('NOUN', 'care')]
# *************************
#  ->  child and maternal health, and
# create pattern
# [('NOUN', 'child'), ('CCONJ', 'and'), ('ADJ', 'maternal'), ('NOUN', 'health'), ('PUNCT', ','), ('CCONJ', 'and')]
# *************************
#  ->
# division by zero
# *************************
#  ->  in improving global health.
# create pattern
# [('ADP', 'in'), ('VERB', 'improve'), ('ADJ', 'global'), ('NOUN', 'health'), ('PUNCT', '.')]
# *************************
#  ->
# division by zero
# *************************
#  ->  in improving global health.
# create pattern
# [('ADP', 'in'), ('VERB', 'improve'), ('ADJ', 'global'), ('NOUN', 'health'), ('PUNCT', '.')]
# *************************
#  ->  expand access to health care and
# create pattern
# [('VERB', 'expand'), ('NOUN', 'access'), ('ADP', 'to'), ('NOUN', 'health'), ('NOUN', 'care'), ('CCONJ', 'and')]
# *************************
#  ->  philanthropy to launch Health Infrastructure 2020–a
# create pattern
# [('NOUN', 'philanthropy'), ('PART', 'to'), ('VERB', 'launch'), ('PROPN', 'health'), ('PROPN', 'infrastructure'), ('NUM', '2020–a')]
# *************************
#  ->  American and global health.
# create pattern
# [('ADJ', 'american'), ('CCONJ', 'and'), ('ADJ', 'global'), ('NOUN', 'health'), ('PUNCT', '.')]
# *************************
#  ->  philanthropy to launch Health Infrastructure 2020–a
# create pattern
# [('NOUN', 'philanthropy'), ('PART', 'to'), ('VERB', 'launch'), ('PROPN', 'health'), ('PROPN', 'infrastructure'), ('NUM', '2020–a')]
# *************************
#  ->  American and global health.
# create pattern
# [('ADJ', 'american'), ('CCONJ', 'and'), ('ADJ', 'global'), ('NOUN', 'health'), ('PUNCT', '.')]
# *************************
#  ->  every child has health insurance,
# create pattern
# [('DET', 'every'), ('NOUN', 'child'), ('VERB', 'have'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('PUNCT', ',')]
# *************************
#  ->
# division by zero
# *************************
#  ->  improves children’s health, so
# create pattern
# [('VERB', 'improve'), ('NOUN', 'child'), ('PROPN', '’s'), ('NOUN', 'health'), ('PUNCT', ','), ('ADV', 'so')]
# *************************
#  ->
# division by zero
# *************************
#  ->  improves children’s health, so
# create pattern
# [('VERB', 'improve'), ('NOUN', 'child'), ('PROPN', '’s'), ('NOUN', 'health'), ('PUNCT', ','), ('ADV', 'so')]
# *************************
#  ->  affordable and quality health insurance.
# create pattern
# [('ADJ', 'affordable'), ('CCONJ', 'and'), ('NOUN', 'quality'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('PUNCT', '.')]
# *************************
#  ->  more nurses and health care workers
# create pattern
# [('ADJ', 'more'), ('NOUN', 'nurse'), ('CCONJ', 'and'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'worker')]
# *************************
#  ->  recognize that such health care and
# create pattern
# [('VERB', 'recognize'), ('ADP', 'that'), ('ADJ', 'such'), ('NOUN', 'health'), ('NOUN', 'care'), ('CCONJ', 'and')]
# *************************
#  ->  post-natal health care,
# create pattern
# [('ADJ', 'post'), ('ADJ', '-'), ('ADJ', 'natal'), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', ',')]
# *************************
#  ->  , housing, health, contracts
# create pattern
# [('PUNCT', ','), ('NOUN', 'housing'), ('PUNCT', ','), ('NOUN', 'health'), ('PUNCT', ','), ('NOUN', 'contract')]
# *************************
#  ->  poverty, filling health care gaps
# create pattern
# [('NOUN', 'poverty'), ('PUNCT', ','), ('VERB', 'fill'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'gap')]
# *************************
#  ->  economic development, health care,
# create pattern
# [('ADJ', 'economic'), ('NOUN', 'development'), ('PUNCT', ','), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', ',')]
# *************************
#  ->  , education, health, and
# create pattern
# [('PUNCT', ','), ('NOUN', 'education'), ('PUNCT', ','), ('NOUN', 'health'), ('PUNCT', ','), ('CCONJ', 'and')]
# *************************
#  ->  in other federal health care assistance
# create pattern
# [('ADP', 'in'), ('ADJ', 'other'), ('ADJ', 'federal'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'assistance')]
# *************************
#  ->  acknowledge the unique health care challenges
# create pattern
# [('VERB', 'acknowledge'), ('DET', 'the'), ('ADJ', 'unique'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'challenge')]
# *************************

# %%
patterns = [
      [('ADP'),('NOUN', 'health'), ('NOUN','insurance'),('NOUN',"***")],
      [('ADP'), ('NOUN', 'health'), ('NOUN', 'care'), ('CCONJ', 'and')]
]
print(patterns)
# Out:
# [['ADP', ('NOUN', 'health'), ('NOUN', 'insurance'), ('NOUN', '***')], ['ADP', ('NOUN', 'health'), ('NOUN', 'care'), ('CCONJ', 'and')]]

# %%
new_contexts = []

analyzed = nlp(text)
lemmas = [token.lemma_.lower() for token in analyzed]
intersect = set(lemmas).intersection(set(term_dictionary))
if len(intersect) > 0:
    for pattern in patterns:
        in_machine = 0
        pattern_pos = 0
        pattern_find = []
        finds = []
        for token in analyzed:
            if in_machine == 0 and token.pos_ == pattern[pattern_pos] :
                in_machine = 1
                pattern_pos += 1
                pattern_find.append(token)
            elif in_machine == 1:
                if pattern_pos == len(pattern):
                    print("FOUND MATCH")
                    print(pattern_find)
                    print(pattern_find[0].sent)
                    finds.append(pattern_find)
                    in_machine = 0
                    pattern_pos = 0
                    pattern_find = []
                if pattern[pattern_pos][1] == "***":
                    if token.pos_ == pattern[pattern_pos][0]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
                elif pattern[pattern_pos][0] != "NOUN":
                    if token.pos_ == pattern[pattern_pos][0]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
                else:
                    if token.pos_ == pattern[pattern_pos][0] and token.lemma_ == pattern[pattern_pos][1]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
        
        
                    
        if len(finds) > 0:
            print(finds)
# Out:
# FOUND MATCH
# [of, health, insurance, plans]
# Families and individuals should have the option of keeping the coverage they have or choosing from a wide array of health insurance plans, including many private health insurance options and a public plan.
# [[of, health, insurance, plans]]
# FOUND MATCH
# [in, health, care, and]
# For families making more than $250,000, we’ll ask them to give back a portion of the Bush tax cuts to invest in health care and other key priorities.
# FOUND MATCH
# [of, health, care, and]
# Instead, we must strengthen our public programs by bringing down the cost of health care and reducing waste while making strategic investments that emphasize quality, efficiency, and prevention.
# FOUND MATCH
# [to, health, care, and]
# We will expand access to health care and nutrition for women and reduce the burden of maternal mortality.
# [[in, health, care, and], [of, health, care, and], [to, health, care, and]]

# %% [markdown]
# # Republican Health 2008

# %%
term_dictionary = []

text = read_file('C:/Users/Place Holder/Downloads/Republican/61620_200811.txt')

term_dictionary.append("health")

num_docs = len(text)

contexts = []

analyzed = nlp(text)

lemmas = [token.lemma_.lower() for token in analyzed]
intersect = set(lemmas).intersection(set(term_dictionary))
if len(intersect) > 0:
    context_sentences = [token.sent.as_doc() for token in analyzed if token.lemma_.lower() in term_dictionary ]
    contexts.extend(context_sentences)
        #print(context_sentences)

# %%
patterns = []

def pattern_creator(context):
    print("create pattern")
    pattern = [(token.pos_, token.lemma_.lower()) for token in context]
    print(pattern)

for sentence in contexts:
    for token in sentence:
        if token.lemma_.lower() in term_dictionary:
            #print(token.text, token.i, " - ", token.pos_)
            start_token = token.i - 3
            end_token = token.i + 3
            context = sentence[start_token:end_token]
            print(" -> ", context)
            try:
                new_pattern = pattern_creator(context.as_doc())
            except Exception as e:
                print(e)
            print("*" * 25)
# Out:
#  ->  our nation's health and safety
# create pattern
# [('DET', '-pron-'), ('NOUN', 'nation'), ('PART', "'s"), ('NOUN', 'health'), ('CCONJ', 'and'), ('NOUN', 'safety')]
# *************************
#  ->  , wreck our health care delivery
# create pattern
# [('PUNCT', ','), ('VERB', 'wreck'), ('DET', '-pron-'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'delivery')]
# *************************
#  ->  the pay, health care,
# create pattern
# [('DET', 'the'), ('NOUN', 'pay'), ('PUNCT', ','), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', ',')]
# *************************
#  ->
# division by zero
# *************************
#  ->  to the special health care needs
# create pattern
# [('ADP', 'to'), ('DET', 'the'), ('ADJ', 'special'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'need')]
# *************************
#  ->  for more mental health professionals who
# create pattern
# [('ADP', 'for'), ('ADJ', 'more'), ('ADJ', 'mental'), ('NOUN', 'health'), ('NOUN', 'professional'), ('PRON', 'who')]
# *************************
#  ->  Maternal and child health, especially
# create pattern
# [('ADJ', 'maternal'), ('CCONJ', 'and'), ('NOUN', 'child'), ('NOUN', 'health'), ('PUNCT', ','), ('ADV', 'especially')]
# *************************
#  ->  in the World Health Organization and
# create pattern
# [('ADP', 'in'), ('DET', 'the'), ('PROPN', 'world'), ('PROPN', 'health'), ('PROPN', 'organization'), ('CCONJ', 'and')]
# *************************
#  ->  future pension and health care costs
# create pattern
# [('ADJ', 'future'), ('NOUN', 'pension'), ('CCONJ', 'and'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'cost')]
# *************************
#  ->  of pension and health care programs
# create pattern
# [('ADP', 'of'), ('NOUN', 'pension'), ('CCONJ', 'and'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'program')]
# *************************
#  ->  discussed in the health care section
# create pattern
# [('VERB', 'discuss'), ('ADP', 'in'), ('DET', 'the'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'section')]
# *************************
#  ->  , improving public health through flexibility
# create pattern
# [('PUNCT', ','), ('VERB', 'improve'), ('ADJ', 'public'), ('NOUN', 'health'), ('ADP', 'through'), ('NOUN', 'flexibility')]
# *************************
#  ->  , a strong health care system
# create pattern
# [('PUNCT', ','), ('DET', 'a'), ('ADJ', 'strong'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'system')]
# *************************
#  ->  in accessibility of health care,
# create pattern
# [('ADP', 'in'), ('NOUN', 'accessibility'), ('ADP', 'of'), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', ',')]
# *************************
#  ->  tax credits for health care and
# create pattern
# [('NOUN', 'tax'), ('NOUN', 'credit'), ('ADP', 'for'), ('NOUN', 'health'), ('NOUN', 'care'), ('CCONJ', 'and')]
# *************************
#  ->
# division by zero
# *************************
#  ->  business owners secure health insurance for
# create pattern
# [('NOUN', 'business'), ('NOUN', 'owner'), ('VERB', 'secure'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('ADP', 'for')]
# *************************
#  ->
# division by zero
# *************************
#  ->  business owners secure health insurance for
# create pattern
# [('NOUN', 'business'), ('NOUN', 'owner'), ('VERB', 'secure'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('ADP', 'for')]
# *************************
#  ->  return control of health care to
# create pattern
# [('VERB', 'return'), ('NOUN', 'control'), ('ADP', 'of'), ('NOUN', 'health'), ('NOUN', 'care'), ('ADP', 'to')]
# *************************
#  ->  in everything from health care to
# create pattern
# [('ADP', 'in'), ('NOUN', 'everything'), ('ADP', 'from'), ('NOUN', 'health'), ('NOUN', 'care'), ('PART', 'to')]
# *************************
#  ->  education, to health care,
# create pattern
# [('NOUN', 'education'), ('PUNCT', ','), ('ADP', 'to'), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', ',')]
# *************************
#  ->  plans and their health insurance,
# create pattern
# [('NOUN', 'plan'), ('CCONJ', 'and'), ('DET', '-pron-'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('PUNCT', ',')]
# *************************
#  ->  to undermine federal health and safety
# create pattern
# [('PART', 'to'), ('VERB', 'undermine'), ('ADJ', 'federal'), ('NOUN', 'health'), ('CCONJ', 'and'), ('NOUN', 'safety')]
# *************************
#  ->  have covered employee health insurance.
# create pattern
# [('VERB', 'have'), ('VERB', 'cover'), ('NOUN', 'employee'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('PUNCT', '.')]
# *************************
#  ->
# division by zero
# *************************
#  ->  them the best health care system
# create pattern
# [('PRON', '-pron-'), ('DET', 'the'), ('ADJ', 'good'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'system')]
# *************************
#  ->  control of the health care system
# create pattern
# [('NOUN', 'control'), ('ADP', 'of'), ('DET', 'the'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'system')]
# *************************
#  ->  patients and their health care providers
# create pattern
# [('NOUN', 'patient'), ('CCONJ', 'and'), ('DET', '-pron-'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'provider')]
# *************************
#  ->  control of the health care system
# create pattern
# [('NOUN', 'control'), ('ADP', 'of'), ('DET', 'the'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'system')]
# *************************
#  ->  patients and their health care providers
# create pattern
# [('NOUN', 'patient'), ('CCONJ', 'and'), ('DET', '-pron-'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'provider')]
# *************************
#  ->  current state of health care:
# create pattern
# [('ADJ', 'current'), ('NOUN', 'state'), ('ADP', 'of'), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', ':')]
# *************************
#  ->  to pay for health care.
# create pattern
# [('PART', 'to'), ('VERB', 'pay'), ('ADP', 'for'), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', '.')]
# *************************
#  ->
# division by zero
# *************************
#  ->  to hold onto health insurance is
# create pattern
# [('PART', 'to'), ('VERB', 'hold'), ('ADP', 'onto'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('VERB', 'be')]
# *************************
#  ->  ambitious: Better health care for
# create pattern
# [('ADJ', 'ambitious'), ('PUNCT', ':'), ('ADJ', 'well'), ('NOUN', 'health'), ('NOUN', 'care'), ('ADP', 'for')]
# *************************
#  ->  quality, comprehensive health coverage?The first
# create pattern
# [('NOUN', 'quality'), ('PUNCT', ','), ('ADJ', 'comprehensive'), ('NOUN', 'health'), ('PROPN', 'coverage?the'), ('ADJ', 'first')]
# *************************
#  ->  government takeover of health care in
# create pattern
# [('NOUN', 'government'), ('NOUN', 'takeover'), ('ADP', 'of'), ('NOUN', 'health'), ('NOUN', 'care'), ('ADP', 'in')]
# *************************
#  ->  -run universal health care system
# create pattern
# [('PUNCT', '-'), ('VERB', 'run'), ('ADJ', 'universal'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'system')]
# *************************
#  ->  we reform our health care system
# create pattern
# [('PRON', '-pron-'), ('VERB', 'reform'), ('DET', '-pron-'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'system')]
# *************************
#  ->  complicate or ration health care.
# create pattern
# [('VERB', 'complicate'), ('CCONJ', 'or'), ('NOUN', 'ration'), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', '.')]
# *************************
#  ->  we reform our health care system
# create pattern
# [('PRON', '-pron-'), ('VERB', 'reform'), ('DET', '-pron-'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'system')]
# *************************
#  ->  complicate or ration health care.
# create pattern
# [('VERB', 'complicate'), ('CCONJ', 'or'), ('NOUN', 'ration'), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', '.')]
# *************************
#  ->  We will encourage health promotion and
# create pattern
# [('PRON', '-pron-'), ('VERB', 'will'), ('VERB', 'encourage'), ('NOUN', 'health'), ('NOUN', 'promotion'), ('CCONJ', 'and')]
# *************************
#  ->  stakeholders in the health care system
# create pattern
# [('NOUN', 'stakeholder'), ('ADP', 'in'), ('DET', 'the'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'system')]
# *************************
#  ->  patients and their health care providers
# create pattern
# [('NOUN', 'patient'), ('CCONJ', 'and'), ('DET', '-pron-'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'provider')]
# *************************
#  ->  instead of reducing health care costs
# create pattern
# [('ADV', 'instead'), ('ADP', 'of'), ('VERB', 'reduce'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'cost')]
# *************************
#  ->  Radical restructuring of health care would
# create pattern
# [('ADJ', 'radical'), ('NOUN', 'restructuring'), ('ADP', 'of'), ('NOUN', 'health'), ('NOUN', 'care'), ('VERB', 'would')]
# *************************
#  ->  choose the best health care provider
# create pattern
# [('VERB', 'choose'), ('DET', 'the'), ('ADJ', 'good'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'provider')]
# *************************
#  ->  hospital, and health coverage for
# create pattern
# [('NOUN', 'hospital'), ('PUNCT', ','), ('CCONJ', 'and'), ('NOUN', 'health'), ('NOUN', 'coverage'), ('ADP', 'for')]
# *************************
#  ->  choose the best health care provider
# create pattern
# [('VERB', 'choose'), ('DET', 'the'), ('ADJ', 'good'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'provider')]
# *************************
#  ->  hospital, and health coverage for
# create pattern
# [('NOUN', 'hospital'), ('PUNCT', ','), ('CCONJ', 'and'), ('NOUN', 'health'), ('NOUN', 'coverage'), ('ADP', 'for')]
# *************************
#  ->  access to a health care provider
# create pattern
# [('NOUN', 'access'), ('ADP', 'to'), ('DET', 'a'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'provider')]
# *************************
#  ->  and coverage of health care throughout
# create pattern
# [('CCONJ', 'and'), ('NOUN', 'coverage'), ('ADP', 'of'), ('NOUN', 'health'), ('NOUN', 'care'), ('ADP', 'throughout')]
# *************************
#  ->  obtain an affordable health care plan
# create pattern
# [('VERB', 'obtain'), ('DET', 'an'), ('ADJ', 'affordable'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'plan')]
# *************************
#  ->  , including a health savings account
# create pattern
# [('PUNCT', ','), ('VERB', 'include'), ('DET', 'a'), ('NOUN', 'health'), ('NOUN', 'saving'), ('NOUN', 'account')]
# *************************
#  ->  obtain an affordable health care plan
# create pattern
# [('VERB', 'obtain'), ('DET', 'an'), ('ADJ', 'affordable'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'plan')]
# *************************
#  ->  , including a health savings account
# create pattern
# [('PUNCT', ','), ('VERB', 'include'), ('DET', 'a'), ('NOUN', 'health'), ('NOUN', 'saving'), ('NOUN', 'account')]
# *************************
#  ->
# division by zero
# *************************
#  ->  do not receive health care from
# create pattern
# [('VERB', 'do'), ('ADV', 'not'), ('VERB', 'receive'), ('NOUN', 'health'), ('NOUN', 'care'), ('ADP', 'from')]
# *************************
#  ->  gives more generous health tax benefits
# create pattern
# [('VERB', 'give'), ('ADV', 'more'), ('ADJ', 'generous'), ('NOUN', 'health'), ('NOUN', 'tax'), ('NOUN', 'benefit')]
# *************************
#  ->  purchase an affordable health care plan
# create pattern
# [('VERB', 'purchase'), ('DET', 'an'), ('ADJ', 'affordable'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'plan')]
# *************************
#  ->  do not receive health care from
# create pattern
# [('VERB', 'do'), ('ADV', 'not'), ('VERB', 'receive'), ('NOUN', 'health'), ('NOUN', 'care'), ('ADP', 'from')]
# *************************
#  ->  gives more generous health tax benefits
# create pattern
# [('VERB', 'give'), ('ADV', 'more'), ('ADJ', 'generous'), ('NOUN', 'health'), ('NOUN', 'tax'), ('NOUN', 'benefit')]
# *************************
#  ->  purchase an affordable health care plan
# create pattern
# [('VERB', 'purchase'), ('DET', 'an'), ('ADJ', 'affordable'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'plan')]
# *************************
#  ->  do not receive health care from
# create pattern
# [('VERB', 'do'), ('ADV', 'not'), ('VERB', 'receive'), ('NOUN', 'health'), ('NOUN', 'care'), ('ADP', 'from')]
# *************************
#  ->  gives more generous health tax benefits
# create pattern
# [('VERB', 'give'), ('ADV', 'more'), ('ADJ', 'generous'), ('NOUN', 'health'), ('NOUN', 'tax'), ('NOUN', 'benefit')]
# *************************
#  ->  purchase an affordable health care plan
# create pattern
# [('VERB', 'purchase'), ('DET', 'an'), ('ADJ', 'affordable'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'plan')]
# *************************
#  ->  who choose a health insurance plan
# create pattern
# [('PRON', 'who'), ('VERB', 'choose'), ('DET', 'a'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('NOUN', 'plan')]
# *************************
#  ->  children including mental health treatment,
# create pattern
# [('NOUN', 'child'), ('VERB', 'include'), ('ADJ', 'mental'), ('NOUN', 'health'), ('NOUN', 'treatment'), ('PUNCT', ',')]
# *************************
#  ->  delivering control of health coverage to
# create pattern
# [('VERB', 'deliver'), ('NOUN', 'control'), ('ADP', 'of'), ('NOUN', 'health'), ('NOUN', 'coverage'), ('ADP', 'to')]
# *************************
#  ->  — are driving health care costs
# create pattern
# [('PUNCT', '—'), ('VERB', 'be'), ('VERB', 'drive'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'cost')]
# *************************
#  ->  of every four health care dollars
# create pattern
# [('ADP', 'of'), ('DET', 'every'), ('NUM', 'four'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'dollar')]
# *************************
#  ->  — are driving health care costs
# create pattern
# [('PUNCT', '—'), ('VERB', 'be'), ('VERB', 'drive'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'cost')]
# *************************
#  ->  of every four health care dollars
# create pattern
# [('ADP', 'of'), ('DET', 'every'), ('NUM', 'four'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'dollar')]
# *************************
#  ->  treatment of mental health conditions.
# create pattern
# [('NOUN', 'treatment'), ('ADP', 'of'), ('ADJ', 'mental'), ('NOUN', 'health'), ('NOUN', 'condition'), ('PUNCT', '.')]
# *************************
#  ->  affordable, quality health care,
# create pattern
# [('ADJ', 'affordable'), ('PUNCT', ','), ('NOUN', 'quality'), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', ',')]
# *************************
#  ->  important that mental health care be
# create pattern
# [('ADJ', 'important'), ('ADP', 'that'), ('ADJ', 'mental'), ('NOUN', 'health'), ('NOUN', 'care'), ('VERB', 'be')]
# *************************
#  ->  equally with physical health care.
# create pattern
# [('ADV', 'equally'), ('ADP', 'with'), ('ADJ', 'physical'), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', '.')]
# *************************
#  ->  important that mental health care be
# create pattern
# [('ADJ', 'important'), ('ADP', 'that'), ('ADJ', 'mental'), ('NOUN', 'health'), ('NOUN', 'care'), ('VERB', 'be')]
# *************************
#  ->  equally with physical health care.
# create pattern
# [('ADV', 'equally'), ('ADP', 'with'), ('ADJ', 'physical'), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', '.')]
# *************************
#  ->  Make the Best Health Care Choices
# create pattern
# [('VERB', 'make'), ('DET', 'the'), ('PROPN', 'best'), ('PROPN', 'health'), ('PROPN', 'care'), ('PROPN', 'choices')]
# *************************
#  ->  Clear information about health care empowers
# create pattern
# [('ADJ', 'clear'), ('NOUN', 'information'), ('ADP', 'about'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'empower')]
# *************************
#  ->  to spend their health care dollars
# create pattern
# [('PART', 'to'), ('VERB', 'spend'), ('DET', '-pron-'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'dollar')]
# *************************
#  ->  decisions about their health care providers
# create pattern
# [('NOUN', 'decision'), ('ADP', 'about'), ('DET', '-pron-'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'provider')]
# *************************
#  ->
# division by zero
# *************************
#  ->  fetal care and health care in
# create pattern
# [('ADJ', 'fetal'), ('NOUN', 'care'), ('CCONJ', 'and'), ('NOUN', 'health'), ('NOUN', 'care'), ('ADP', 'in')]
# *************************
#  ->
# division by zero
# *************************
#  ->  test results).Protect Good Health Care Providers
# create pattern
# [('NOUN', 'test'), ('PROPN', 'results).protect'), ('PROPN', 'good'), ('PROPN', 'health'), ('PROPN', 'care'), ('PROPN', 'providers')]
# *************************
#  ->
# division by zero
# *************************
#  ->  test results).Protect Good Health Care Providers
# create pattern
# [('NOUN', 'test'), ('PROPN', 'results).protect'), ('PROPN', 'good'), ('PROPN', 'health'), ('PROPN', 'care'), ('PROPN', 'providers')]
# *************************
#  ->  the cost of health care as
# create pattern
# [('DET', 'the'), ('NOUN', 'cost'), ('ADP', 'of'), ('NOUN', 'health'), ('NOUN', 'care'), ('ADP', 'as')]
# *************************
#  ->  health care as health care providers
# create pattern
# [('NOUN', 'health'), ('NOUN', 'care'), ('ADP', 'as'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'provider')]
# *************************
#  ->  the cost of health care as
# create pattern
# [('DET', 'the'), ('NOUN', 'cost'), ('ADP', 'of'), ('NOUN', 'health'), ('NOUN', 'care'), ('ADP', 'as')]
# *************************
#  ->  health care as health care providers
# create pattern
# [('NOUN', 'health'), ('NOUN', 'care'), ('ADP', 'as'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'provider')]
# *************************
#  ->
# division by zero
# *************************
#  ->  deserve access to health care providers
# create pattern
# [('VERB', 'deserve'), ('NOUN', 'access'), ('ADP', 'to'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'provider')]
# *************************
#  ->  with the right health care provider
# create pattern
# [('ADP', 'with'), ('DET', 'the'), ('ADJ', 'right'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'provider')]
# *************************
#  ->
# division by zero
# *************************
#  ->  deserve access to health care providers
# create pattern
# [('VERB', 'deserve'), ('NOUN', 'access'), ('ADP', 'to'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'provider')]
# *************************
#  ->  with the right health care provider
# create pattern
# [('ADP', 'with'), ('DET', 'the'), ('ADJ', 'right'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'provider')]
# *************************
#  ->
# division by zero
# *************************
#  ->  deserve access to health care providers
# create pattern
# [('VERB', 'deserve'), ('NOUN', 'access'), ('ADP', 'to'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'provider')]
# *************************
#  ->  with the right health care provider
# create pattern
# [('ADP', 'with'), ('DET', 'the'), ('ADJ', 'right'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'provider')]
# *************************
#  ->  national market for health insurance means
# create pattern
# [('ADJ', 'national'), ('NOUN', 'market'), ('ADP', 'for'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('VERB', 'mean')]
# *************************
#  ->  to provide affordable health care options
# create pattern
# [('PART', 'to'), ('VERB', 'provide'), ('ADJ', 'affordable'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'option')]
# *************************
#  ->  majority of our health care costs
# create pattern
# [('NOUN', 'majority'), ('ADP', 'of'), ('DET', '-pron-'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'cost')]
# *************************
#  ->  Rights of ConscienceThe health care profession
# create pattern
# [('PROPN', 'rights'), ('ADP', 'of'), ('PROPN', 'consciencethe'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'profession')]
# *************************
#  ->
# division by zero
# *************************
#  ->  refer for a health care service
# create pattern
# [('VERB', 'refer'), ('ADP', 'for'), ('DET', 'a'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'service')]
# *************************
#  ->
# division by zero
# *************************
#  ->  refer for a health care service
# create pattern
# [('VERB', 'refer'), ('ADP', 'for'), ('DET', 'a'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'service')]
# *************************
#  ->  of America’s health care,
# create pattern
# [('ADP', 'of'), ('PROPN', 'america'), ('PROPN', '’s'), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', ',')]
# *************************
#  ->  quality and accessible health care options
# create pattern
# [('NOUN', 'quality'), ('CCONJ', 'and'), ('ADJ', 'accessible'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'option')]
# *************************
#  ->  rest of our health care system
# create pattern
# [('NOUN', 'rest'), ('ADP', 'of'), ('DET', '-pron-'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'system')]
# *************************
#  ->  to provide quality health care.
# create pattern
# [('PART', 'to'), ('VERB', 'provide'), ('NOUN', 'quality'), ('NOUN', 'health'), ('NOUN', 'care'), ('PUNCT', '.')]
# *************************
#  ->  ~ recipients more health care options
# create pattern
# [('PUNCT', '~'), ('NOUN', 'recipient'), ('ADJ', 'more'), ('NOUN', 'health'), ('NOUN', 'care'), ('NOUN', 'option')]
# *************************
#  ->  to buy regular health insurance with
# create pattern
# [('PART', 'to'), ('VERB', 'buy'), ('ADJ', 'regular'), ('NOUN', 'health'), ('NOUN', 'insurance'), ('ADP', 'with')]
# *************************
#  ->
# division by zero
# *************************
#  ->
# division by zero
# *************************
#  ->  permitted to extend health-care
# create pattern
# [('VERB', 'permit'), ('PART', 'to'), ('VERB', 'extend'), ('NOUN', 'health'), ('PUNCT', '-'), ('NOUN', 'care')]
# *************************
#  ->  improve the Indian Health Service to
# create pattern
# [('VERB', 'improve'), ('DET', 'the'), ('PROPN', 'indian'), ('PROPN', 'health'), ('PROPN', 'service'), ('PART', 'to')]
# *************************

# %%
patterns = [
      [('ADP'),('NOUN', 'health'), ('NOUN','insurance'),('NOUN',"***")],
      [('ADP'), ('NOUN', 'health'), ('NOUN', 'care'), ('ADP', '***')]
]
print(patterns)
# Out:
# [['ADP', ('NOUN', 'health'), ('NOUN', 'insurance'), ('NOUN', '***')], ['ADP', ('NOUN', 'health'), ('NOUN', 'care'), ('ADP', '***')]]

# %%
new_contexts = []

analyzed = nlp(text)
lemmas = [token.lemma_.lower() for token in analyzed]
intersect = set(lemmas).intersection(set(term_dictionary))
if len(intersect) > 0:
    for pattern in patterns:
        in_machine = 0
        pattern_pos = 0
        pattern_find = []
        finds = []
        for token in analyzed:
            if in_machine == 0 and token.pos_ == pattern[pattern_pos] :
                in_machine = 1
                pattern_pos += 1
                pattern_find.append(token)
            elif in_machine == 1:
                if pattern_pos == len(pattern):
                    print("FOUND MATCH")
                    print(pattern_find)
                    print(pattern_find[0].sent)
                    finds.append(pattern_find)
                    in_machine = 0
                    pattern_pos = 0
                    pattern_find = []
                if pattern[pattern_pos][1] == "***":
                    if token.pos_ == pattern[pattern_pos][0]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
                elif pattern[pattern_pos][0] != "NOUN":
                    if token.pos_ == pattern[pattern_pos][0]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
                else:
                    if token.pos_ == pattern[pattern_pos][0] and token.lemma_ == pattern[pattern_pos][1]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
        
        
                    
        if len(finds) > 0:
            print(finds)
# Out:
# FOUND MATCH
# [of, health, care, to]
# Our plan to return control of health care to patients and providers will benefit small   business employers and employees alike.
# FOUND MATCH
# [of, health, care, in]
# The American people rejected Democrats~ attempted government takeover of health care in 1993, and they remain skeptical of politicians who would send us down that road.
# FOUND MATCH
# [of, health, care, throughout]
# We offer a detailed program that will improve the quality, cost, and coverage of health care throughout the nation, and we will turn that plan into reality.
# FOUND MATCH
# [of, health, care, as]
# Frivolous lawsuits also drive up the cost of health care as health care providers are forced to practice defensive medicine, such as ordering unnecessary tests.
# [[of, health, care, to], [of, health, care, in], [of, health, care, throughout], [of, health, care, as]]

# %% [markdown]
# # Republican Jobs 2012

# %%
term_dictionary = []

text = read_file('C:/Users/Place Holder/Downloads/Republican/61620_201211.txt')


term_dictionary.append("job")

num_docs = len(text)

contexts = []

analyzed = nlp(text)

lemmas = [token.lemma_.lower() for token in analyzed]
intersect = set(lemmas).intersection(set(term_dictionary))
if len(intersect) > 0:
    context_sentences = [token.sent.as_doc() for token in analyzed if token.lemma_.lower() in term_dictionary ]
    contexts.extend(context_sentences)
        #print(context_sentences)

# %%
patterns = []

def pattern_creator(context):
    print("create pattern")
    pattern = [(token.pos_, token.lemma_.lower()) for token in context]
    print(pattern)

for sentence in contexts:
    for token in sentence:
        if token.lemma_.lower() in term_dictionary:
            #print(token.text, token.i, " - ", token.pos_)
            start_token = token.i - 3
            end_token = token.i + 3
            context = sentence[start_token:end_token]
            print(" -> ", context)
            try:
                new_pattern = pattern_creator(context.as_doc())
            except Exception as e:
                print(e)
            print("*" * 25)
# Out:
#  ->  burden of lost jobs, lost
# create pattern
# [('NOUN', 'burden'), ('ADP', 'of'), ('VERB', 'lose'), ('NOUN', 'job'), ('PUNCT', ','), ('VERB', 'lose')]
# *************************
#  ->  growth, destroyed jobs, halted
# create pattern
# [('NOUN', 'growth'), ('PUNCT', ','), ('VERB', 'destroy'), ('NOUN', 'job'), ('PUNCT', ','), ('VERB', 'halt')]
# *************************
#  ->  business formation and job creation.
# create pattern
# [('NOUN', 'business'), ('NOUN', 'formation'), ('CCONJ', 'and'), ('NOUN', 'job'), ('NOUN', 'creation'), ('PUNCT', '.')]
# *************************
#  ->  to workers without jobs,families
# create pattern
# [('ADP', 'to'), ('NOUN', 'worker'), ('ADP', 'without'), ('NOUN', 'job'), ('PUNCT', ','), ('NOUN', 'family')]
# *************************
#  ->
# division by zero
# *************************
#  ->
# division by zero
# *************************
#  ->  temporary or artificial jobs.
# create pattern
# [('ADJ', 'temporary'), ('CCONJ', 'or'), ('ADJ', 'artificial'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  want a roaring job market to
# create pattern
# [('VERB', 'want'), ('DET', 'a'), ('ADJ', 'roaring'), ('NOUN', 'job'), ('NOUN', 'market'), ('PART', 'to')]
# *************************
#  ->  boost employmentand create job growth and
# create pattern
# [('VERB', 'boost'), ('ADJ', 'employmentand'), ('VERB', 'create'), ('NOUN', 'job'), ('NOUN', 'growth'), ('CCONJ', 'and')]
# *************************
#  ->  vast majority of jobs, patents
# create pattern
# [('ADJ', 'vast'), ('NOUN', 'majority'), ('ADP', 'of'), ('NOUN', 'job'), ('PUNCT', ','), ('NOUN', 'patent')]
# *************************
#  ->  grow and create jobs for our
# create pattern
# [('VERB', 'grow'), ('CCONJ', 'and'), ('VERB', 'create'), ('NOUN', 'job'), ('ADP', 'for'), ('DET', '-pron-')]
# *************************
#  ->  investment,cripples job creation,
# create pattern
# [('NOUN', 'investment'), ('PUNCT', ','), ('NOUN', 'cripple'), ('NOUN', 'job'), ('NOUN', 'creation'), ('PUNCT', ',')]
# *************************
#  ->  and to spur job creation here
# create pattern
# [('CCONJ', 'and'), ('PART', 'to'), ('VERB', 'spur'), ('NOUN', 'job'), ('NOUN', 'creation'), ('ADV', 'here')]
# *************************
#  ->  already harming  job  creation
# create pattern
# [('ADV', 'already'), ('VERB', 'harm'), ('SPACE', '  '), ('NOUN', 'job'), ('SPACE', '  '), ('NOUN', 'creation')]
# *************************
#  ->  , construction industry jobs remain down
# create pattern
# [('PUNCT', ','), ('NOUN', 'construction'), ('NOUN', 'industry'), ('NOUN', 'job'), ('VERB', 'remain'), ('ADV', 'down')]
# *************************
#  ->  , and create jobs.
# create pattern
# [('PUNCT', ','), ('CCONJ', 'and'), ('VERB', 'create'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  economic growth and job creation.
# create pattern
# [('ADJ', 'economic'), ('NOUN', 'growth'), ('CCONJ', 'and'), ('NOUN', 'job'), ('NOUN', 'creation'), ('PUNCT', '.')]
# *************************
#  ->  Certainty, and Job Creation Act
# create pattern
# [('PROPN', 'certainty'), ('PUNCT', ','), ('CCONJ', 'and'), ('PROPN', 'job'), ('PROPN', 'creation'), ('PROPN', 'act')]
# *************************
#  ->  means more American jobs,higher
# create pattern
# [('VERB', 'mean'), ('ADJ', 'more'), ('ADJ', 'american'), ('NOUN', 'job'), ('PUNCT', ','), ('ADJ', 'high')]
# *************************
#  ->  means another 5,000 jobs here at
# create pattern
# [('VERB', 'mean'), ('DET', 'another'), ('NUM', '5,000'), ('NOUN', 'job'), ('ADV', 'here'), ('ADP', 'at')]
# *************************
#  ->  nearly ten million jobs supported by
# create pattern
# [('ADV', 'nearly'), ('NUM', 'ten'), ('NUM', 'million'), ('NOUN', 'job'), ('VERB', 'support'), ('ADP', 'by')]
# *************************
#  ->  no payoff in jobs.
# create pattern
# [('DET', 'no'), ('NOUN', 'payoff'), ('ADP', 'in'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->   and  job  creation
# create pattern
# [('SPACE', '  '), ('CCONJ', 'and'), ('SPACE', '  '), ('NOUN', 'job'), ('SPACE', '  '), ('NOUN', 'creation')]
# *************************
#  ->  from competing for jobs in many
# create pattern
# [('ADP', 'from'), ('VERB', 'compete'), ('ADP', 'for'), ('NOUN', 'job'), ('ADP', 'in'), ('ADJ', 'many')]
# *************************
#  ->  businesses and American jobs,but
# create pattern
# [('NOUN', 'business'), ('CCONJ', 'and'), ('ADJ', 'american'), ('NOUN', 'job'), ('PUNCT', ','), ('CCONJ', 'but')]
# *************************
#  ->  party of sustainable jobs and economic
# create pattern
# [('NOUN', 'party'), ('ADP', 'of'), ('ADJ', 'sustainable'), ('NOUN', 'job'), ('CCONJ', 'and'), ('ADJ', 'economic')]
# *************************
#  ->  sector is a job generatorand a
# create pattern
# [('NOUN', 'sector'), ('VERB', 'be'), ('DET', 'a'), ('NOUN', 'job'), ('VERB', 'generatorand'), ('DET', 'a')]
# *************************
#  ->  because of the jobs that will
# create pattern
# [('ADP', 'because'), ('ADP', 'of'), ('DET', 'the'), ('NOUN', 'job'), ('DET', 'that'), ('VERB', 'will')]
# *************************
#  ->  determined to create jobs,spur
# create pattern
# [('ADJ', 'determined'), ('PART', 'to'), ('VERB', 'create'), ('NOUN', 'job'), ('PUNCT', ','), ('VERB', 'spur')]
# *************************
#  ->  of thousands of jobs that go
# create pattern
# [('ADP', 'of'), ('NOUN', 'thousand'), ('ADP', 'of'), ('NOUN', 'job'), ('DET', 'that'), ('VERB', 'go')]
# *************************
#  ->  resources,the jobs it produces
# create pattern
# [('NOUN', 'resource'), ('PUNCT', ','), ('DET', 'the'), ('NOUN', 'job'), ('PRON', '-pron-'), ('VERB', 'produce')]
# *************************
#  ->   real  job creation
# create pattern
# [('SPACE', '  '), ('ADJ', 'real'), ('SPACE', '  '), ('NOUN', 'job'), ('NOUN', 'creation'), ('SPACE', '  ')]
# *************************
#  ->   and  jobs  projects
# create pattern
# [('SPACE', '  '), ('CCONJ', 'and'), ('SPACE', '  '), ('NOUN', 'job'), ('SPACE', '  '), ('NOUN', 'project')]
# *************************
#  ->   of  jobs.
# create pattern
# [('SPACE', '  '), ('ADP', 'of'), ('SPACE', '  '), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  our agenda for jobs, growth
# create pattern
# [('DET', '-pron-'), ('NOUN', 'agenda'), ('ADP', 'for'), ('NOUN', 'job'), ('PUNCT', ','), ('NOUN', 'growth')]
# *************************
#  ->  producers and the jobs they generate
# create pattern
# [('NOUN', 'producer'), ('CCONJ', 'and'), ('DET', 'the'), ('NOUN', 'job'), ('PRON', '-pron-'), ('VERB', 'generate')]
# *************************
#  ->  which  provides jobs  to
# create pattern
# [('DET', 'which'), ('SPACE', '  '), ('VERB', 'provide'), ('NOUN', 'job'), ('SPACE', '  '), ('ADP', 'to')]
# *************************
#  ->  economic development, job creation,
# create pattern
# [('ADJ', 'economic'), ('NOUN', 'development'), ('PUNCT', ','), ('NOUN', 'job'), ('NOUN', 'creation'), ('PUNCT', ',')]
# *************************
#  ->  , and stifling job creation.
# create pattern
# [('PUNCT', ','), ('CCONJ', 'and'), ('VERB', 'stifle'), ('NOUN', 'job'), ('NOUN', 'creation'), ('PUNCT', '.')]
# *************************
#  ->  full impact on jobs and the
# create pattern
# [('ADJ', 'full'), ('NOUN', 'impact'), ('ADP', 'on'), ('NOUN', 'job'), ('CCONJ', 'and'), ('DET', 'the')]
# *************************
#  ->  threaten millions of jobs over the
# create pattern
# [('VERB', 'threaten'), ('NOUN', 'million'), ('ADP', 'of'), ('NOUN', 'job'), ('ADP', 'over'), ('DET', 'the')]
# *************************
#  ->  protection goals and job creation.
# create pattern
# [('NOUN', 'protection'), ('NOUN', 'goal'), ('CCONJ', 'and'), ('NOUN', 'job'), ('NOUN', 'creation'), ('PUNCT', '.')]
# *************************
#  ->  on regulations is jobs.
# create pattern
# [('ADP', 'on'), ('NOUN', 'regulation'), ('VERB', 'be'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  grow,created jobs,and
# create pattern
# [('VERB', 'grow'), ('PUNCT', ','), ('VERB', 'create'), ('NOUN', 'job'), ('PUNCT', ','), ('CCONJ', 'and')]
# *************************
#  ->  frozen investment and job
# create pattern
# [('VERB', 'freeze'), ('NOUN', 'investment'), ('CCONJ', 'and'), ('NOUN', 'job')]
# *************************
#  ->  systems so that jobs can be
# create pattern
# [('NOUN', 'system'), ('ADP', 'so'), ('ADP', 'that'), ('NOUN', 'job'), ('VERB', 'can'), ('VERB', 'be')]
# *************************
#  ->   need  jobs,
# create pattern
# [('SPACE', '  '), ('VERB', 'need'), ('SPACE', '  '), ('NOUN', 'job'), ('PUNCT', ','), ('SPACE', '  ')]
# *************************
#  ->  regulations that thwart job creation must
# create pattern
# [('NOUN', 'regulation'), ('DET', 'that'), ('VERB', 'thwart'), ('NOUN', 'job'), ('NOUN', 'creation'), ('VERB', 'must')]
# *************************
#  ->  of highvalue American jobs.
# create pattern
# [('ADP', 'of'), ('ADJ', 'highvalue'), ('ADJ', 'american'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  a part time job, working
# create pattern
# [('DET', 'a'), ('NOUN', 'part'), ('NOUN', 'time'), ('NOUN', 'job'), ('PUNCT', ','), ('VERB', 'work')]
# *************************
#  ->  replace dependency with jobs in the
# create pattern
# [('VERB', 'replace'), ('NOUN', 'dependency'), ('ADP', 'with'), ('NOUN', 'job'), ('ADP', 'in'), ('DET', 'the')]
# *************************
#  ->  with them from job to job
# create pattern
# [('ADP', 'with'), ('PRON', '-pron-'), ('ADP', 'from'), ('NOUN', 'job'), ('ADP', 'to'), ('NOUN', 'job')]
# *************************
#  ->  from job to job.
# create pattern
# [('ADP', 'from'), ('NOUN', 'job'), ('ADP', 'to'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  with them from job to job
# create pattern
# [('ADP', 'with'), ('PRON', '-pron-'), ('ADP', 'from'), ('NOUN', 'job'), ('ADP', 'to'), ('NOUN', 'job')]
# *************************
#  ->  from job to job.
# create pattern
# [('ADP', 'from'), ('NOUN', 'job'), ('ADP', 'to'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  innovation, U.S. job creation,
# create pattern
# [('NOUN', 'innovation'), ('PUNCT', ','), ('PROPN', 'u.s.'), ('NOUN', 'job'), ('NOUN', 'creation'), ('PUNCT', ',')]
# *************************
#  ->  millions of highpaying jobs to our
# create pattern
# [('NOUN', 'million'), ('ADP', 'of'), ('VERB', 'highpaye'), ('NOUN', 'job'), ('ADP', 'to'), ('DET', '-pron-')]
# *************************
#  ->  innovators, and job creators
# create pattern
# [('NOUN', 'innovator'), ('PUNCT', ','), ('CCONJ', 'and'), ('NOUN', 'job'), ('NOUN', 'creator')]
# *************************
#  ->  device and drug jobs stay in
# create pattern
# [('NOUN', 'device'), ('CCONJ', 'and'), ('NOUN', 'drug'), ('NOUN', 'job'), ('VERB', 'stay'), ('ADP', 'in')]
# *************************
#  ->  , working at jobs for which
# create pattern
# [('PUNCT', ','), ('VERB', 'work'), ('ADP', 'at'), ('NOUN', 'job'), ('ADP', 'for'), ('DET', 'which')]
# *************************
#  ->  directly related to job opportunities.
# create pattern
# [('ADV', 'directly'), ('VERB', 'relate'), ('ADP', 'to'), ('NOUN', 'job'), ('NOUN', 'opportunity'), ('PUNCT', '.')]
# *************************
#  ->  1.5 million defenserelated jobs.
# create pattern
# [('NUM', '1.5'), ('NUM', 'million'), ('VERB', 'defenserelate'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  do a better job of protecting
# create pattern
# [('VERB', 'do'), ('DET', 'a'), ('ADJ', 'well'), ('NOUN', 'job'), ('ADP', 'of'), ('VERB', 'protect')]
# *************************
#  ->  to their civilian jobs, whether
# create pattern
# [('ADP', 'to'), ('DET', '-pron-'), ('ADJ', 'civilian'), ('NOUN', 'job'), ('PUNCT', ','), ('ADP', 'whether')]
# *************************
#  ->    for  job  programs
# create pattern
# [('SPACE', '\xa0 '), ('ADP', 'for'), ('SPACE', '\xa0 '), ('NOUN', 'job'), ('SPACE', '\xa0 '), ('NOUN', 'program')]
# *************************
#  ->  reentry into the job market as
# create pattern
# [('NOUN', 'reentry'), ('ADP', 'into'), ('DET', 'the'), ('NOUN', 'job'), ('NOUN', 'market'), ('ADV', 'as')]
# *************************
#  ->
# division by zero
# *************************

# %%
patterns = [
      [('ADJ'),('NOUN','job'), ('CCONJ',"***"),('ADJ',"***")],
      [('ADJ'), ('PART', "***"), ('VERB', 'create'), ('NOUN','job')],
      [('ADP'), ('NOUN', 'job'), ('ADP', 'to'), ('NOUN','job')],
      [('VERB'), ('ADP', "***"), ('NOUN', 'job'), ('NOUN',"***")]
]

print(patterns)
# Out:
# [['ADJ', ('NOUN', 'job'), ('CCONJ', '***'), ('ADJ', '***')], ['ADJ', ('PART', '***'), ('VERB', 'create'), ('NOUN', 'job')], ['ADP', ('NOUN', 'job'), ('ADP', 'to'), ('NOUN', 'job')], ['VERB', ('ADP', '***'), ('NOUN', 'job'), ('NOUN', '***')]]

# %%
new_contexts = []

analyzed = nlp(text)
lemmas = [token.lemma_.lower() for token in analyzed]
intersect = set(lemmas).intersection(set(term_dictionary))
if len(intersect) > 0:
    for pattern in patterns:
        in_machine = 0
        pattern_pos = 0
        pattern_find = []
        finds = []
        for token in analyzed:
            if in_machine == 0 and token.pos_ == pattern[pattern_pos] :
                in_machine = 1
                pattern_pos += 1
                pattern_find.append(token)
            elif in_machine == 1:
                if pattern_pos == len(pattern):
                    print("FOUND MATCH")
                    print(pattern_find)
                    print(pattern_find[0].sent)
                    finds.append(pattern_find)
                    in_machine = 0
                    pattern_pos = 0
                    pattern_find = []
                if pattern[pattern_pos][1] == "***":
                    if token.pos_ == pattern[pattern_pos][0]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
                elif pattern[pattern_pos][0] != "NOUN":
                    if token.pos_ == pattern[pattern_pos][0]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
                else:
                    if token.pos_ == pattern[pattern_pos][0] and token.lemma_ == pattern[pattern_pos][1]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
        
        
                    
        if len(finds) > 0:
            print(finds)
# Out:
# FOUND MATCH
# [sustainable, jobs, and, economic]
# Energy, Agriculture and the EnvironmentWe are the party of sustainable jobs and economic growth – through American energy, agriculture, and environmental policy.
# [[sustainable, jobs, and, economic]]
# FOUND MATCH
# [determined, to, create, jobs]
# We are determined to create jobs,spur economic growth,lower energy prices,and strengthen our energy industry.
# [[determined, to, create, jobs]]
# FOUND MATCH
# [from, job, to, job]
# Today’s highly mobile work force requires portability of insurance coverage that can go with them from job to job.
# [[from, job, to, job]]
# FOUND MATCH
# [related, to, job, opportunities]
# It is time to get back to basics and to higher education programs directly related to job opportunities.
# [[related, to, job, opportunities]]

# %% [markdown]
# # Democrats Jobs 2012

# %%
term_dictionary = []

text = read_file('C:/Users/Place Holder/Downloads/Democrat/61320_201211.txt')


term_dictionary.append("job")

num_docs = len(text)

contexts = []

analyzed = nlp(text)

lemmas = [token.lemma_.lower() for token in analyzed]
intersect = set(lemmas).intersection(set(term_dictionary))
if len(intersect) > 0:
    context_sentences = [token.sent.as_doc() for token in analyzed if token.lemma_.lower() in term_dictionary ]
    contexts.extend(context_sentences)
        #print(context_sentences)

# %%
patterns = []

def pattern_creator(context):
    print("create pattern")
    pattern = [(token.pos_, token.lemma_.lower()) for token in context]
    print(pattern)

for sentence in contexts:
    for token in sentence:
        if token.lemma_.lower() in term_dictionary:
            #print(token.text, token.i, " - ", token.pos_)
            start_token = token.i - 3
            end_token = token.i + 3
            context = sentence[start_token:end_token]
            print(" -> ", context)
            try:
                new_pattern = pattern_creator(context.as_doc())
            except Exception as e:
                print(e)
            print("*" * 25)
# Out:
#  ->  to find a job that pays
# create pattern
# [('PART', 'to'), ('VERB', 'find'), ('DET', 'a'), ('NOUN', 'job'), ('DET', 'that'), ('VERB', 'pay')]
# *************************
#  ->  automatically translate into jobs and prosperity
# create pattern
# [('ADV', 'automatically'), ('VERB', 'translate'), ('ADP', 'into'), ('NOUN', 'job'), ('CCONJ', 'and'), ('NOUN', 'prosperity')]
# *************************
#  ->  so many their jobs, homes
# create pattern
# [('ADV', 'so'), ('ADJ', 'many'), ('DET', '-pron-'), ('NOUN', 'job'), ('PUNCT', ','), ('NOUN', 'home')]
# *************************
#  ->  are working multiple jobs and struggling
# create pattern
# [('VERB', 'be'), ('VERB', 'work'), ('ADJ', 'multiple'), ('NOUN', 'job'), ('CCONJ', 'and'), ('VERB', 'struggle')]
# *************************
#  ->  Americans lost their jobs – more
# create pattern
# [('PROPN', 'americans'), ('VERB', 'lose'), ('DET', '-pron-'), ('NOUN', 'job'), ('PUNCT', '–'), ('ADJ', 'more')]
# *************************
#  ->  created 4.5 million jobs,and
# create pattern
# [('VERB', 'create'), ('NUM', '4.5'), ('NUM', 'million'), ('NOUN', 'job'), ('PUNCT', ','), ('CCONJ', 'and')]
# *************************
#  ->  that creates the jobs of the
# create pattern
# [('DET', 'that'), ('VERB', 'create'), ('DET', 'the'), ('NOUN', 'job'), ('ADP', 'of'), ('DET', 'the')]
# *************************
#  ->  firefighters on the job.
# create pattern
# [('NOUN', 'firefighter'), ('ADP', 'on'), ('DET', 'the'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  create one million jobs.
# create pattern
# [('VERB', 'create'), ('NUM', 'one'), ('NUM', 'million'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  economic growth and job creation,
# create pattern
# [('ADJ', 'economic'), ('NOUN', 'growth'), ('CCONJ', 'and'), ('NOUN', 'job'), ('NOUN', 'creation'), ('PUNCT', ',')]
# *************************
#  ->  recovery and create jobs now,
# create pattern
# [('NOUN', 'recovery'), ('CCONJ', 'and'), ('VERB', 'create'), ('NOUN', 'job'), ('ADV', 'now'), ('PUNCT', ',')]
# *************************
#  ->  responders on the job, putting
# create pattern
# [('NOUN', 'responder'), ('ADP', 'on'), ('DET', 'the'), ('NOUN', 'job'), ('PUNCT', ','), ('VERB', 'put')]
# *************************
#  ->  recovery and create jobs now,
# create pattern
# [('NOUN', 'recovery'), ('CCONJ', 'and'), ('VERB', 'create'), ('NOUN', 'job'), ('ADV', 'now'), ('PUNCT', ',')]
# *************************
#  ->  responders on the job, putting
# create pattern
# [('NOUN', 'responder'), ('ADP', 'on'), ('DET', 'the'), ('NOUN', 'job'), ('PUNCT', ','), ('VERB', 'put')]
# *************************
#  ->  more training and job search assistance
# create pattern
# [('ADJ', 'more'), ('NOUN', 'training'), ('CCONJ', 'and'), ('NOUN', 'job'), ('NOUN', 'search'), ('NOUN', 'assistance')]
# *************************
#  ->  they lost their job.
# create pattern
# [('PRON', '-pron-'), ('VERB', 'lose'), ('DET', '-pron-'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  more training and job search assistance
# create pattern
# [('ADJ', 'more'), ('NOUN', 'training'), ('CCONJ', 'and'), ('NOUN', 'job'), ('NOUN', 'search'), ('NOUN', 'assistance')]
# *************************
#  ->  they lost their job.
# create pattern
# [('PRON', '-pron-'), ('VERB', 'lose'), ('DET', '-pron-'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  of thousands of jobs going overseas
# create pattern
# [('ADP', 'of'), ('NOUN', 'thousand'), ('ADP', 'of'), ('NOUN', 'job'), ('VERB', 'go'), ('ADV', 'overseas')]
# *************************
#  ->  or loses their job.
# create pattern
# [('CCONJ', 'or'), ('VERB', 'lose'), ('DET', '-pron-'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  than 400,000 educator jobs.
# create pattern
# [('ADP', 'than'), ('NUM', '400,000'), ('NOUN', 'educator'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  do a heroic job for their
# create pattern
# [('VERB', 'do'), ('DET', 'a'), ('ADJ', 'heroic'), ('NOUN', 'job'), ('ADP', 'for'), ('DET', '-pron-')]
# *************************
#  ->  work-study jobs available to
# create pattern
# [('NOUN', 'work'), ('PUNCT', '-'), ('NOUN', 'study'), ('NOUN', 'job'), ('ADJ', 'available'), ('ADP', 'to')]
# *************************
#  ->  need for good jobs waiting to
# create pattern
# [('VERB', 'need'), ('ADP', 'for'), ('ADJ', 'good'), ('NOUN', 'job'), ('VERB', 'wait'), ('PART', 'to')]
# *************************
#  ->  and help create jobs here at
# create pattern
# [('CCONJ', 'and'), ('VERB', 'help'), ('VERB', 'create'), ('NOUN', 'job'), ('ADV', 'here'), ('ADP', 'at')]
# *************************
#  ->  good middle class jobs – even
# create pattern
# [('ADJ', 'good'), ('ADJ', 'middle'), ('NOUN', 'class'), ('NOUN', 'job'), ('PUNCT', '–'), ('ADV', 'even')]
# *************************
#  ->  thousands of such jobs during the
# create pattern
# [('NOUN', 'thousand'), ('ADP', 'of'), ('ADJ', 'such'), ('NOUN', 'job'), ('ADP', 'during'), ('DET', 'the')]
# *************************
#  ->  still shedding these jobs.
# create pattern
# [('ADV', 'still'), ('VERB', 'shed'), ('DET', 'these'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  good middle class jobs – even
# create pattern
# [('ADJ', 'good'), ('ADJ', 'middle'), ('NOUN', 'class'), ('NOUN', 'job'), ('PUNCT', '–'), ('ADV', 'even')]
# *************************
#  ->  thousands of such jobs during the
# create pattern
# [('NOUN', 'thousand'), ('ADP', 'of'), ('ADJ', 'such'), ('NOUN', 'job'), ('ADP', 'during'), ('DET', 'the')]
# *************************
#  ->  still shedding these jobs.
# create pattern
# [('ADV', 'still'), ('VERB', 'shed'), ('DET', 'these'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  good middle class jobs – even
# create pattern
# [('ADJ', 'good'), ('ADJ', 'middle'), ('NOUN', 'class'), ('NOUN', 'job'), ('PUNCT', '–'), ('ADV', 'even')]
# *************************
#  ->  thousands of such jobs during the
# create pattern
# [('NOUN', 'thousand'), ('ADP', 'of'), ('ADJ', 'such'), ('NOUN', 'job'), ('ADP', 'during'), ('DET', 'the')]
# *************************
#  ->  still shedding these jobs.
# create pattern
# [('ADV', 'still'), ('VERB', 'shed'), ('DET', 'these'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  skills for quality jobs and that
# create pattern
# [('NOUN', 'skill'), ('ADP', 'for'), ('NOUN', 'quality'), ('NOUN', 'job'), ('CCONJ', 'and'), ('DET', 'that')]
# *************************
#  ->  helping to bring jobs and industry
# create pattern
# [('VERB', 'help'), ('PART', 'to'), ('VERB', 'bring'), ('NOUN', 'job'), ('CCONJ', 'and'), ('NOUN', 'industry')]
# *************************
#  ->  businesses and American jobs in communities
# create pattern
# [('NOUN', 'business'), ('CCONJ', 'and'), ('ADJ', 'american'), ('NOUN', 'job'), ('ADP', 'in'), ('NOUN', 'community')]
# *************************
#  ->  Oil while promoting job growth in
# create pattern
# [('PROPN', 'oil'), ('ADP', 'while'), ('VERB', 'promote'), ('NOUN', 'job'), ('NOUN', 'growth'), ('ADP', 'in')]
# *************************
#  ->  deficit and increase jobs and growth
# create pattern
# [('NOUN', 'deficit'), ('CCONJ', 'and'), ('VERB', 'increase'), ('NOUN', 'job'), ('CCONJ', 'and'), ('NOUN', 'growth')]
# *************************
#  ->  Oil while promoting job growth in
# create pattern
# [('PROPN', 'oil'), ('ADP', 'while'), ('VERB', 'promote'), ('NOUN', 'job'), ('NOUN', 'growth'), ('ADP', 'in')]
# *************************
#  ->  deficit and increase jobs and growth
# create pattern
# [('NOUN', 'deficit'), ('CCONJ', 'and'), ('VERB', 'increase'), ('NOUN', 'job'), ('CCONJ', 'and'), ('NOUN', 'growth')]
# *************************
#  ->  private-sector jobs here in
# create pattern
# [('ADJ', 'private'), ('PUNCT', '-'), ('NOUN', 'sector'), ('NOUN', 'job'), ('ADV', 'here'), ('ADP', 'in')]
# *************************
#  ->  manufacturers are creating jobs for the
# create pattern
# [('NOUN', 'manufacturer'), ('VERB', 'be'), ('VERB', 'create'), ('NOUN', 'job'), ('ADP', 'for'), ('DET', 'the')]
# *************************
#  ->  more than 500,000 jobs since the
# create pattern
# [('ADJ', 'more'), ('ADP', 'than'), ('NUM', '500,000'), ('NOUN', 'job'), ('ADP', 'since'), ('DET', 'the')]
# *************************
#  ->  2010.Instead of cutting jobs or shipping
# create pattern
# [('NUM', '2010.instead'), ('ADP', 'of'), ('VERB', 'cut'), ('NOUN', 'job'), ('CCONJ', 'or'), ('VERB', 'ship')]
# *************************
#  ->  or bringing overseas jobs back home
# create pattern
# [('CCONJ', 'or'), ('VERB', 'bring'), ('ADJ', 'overseas'), ('NOUN', 'job'), ('ADV', 'back'), ('ADV', 'home')]
# *************************
#  ->  manufacturers are creating jobs for the
# create pattern
# [('NOUN', 'manufacturer'), ('VERB', 'be'), ('VERB', 'create'), ('NOUN', 'job'), ('ADP', 'for'), ('DET', 'the')]
# *************************
#  ->  more than 500,000 jobs since the
# create pattern
# [('ADJ', 'more'), ('ADP', 'than'), ('NUM', '500,000'), ('NOUN', 'job'), ('ADP', 'since'), ('DET', 'the')]
# *************************
#  ->  2010.Instead of cutting jobs or shipping
# create pattern
# [('NUM', '2010.instead'), ('ADP', 'of'), ('VERB', 'cut'), ('NOUN', 'job'), ('CCONJ', 'or'), ('VERB', 'ship')]
# *************************
#  ->  or bringing overseas jobs back home
# create pattern
# [('CCONJ', 'or'), ('VERB', 'bring'), ('ADJ', 'overseas'), ('NOUN', 'job'), ('ADV', 'back'), ('ADV', 'home')]
# *************************
#  ->  manufacturers are creating jobs for the
# create pattern
# [('NOUN', 'manufacturer'), ('VERB', 'be'), ('VERB', 'create'), ('NOUN', 'job'), ('ADP', 'for'), ('DET', 'the')]
# *************************
#  ->  more than 500,000 jobs since the
# create pattern
# [('ADJ', 'more'), ('ADP', 'than'), ('NUM', '500,000'), ('NOUN', 'job'), ('ADP', 'since'), ('DET', 'the')]
# *************************
#  ->  2010.Instead of cutting jobs or shipping
# create pattern
# [('NUM', '2010.instead'), ('ADP', 'of'), ('VERB', 'cut'), ('NOUN', 'job'), ('CCONJ', 'or'), ('VERB', 'ship')]
# *************************
#  ->  or bringing overseas jobs back home
# create pattern
# [('CCONJ', 'or'), ('VERB', 'bring'), ('ADJ', 'overseas'), ('NOUN', 'job'), ('ADV', 'back'), ('ADV', 'home')]
# *************************
#  ->  manufacturers are creating jobs for the
# create pattern
# [('NOUN', 'manufacturer'), ('VERB', 'be'), ('VERB', 'create'), ('NOUN', 'job'), ('ADP', 'for'), ('DET', 'the')]
# *************************
#  ->  more than 500,000 jobs since the
# create pattern
# [('ADJ', 'more'), ('ADP', 'than'), ('NUM', '500,000'), ('NOUN', 'job'), ('ADP', 'since'), ('DET', 'the')]
# *************************
#  ->  2010.Instead of cutting jobs or shipping
# create pattern
# [('NUM', '2010.instead'), ('ADP', 'of'), ('VERB', 'cut'), ('NOUN', 'job'), ('CCONJ', 'or'), ('VERB', 'ship')]
# *************************
#  ->  or bringing overseas jobs back home
# create pattern
# [('CCONJ', 'or'), ('VERB', 'bring'), ('ADJ', 'overseas'), ('NOUN', 'job'), ('ADV', 'back'), ('ADV', 'home')]
# *************************
#  ->  than one million jobs,preventing
# create pattern
# [('ADP', 'than'), ('NUM', 'one'), ('NUM', 'million'), ('NOUN', 'job'), ('PUNCT', ','), ('VERB', 'prevent')]
# *************************
#  ->  more than 200,000 jobs in the
# create pattern
# [('ADJ', 'more'), ('ADP', 'than'), ('NUM', '200,000'), ('NOUN', 'job'), ('ADP', 'in'), ('DET', 'the')]
# *************************
#  ->  that are shipping jobs overseas and
# create pattern
# [('DET', 'that'), ('VERB', 'be'), ('VERB', 'ship'), ('NOUN', 'job'), ('ADV', 'overseas'), ('CCONJ', 'and')]
# *************************
#  ->  American companies take jobs to other
# create pattern
# [('ADJ', 'american'), ('NOUN', 'company'), ('VERB', 'take'), ('NOUN', 'job'), ('ADP', 'to'), ('ADJ', 'other')]
# *************************
#  ->  and even bring jobs back from
# create pattern
# [('CCONJ', 'and'), ('ADV', 'even'), ('VERB', 'bring'), ('NOUN', 'job'), ('ADV', 'back'), ('ADP', 'from')]
# *************************
#  ->  American companies take jobs to other
# create pattern
# [('ADJ', 'american'), ('NOUN', 'company'), ('VERB', 'take'), ('NOUN', 'job'), ('ADP', 'to'), ('ADJ', 'other')]
# *************************
#  ->  and even bring jobs back from
# create pattern
# [('CCONJ', 'and'), ('ADV', 'even'), ('VERB', 'bring'), ('NOUN', 'job'), ('ADV', 'back'), ('ADP', 'from')]
# *************************
#  ->  who create good jobs at home
# create pattern
# [('PRON', 'who'), ('VERB', 'create'), ('ADJ', 'good'), ('NOUN', 'job'), ('ADP', 'at'), ('NOUN', 'home')]
# *************************
#  ->  back on the job,and
# create pattern
# [('ADV', 'back'), ('ADP', 'on'), ('DET', 'the'), ('NOUN', 'job'), ('PUNCT', ','), ('CCONJ', 'and')]
# *************************
#  ->  capital and create jobs.
# create pattern
# [('NOUN', 'capital'), ('CCONJ', 'and'), ('VERB', 'create'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  private-sector job growth in
# create pattern
# [('ADJ', 'private'), ('PUNCT', '-'), ('NOUN', 'sector'), ('NOUN', 'job'), ('NOUN', 'growth'), ('ADP', 'in')]
# *************************
#  ->  that creates good jobs that pay
# create pattern
# [('DET', 'that'), ('VERB', 'create'), ('ADJ', 'good'), ('NOUN', 'job'), ('DET', 'that'), ('VERB', 'pay')]
# *************************
#  ->  voice on the job anda chance
# create pattern
# [('NOUN', 'voice'), ('ADP', 'on'), ('DET', 'the'), ('NOUN', 'job'), ('NOUN', 'anda'), ('NOUN', 'chance')]
# *************************
#  ->  sector workers – jobs that are
# create pattern
# [('NOUN', 'sector'), ('NOUN', 'worker'), ('PUNCT', '–'), ('NOUN', 'job'), ('DET', 'that'), ('VERB', 'be')]
# *************************
#  ->  can find good jobs,where
# create pattern
# [('VERB', 'can'), ('VERB', 'find'), ('ADJ', 'good'), ('NOUN', 'job'), ('PUNCT', ','), ('ADV', 'where')]
# *************************
#  ->  three net new jobs.
# create pattern
# [('NUM', 'three'), ('ADJ', 'net'), ('ADJ', 'new'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  the engine of job growth in
# create pattern
# [('DET', 'the'), ('NOUN', 'engine'), ('ADP', 'of'), ('NOUN', 'job'), ('NOUN', 'growth'), ('ADP', 'in')]
# *************************
#  ->  more workersand make job-creating
# create pattern
# [('ADJ', 'more'), ('ADJ', 'workersand'), ('VERB', 'make'), ('NOUN', 'job'), ('PUNCT', '-'), ('VERB', 'create')]
# *************************
#  ->  once again creating jobs.
# create pattern
# [('ADV', 'once'), ('ADV', 'again'), ('VERB', 'create'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  private-sector jobs,but
# create pattern
# [('ADJ', 'private'), ('PUNCT', '-'), ('NOUN', 'sector'), ('NOUN', 'job'), ('PUNCT', ','), ('CCONJ', 'but')]
# *************************
#  ->  economy millions of jobs,hurt
# create pattern
# [('NOUN', 'economy'), ('NOUN', 'million'), ('ADP', 'of'), ('NOUN', 'job'), ('PUNCT', ','), ('VERB', 'hurt')]
# *************************
#  ->  businesses who create jobs and financing
# create pattern
# [('NOUN', 'business'), ('PRON', 'who'), ('VERB', 'create'), ('NOUN', 'job'), ('CCONJ', 'and'), ('NOUN', 'financing')]
# *************************
#  ->  agency whose sole job is looking
# create pattern
# [('NOUN', 'agency'), ('DET', 'whose'), ('ADJ', 'sole'), ('NOUN', 'job'), ('VERB', 'be'), ('VERB', 'look')]
# *************************
#  ->  choose between their jobs and their
# create pattern
# [('VERB', 'choose'), ('ADP', 'between'), ('DET', '-pron-'), ('NOUN', 'job'), ('CCONJ', 'and'), ('DET', '-pron-')]
# *************************
#  ->  innovation, and job creationwhile also
# create pattern
# [('NOUN', 'innovation'), ('PUNCT', ','), ('CCONJ', 'and'), ('NOUN', 'job'), ('NOUN', 'creationwhile'), ('ADV', 'also')]
# *************************
#  ->  education, and job opportunities that
# create pattern
# [('NOUN', 'education'), ('PUNCT', ','), ('CCONJ', 'and'), ('NOUN', 'job'), ('NOUN', 'opportunity'), ('DET', 'that')]
# *************************
#  ->  to get good jobs and put
# create pattern
# [('PART', 'to'), ('VERB', 'get'), ('ADJ', 'good'), ('NOUN', 'job'), ('CCONJ', 'and'), ('VERB', 'put')]
# *************************
#  ->  into skilled manufacturing jobs,and
# create pattern
# [('ADP', 'into'), ('ADJ', 'skilled'), ('NOUN', 'manufacturing'), ('NOUN', 'job'), ('PUNCT', ','), ('CCONJ', 'and')]
# *************************
#  ->  By investing in job creation,
# create pattern
# [('ADP', 'by'), ('VERB', 'invest'), ('ADP', 'in'), ('NOUN', 'job'), ('NOUN', 'creation'), ('PUNCT', ',')]
# *************************
#  ->  that is creating jobs and helping
# create pattern
# [('DET', 'that'), ('VERB', 'be'), ('VERB', 'create'), ('NOUN', 'job'), ('CCONJ', 'and'), ('VERB', 'help')]
# *************************
#  ->  , creating new jobs.
# create pattern
# [('PUNCT', ','), ('VERB', 'create'), ('ADJ', 'new'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  creating even more jobs.
# create pattern
# [('VERB', 'create'), ('ADV', 'even'), ('ADJ', 'more'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  care, undermining job growth and
# create pattern
# [('NOUN', 'care'), ('PUNCT', ','), ('VERB', 'undermine'), ('NOUN', 'job'), ('NOUN', 'growth'), ('CCONJ', 'and')]
# *************************
#  ->  a million agriculture jobs here at
# create pattern
# [('DET', 'a'), ('NUM', 'million'), ('NOUN', 'agriculture'), ('NOUN', 'job'), ('ADV', 'here'), ('ADP', 'at')]
# *************************
#  ->  every 12 American jobs.
# create pattern
# [('DET', 'every'), ('NUM', '12'), ('ADJ', 'american'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  -determinationand create jobs in Indian
# create pattern
# [('PUNCT', '-'), ('NOUN', 'determinationand'), ('NOUN', 'create'), ('NOUN', 'job'), ('ADP', 'in'), ('PROPN', 'indian')]
# *************************
#  ->  status by promoting job creation,
# create pattern
# [('NOUN', 'status'), ('ADP', 'by'), ('VERB', 'promote'), ('NOUN', 'job'), ('NOUN', 'creation'), ('PUNCT', ',')]
# *************************
#  ->  to work is Job One,
# create pattern
# [('ADP', 'to'), ('NOUN', 'work'), ('VERB', 'be'), ('PROPN', 'job'), ('NUM', 'one'), ('PUNCT', ',')]
# *************************
#  ->  to work is Job One.
# create pattern
# [('ADP', 'to'), ('NOUN', 'work'), ('VERB', 'be'), ('PROPN', 'job'), ('NUM', 'one'), ('PUNCT', '.')]
# *************************
#  ->  they lose their jobs.
# create pattern
# [('PRON', '-pron-'), ('VERB', 'lose'), ('DET', '-pron-'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  of innovation and job creation.
# create pattern
# [('ADP', 'of'), ('NOUN', 'innovation'), ('CCONJ', 'and'), ('NOUN', 'job'), ('NOUN', 'creation'), ('PUNCT', '.')]
# *************************
#  ->  invested in green jobs training programs
# create pattern
# [('VERB', 'invest'), ('ADP', 'in'), ('ADJ', 'green'), ('NOUN', 'job'), ('NOUN', 'training'), ('NOUN', 'program')]
# *************************
#  ->  family-supporting jobs.
# create pattern
# [('NOUN', 'family'), ('PUNCT', '-'), ('VERB', 'support'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  of thousands of jobs a month
# create pattern
# [('ADP', 'of'), ('NOUN', 'thousand'), ('ADP', 'of'), ('NOUN', 'job'), ('DET', 'a'), ('NOUN', 'month')]
# *************************
#  ->  resources while creating jobs, preserving
# create pattern
# [('NOUN', 'resource'), ('ADP', 'while'), ('VERB', 'create'), ('NOUN', 'job'), ('PUNCT', ','), ('VERB', 'preserve')]
# *************************
#  ->  create clean energy jobs here at
# create pattern
# [('VERB', 'create'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'job'), ('ADV', 'here'), ('ADP', 'at')]
# *************************
#  ->  – benefits like job creation,
# create pattern
# [('PUNCT', '–'), ('NOUN', 'benefit'), ('ADP', 'like'), ('NOUN', 'job'), ('NOUN', 'creation'), ('PUNCT', ',')]
# *************************
#  ->  They ignore the jobs that are
# create pattern
# [('PRON', '-pron-'), ('VERB', 'ignore'), ('DET', 'the'), ('NOUN', 'job'), ('DET', 'that'), ('VERB', 'be')]
# *************************
#  ->  and create new jobs and industry;infrastructure
# create pattern
# [('CCONJ', 'and'), ('VERB', 'create'), ('ADJ', 'new'), ('NOUN', 'job'), ('CCONJ', 'and'), ('NOUN', 'industry;infrastructure')]
# *************************
#  ->  that creates green jobs and combats
# create pattern
# [('DET', 'that'), ('VERB', 'create'), ('ADJ', 'green'), ('NOUN', 'job'), ('CCONJ', 'and'), ('NOUN', 'combat')]
# *************************
#  ->  critical to creating jobs and opportunities
# create pattern
# [('ADJ', 'critical'), ('ADP', 'to'), ('VERB', 'create'), ('NOUN', 'job'), ('CCONJ', 'and'), ('NOUN', 'opportunity')]
# *************************
#  ->  create more American jobs.
# create pattern
# [('VERB', 'create'), ('ADJ', 'more'), ('ADJ', 'american'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  support thousands of jobs here at
# create pattern
# [('VERB', 'support'), ('NOUN', 'thousand'), ('ADP', 'of'), ('NOUN', 'job'), ('ADV', 'here'), ('ADP', 'at')]
# *************************
#  ->  and creates American jobs.
# create pattern
# [('CCONJ', 'and'), ('VERB', 'create'), ('ADJ', 'american'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  to get the job done.
# create pattern
# [('PART', 'to'), ('VERB', 'get'), ('DET', 'the'), ('NOUN', 'job'), ('VERB', 'do'), ('PUNCT', '.')]
# *************************
#  ->  investments to create jobs,grow
# create pattern
# [('NOUN', 'investment'), ('PART', 'to'), ('VERB', 'create'), ('NOUN', 'job'), ('PUNCT', ','), ('VERB', 'grow')]
# *************************

# %%
patterns = [
      [('VERB'), ('NUM', '4.5'), ('NUM', 'million'), ('NOUN', 'job')],
      [('ADJ'), ('PART', "***"), ('VERB', 'create'), ('NOUN','job')],
      [('ADP'), ('NOUN', 'job'), ('ADP', 'to'), ('NOUN','job')],
      [('VERB'), ('ADP', "***"), ('NOUN', 'job'), ('NOUN',"***")],
      [('ADJ'), ('NOUN', 'growth'), ('CCONJ', 'and'), ('NOUN', 'job')]
]

print(patterns)
# Out:
# [['VERB', ('NUM', '4.5'), ('NUM', 'million'), ('NOUN', 'job')], ['ADJ', ('PART', '***'), ('VERB', 'create'), ('NOUN', 'job')], ['ADP', ('NOUN', 'job'), ('ADP', 'to'), ('NOUN', 'job')], ['VERB', ('ADP', '***'), ('NOUN', 'job'), ('NOUN', '***')], ['ADJ', ('NOUN', 'growth'), ('CCONJ', 'and'), ('NOUN', 'job')]]

# %%
new_contexts = []

analyzed = nlp(text)
lemmas = [token.lemma_.lower() for token in analyzed]
intersect = set(lemmas).intersection(set(term_dictionary))
if len(intersect) > 0:
    for pattern in patterns:
        in_machine = 0
        pattern_pos = 0
        pattern_find = []
        finds = []
        for token in analyzed:
            if in_machine == 0 and token.pos_ == pattern[pattern_pos] :
                in_machine = 1
                pattern_pos += 1
                pattern_find.append(token)
            elif in_machine == 1:
                if pattern_pos == len(pattern):
                    print("FOUND MATCH")
                    print(pattern_find)
                    print(pattern_find[0].sent)
                    finds.append(pattern_find)
                    in_machine = 0
                    pattern_pos = 0
                    pattern_find = []
                if pattern[pattern_pos][1] == "***":
                    if token.pos_ == pattern[pattern_pos][0]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
                elif pattern[pattern_pos][0] != "NOUN":
                    if token.pos_ == pattern[pattern_pos][0]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
                else:
                    if token.pos_ == pattern[pattern_pos][0] and token.lemma_ == pattern[pattern_pos][1]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
        
        
                    
        if len(finds) > 0:
            print(finds)
# Out:
# FOUND MATCH
# [create, one, million, jobs]
# But Republicans in Congress blocked other provisions that independent analysis said could create one million jobs.
# [[create, one, million, jobs]]
# FOUND MATCH
# [investing, in, job, creation]
# By investing in job creation, clean energy, agriculture, and education, Democrats have built a stronger rural economy where future generations can enjoy the rural way of life.
# [[investing, in, job, creation]]
# FOUND MATCH
# [economic, growth, and, job]
# Even as President Obama remains committed to working with both parties, he and his cabinet pursued a series of executive actions to help spark economic growth and job creation,including expanding access to refinancing for families who have stayed current on their mortgages,challenging Community Health Centers to hire veterans,accelerating permitting for transportation projects,cutting waste and reducing improper payments,and enabling student loan borrowers to cap their payments at a percentage of income.
# [[economic, growth, and, job]]

# %% [markdown]
# # Democrats Energy 2016

# %%
term_dictionary = []

text = read_file('C:/Users/Place Holder/Downloads/Democrat/61320_201611.txt')


term_dictionary.append("energy")

num_docs = len(text)

contexts = []

analyzed = nlp(text)

lemmas = [token.lemma_.lower() for token in analyzed]
intersect = set(lemmas).intersection(set(term_dictionary))
if len(intersect) > 0:
    context_sentences = [token.sent.as_doc() for token in analyzed if token.lemma_.lower() in term_dictionary ]
    contexts.extend(context_sentences)
        #print(context_sentences)

# %%
patterns = []

def pattern_creator(context):
    print("create pattern")
    pattern = [(token.pos_, token.lemma_.lower()) for token in context]
    print(pattern)

for sentence in contexts:
    for token in sentence:
        if token.lemma_.lower() in term_dictionary:
            #print(token.text, token.i, " - ", token.pos_)
            start_token = token.i - 3
            end_token = token.i + 3
            context = sentence[start_token:end_token]
            print(" -> ", context)
            try:
                new_pattern = pattern_creator(context.as_doc())
            except Exception as e:
                print(e)
            print("*" * 25)
# Out:
#  ->  more of our energy from the
# create pattern
# [('ADJ', 'more'), ('ADP', 'of'), ('DET', '-pron-'), ('NOUN', 'energy'), ('ADP', 'from'), ('DET', 'the')]
# *************************
#  ->  becoming the clean energy superpower of
# create pattern
# [('VERB', 'become'), ('DET', 'the'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'superpower'), ('ADP', 'of')]
# *************************
#  ->  build 21st century energy and water
# create pattern
# [('VERB', 'build'), ('ADJ', '21st'), ('NOUN', 'century'), ('NOUN', 'energy'), ('CCONJ', 'and'), ('NOUN', 'water')]
# *************************
#  ->  for investments in energy, water
# create pattern
# [('ADP', 'for'), ('NOUN', 'investment'), ('ADP', 'in'), ('NOUN', 'energy'), ('PUNCT', ','), ('NOUN', 'water')]
# *************************
#  ->  -Paying Clean Energy JobsWe must
# create pattern
# [('PUNCT', '-'), ('VERB', 'pay'), ('PROPN', 'clean'), ('PROPN', 'energy'), ('PROPN', 'jobswe'), ('VERB', 'must')]
# *************************
#  ->  in global clean energy, high
# create pattern
# [('ADP', 'in'), ('ADJ', 'global'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('PUNCT', ','), ('ADJ', 'high')]
# *************************
#  ->  -Paying Clean Energy JobsWe must
# create pattern
# [('PUNCT', '-'), ('VERB', 'pay'), ('PROPN', 'clean'), ('PROPN', 'energy'), ('PROPN', 'jobswe'), ('VERB', 'must')]
# *************************
#  ->  in global clean energy, high
# create pattern
# [('ADP', 'in'), ('ADJ', 'global'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('PUNCT', ','), ('ADJ', 'high')]
# *************************
#  ->  investing in industrial energy efficiency.
# create pattern
# [('VERB', 'invest'), ('ADP', 'in'), ('ADJ', 'industrial'), ('NOUN', 'energy'), ('NOUN', 'efficiency'), ('PUNCT', '.')]
# *************************
#  ->  as well as energy, manufacturing
# create pattern
# [('ADV', 'as'), ('ADV', 'well'), ('ADP', 'as'), ('NOUN', 'energy'), ('PUNCT', ','), ('NOUN', 'manufacturing')]
# *************************
#  ->  will promote clean energy leadership and
# create pattern
# [('VERB', 'will'), ('VERB', 'promote'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'leadership'), ('CCONJ', 'and')]
# *************************
#  ->  , lower our energy bills,
# create pattern
# [('PUNCT', ','), ('VERB', 'lower'), ('DET', '-pron-'), ('NOUN', 'energy'), ('NOUN', 'bill'), ('PUNCT', ',')]
# *************************
#  ->  America the clean energy superpower of
# create pattern
# [('PROPN', 'america'), ('DET', 'the'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'superpower'), ('ADP', 'of')]
# *************************
#  ->  , lower our energy bills,
# create pattern
# [('PUNCT', ','), ('VERB', 'lower'), ('DET', '-pron-'), ('NOUN', 'energy'), ('NOUN', 'bill'), ('PUNCT', ',')]
# *************************
#  ->  America the clean energy superpower of
# create pattern
# [('PROPN', 'america'), ('DET', 'the'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'superpower'), ('ADP', 'of')]
# *************************
#  ->  and other clean energy jobs.
# create pattern
# [('CCONJ', 'and'), ('ADJ', 'other'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'job'), ('PUNCT', '.')]
# *************************
#  ->  Build a Clean Energy Economy,
# create pattern
# [('VERB', 'build'), ('DET', 'a'), ('PROPN', 'clean'), ('PROPN', 'energy'), ('PROPN', 'economy'), ('PUNCT', ',')]
# *************************
#  ->  entirely on clean energy by mid
# create pattern
# [('ADV', 'entirely'), ('ADP', 'on'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('ADP', 'by'), ('ADJ', 'mid')]
# *************************
#  ->  to a clean energy economy,
# create pattern
# [('ADP', 'to'), ('DET', 'a'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'economy'), ('PUNCT', ',')]
# *************************
#  ->  Building a Clean Energy EconomyWe are
# create pattern
# [('VERB', 'build'), ('DET', 'a'), ('PROPN', 'clean'), ('PROPN', 'energy'), ('PROPN', 'economywe'), ('VERB', 'be')]
# *************************
#  ->  electricity from clean energy sources within
# create pattern
# [('NOUN', 'electricity'), ('ADP', 'from'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'source'), ('ADP', 'within')]
# *************************
#  ->  and enough renewable energy to power
# create pattern
# [('CCONJ', 'and'), ('ADJ', 'enough'), ('ADJ', 'renewable'), ('NOUN', 'energy'), ('ADP', 'to'), ('NOUN', 'power')]
# *************************
#  ->  Building a Clean Energy EconomyWe are
# create pattern
# [('VERB', 'build'), ('DET', 'a'), ('PROPN', 'clean'), ('PROPN', 'energy'), ('PROPN', 'economywe'), ('VERB', 'be')]
# *************************
#  ->  electricity from clean energy sources within
# create pattern
# [('NOUN', 'electricity'), ('ADP', 'from'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'source'), ('ADP', 'within')]
# *************************
#  ->  and enough renewable energy to power
# create pattern
# [('CCONJ', 'and'), ('ADJ', 'enough'), ('ADJ', 'renewable'), ('NOUN', 'energy'), ('ADP', 'to'), ('NOUN', 'power')]
# *************************
#  ->  Building a Clean Energy EconomyWe are
# create pattern
# [('VERB', 'build'), ('DET', 'a'), ('PROPN', 'clean'), ('PROPN', 'energy'), ('PROPN', 'economywe'), ('VERB', 'be')]
# *************************
#  ->  electricity from clean energy sources within
# create pattern
# [('NOUN', 'electricity'), ('ADP', 'from'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'source'), ('ADP', 'within')]
# *************************
#  ->  and enough renewable energy to power
# create pattern
# [('CCONJ', 'and'), ('ADJ', 'enough'), ('ADJ', 'renewable'), ('NOUN', 'energy'), ('ADP', 'to'), ('NOUN', 'power')]
# *************************
#  ->  We will cut energy waste in
# create pattern
# [('PRON', '-pron-'), ('VERB', 'will'), ('VERB', 'cut'), ('NOUN', 'energy'), ('NOUN', 'waste'), ('ADP', 'in')]
# *************************
#  ->  and offices through energy efficient improvements;modernize
# create pattern
# [('CCONJ', 'and'), ('NOUN', 'office'), ('ADP', 'through'), ('NOUN', 'energy'), ('ADJ', 'efficient'), ('PUNCT', 'improvements;modernize')]
# *************************
#  ->  We will cut energy waste in
# create pattern
# [('PRON', '-pron-'), ('VERB', 'will'), ('VERB', 'cut'), ('NOUN', 'energy'), ('NOUN', 'waste'), ('ADP', 'in')]
# *************************
#  ->  and offices through energy efficient improvements;modernize
# create pattern
# [('CCONJ', 'and'), ('NOUN', 'office'), ('ADP', 'through'), ('NOUN', 'energy'), ('ADJ', 'efficient'), ('PUNCT', 'improvements;modernize')]
# *************************
#  ->  on their monthly energy bills.
# create pattern
# [('ADP', 'on'), ('DET', '-pron-'), ('ADJ', 'monthly'), ('NOUN', 'energy'), ('NOUN', 'bill'), ('PUNCT', '.')]
# *************************
#  ->  to a clean energy future by
# create pattern
# [('ADP', 'to'), ('DET', 'a'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'future'), ('ADP', 'by')]
# *************************
#  ->  tax incentives for energy efficiency and
# create pattern
# [('NOUN', 'tax'), ('NOUN', 'incentive'), ('ADP', 'for'), ('NOUN', 'energy'), ('NOUN', 'efficiency'), ('CCONJ', 'and')]
# *************************
#  ->  efficiency and clean energy.
# create pattern
# [('NOUN', 'efficiency'), ('CCONJ', 'and'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('PUNCT', '.')]
# *************************
#  ->  to a clean energy future by
# create pattern
# [('ADP', 'to'), ('DET', 'a'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'future'), ('ADP', 'by')]
# *************************
#  ->  tax incentives for energy efficiency and
# create pattern
# [('NOUN', 'tax'), ('NOUN', 'incentive'), ('ADP', 'for'), ('NOUN', 'energy'), ('NOUN', 'efficiency'), ('CCONJ', 'and')]
# *************************
#  ->  efficiency and clean energy.
# create pattern
# [('NOUN', 'efficiency'), ('CCONJ', 'and'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('PUNCT', '.')]
# *************************
#  ->  to a clean energy future by
# create pattern
# [('ADP', 'to'), ('DET', 'a'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'future'), ('ADP', 'by')]
# *************************
#  ->  tax incentives for energy efficiency and
# create pattern
# [('NOUN', 'tax'), ('NOUN', 'incentive'), ('ADP', 'for'), ('NOUN', 'energy'), ('NOUN', 'efficiency'), ('CCONJ', 'and')]
# *************************
#  ->  efficiency and clean energy.
# create pattern
# [('NOUN', 'efficiency'), ('CCONJ', 'and'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('PUNCT', '.')]
# *************************
#  ->  to a clean energy economy and
# create pattern
# [('ADP', 'to'), ('DET', 'a'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'economy'), ('CCONJ', 'and')]
# *************************
#  ->  to expanding clean energy research and
# create pattern
# [('ADP', 'to'), ('VERB', 'expand'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'research'), ('CCONJ', 'and')]
# *************************
#  ->  our national clean energy goals requires
# create pattern
# [('DET', '-pron-'), ('ADJ', 'national'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'goal'), ('VERB', 'require')]
# *************************
#  ->  our country’s energy policy is
# create pattern
# [('DET', '-pron-'), ('NOUN', 'country'), ('PROPN', '’s'), ('NOUN', 'energy'), ('NOUN', 'policy'), ('VERB', 'be')]
# *************************
#  ->  our national clean energy goals requires
# create pattern
# [('DET', '-pron-'), ('ADJ', 'national'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'goal'), ('VERB', 'require')]
# *************************
#  ->  our country’s energy policy is
# create pattern
# [('DET', '-pron-'), ('NOUN', 'country'), ('PROPN', '’s'), ('NOUN', 'energy'), ('NOUN', 'policy'), ('VERB', 'be')]
# *************************
#  ->  lead on clean energy and energy
# create pattern
# [('NOUN', 'lead'), ('ADP', 'on'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('CCONJ', 'and'), ('NOUN', 'energy')]
# *************************
#  ->  clean energy and energy efficiency have
# create pattern
# [('ADJ', 'clean'), ('NOUN', 'energy'), ('CCONJ', 'and'), ('NOUN', 'energy'), ('NOUN', 'efficiency'), ('VERB', 'have')]
# *************************
#  ->  lead on clean energy and energy
# create pattern
# [('NOUN', 'lead'), ('ADP', 'on'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('CCONJ', 'and'), ('NOUN', 'energy')]
# *************************
#  ->  clean energy and energy efficiency have
# create pattern
# [('ADJ', 'clean'), ('NOUN', 'energy'), ('CCONJ', 'and'), ('NOUN', 'energy'), ('NOUN', 'efficiency'), ('VERB', 'have')]
# *************************
#  ->  -saving renewable energy by low
# create pattern
# [('PUNCT', '-'), ('VERB', 'save'), ('ADJ', 'renewable'), ('NOUN', 'energy'), ('ADP', 'by'), ('ADJ', 'low')]
# *************************
#  ->  have struggled with energy poverty,
# create pattern
# [('VERB', 'have'), ('VERB', 'struggle'), ('ADP', 'with'), ('NOUN', 'energy'), ('NOUN', 'poverty'), ('PUNCT', ',')]
# *************************
#  ->  or slow clean energy deployment.
# create pattern
# [('CCONJ', 'or'), ('VERB', 'slow'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'deployment'), ('PUNCT', '.')]
# *************************
#  ->  -saving renewable energy by low
# create pattern
# [('PUNCT', '-'), ('VERB', 'save'), ('ADJ', 'renewable'), ('NOUN', 'energy'), ('ADP', 'by'), ('ADJ', 'low')]
# *************************
#  ->  have struggled with energy poverty,
# create pattern
# [('VERB', 'have'), ('VERB', 'struggle'), ('ADP', 'with'), ('NOUN', 'energy'), ('NOUN', 'poverty'), ('PUNCT', ',')]
# *************************
#  ->  or slow clean energy deployment.
# create pattern
# [('CCONJ', 'or'), ('VERB', 'slow'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'deployment'), ('PUNCT', '.')]
# *************************
#  ->  -saving renewable energy by low
# create pattern
# [('PUNCT', '-'), ('VERB', 'save'), ('ADJ', 'renewable'), ('NOUN', 'energy'), ('ADP', 'by'), ('ADJ', 'low')]
# *************************
#  ->  have struggled with energy poverty,
# create pattern
# [('VERB', 'have'), ('VERB', 'struggle'), ('ADP', 'with'), ('NOUN', 'energy'), ('NOUN', 'poverty'), ('PUNCT', ',')]
# *************************
#  ->  or slow clean energy deployment.
# create pattern
# [('CCONJ', 'or'), ('VERB', 'slow'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'deployment'), ('PUNCT', '.')]
# *************************
#  ->  -cost renewable energy to market
# create pattern
# [('PUNCT', '-'), ('NOUN', 'cost'), ('ADJ', 'renewable'), ('NOUN', 'energy'), ('ADP', 'to'), ('NOUN', 'market')]
# *************************
#  ->  and other renewable energy over the
# create pattern
# [('CCONJ', 'and'), ('ADJ', 'other'), ('ADJ', 'renewable'), ('NOUN', 'energy'), ('ADP', 'over'), ('DET', 'the')]
# *************************
#  ->  -cost renewable energy to market
# create pattern
# [('PUNCT', '-'), ('NOUN', 'cost'), ('ADJ', 'renewable'), ('NOUN', 'energy'), ('ADP', 'to'), ('NOUN', 'market')]
# *************************
#  ->  and other renewable energy over the
# create pattern
# [('CCONJ', 'and'), ('ADJ', 'other'), ('ADJ', 'renewable'), ('NOUN', 'energy'), ('ADP', 'over'), ('DET', 'the')]
# *************************
#  ->  power our clean energy future.
# create pattern
# [('VERB', 'power'), ('DET', '-pron-'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'future'), ('PUNCT', '.')]
# *************************
#  ->  standards in clean energy infrastructure and
# create pattern
# [('NOUN', 'standard'), ('ADP', 'in'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'infrastructure'), ('CCONJ', 'and')]
# *************************
#  ->  During the clean energy transition,
# create pattern
# [('ADP', 'during'), ('DET', 'the'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'transition'), ('PUNCT', ',')]
# *************************
#  ->  and expand clean energy, energy
# create pattern
# [('CCONJ', 'and'), ('VERB', 'expand'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('PUNCT', ','), ('NOUN', 'energy')]
# *************************
#  ->  clean energy, energy efficiency,
# create pattern
# [('ADJ', 'clean'), ('NOUN', 'energy'), ('PUNCT', ','), ('NOUN', 'energy'), ('NOUN', 'efficiency'), ('PUNCT', ',')]
# *************************
#  ->  and expand clean energy, energy
# create pattern
# [('CCONJ', 'and'), ('VERB', 'expand'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('PUNCT', ','), ('NOUN', 'energy')]
# *************************
#  ->  clean energy, energy efficiency,
# create pattern
# [('ADJ', 'clean'), ('NOUN', 'energy'), ('PUNCT', ','), ('NOUN', 'energy'), ('NOUN', 'efficiency'), ('PUNCT', ',')]
# *************************
#  ->  new investments in energy-producing
# create pattern
# [('ADJ', 'new'), ('NOUN', 'investment'), ('ADP', 'in'), ('NOUN', 'energy'), ('PUNCT', '-'), ('VERB', 'produce')]
# *************************
#  ->  of the clean energy economy and
# create pattern
# [('ADP', 'of'), ('DET', 'the'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('NOUN', 'economy'), ('CCONJ', 'and')]
# *************************
#  ->  amount of renewable energy production on
# create pattern
# [('NOUN', 'amount'), ('ADP', 'of'), ('ADJ', 'renewable'), ('NOUN', 'energy'), ('NOUN', 'production'), ('ADP', 'on')]
# *************************
#  ->  deploy more clean energy,and
# create pattern
# [('VERB', 'deploy'), ('ADV', 'more'), ('ADJ', 'clean'), ('NOUN', 'energy'), ('PUNCT', ','), ('CCONJ', 'and')]
# *************************

# %%
patterns = [
      
[('ADJ'),('NOUN',"***"), ('ADP',"***"),('NOUN','energy')],
      [('DET'), ('ADJ', "***"), ('NOUN', 'energy'), ('NOUN',"***")],
      [('VERB'), ('PRON', "***"), ('NOUN', 'energy'), ('NOUN',"***")], 
    
]
print(patterns)
# Out:
# [['ADJ', ('NOUN', '***'), ('ADP', '***'), ('NOUN', 'energy')], ['DET', ('ADJ', '***'), ('NOUN', 'energy'), ('NOUN', '***')], ['VERB', ('PRON', '***'), ('NOUN', 'energy'), ('NOUN', '***')]]

# %%
new_contexts = []

analyzed = nlp(text)
lemmas = [token.lemma_.lower() for token in analyzed]
intersect = set(lemmas).intersection(set(term_dictionary))
if len(intersect) > 0:
    for pattern in patterns:
        in_machine = 0
        pattern_pos = 0
        pattern_find = []
        finds = []
        for token in analyzed:
            if in_machine == 0 and token.pos_ == pattern[pattern_pos] :
                in_machine = 1
                pattern_pos += 1
                pattern_find.append(token)
            elif in_machine == 1:
                if pattern_pos == len(pattern):
                    print("FOUND MATCH")
                    print(pattern_find)
                    print(pattern_find[0].sent)
                    finds.append(pattern_find)
                    in_machine = 0
                    pattern_pos = 0
                    pattern_find = []
                if pattern[pattern_pos][1] == "***":
                    if token.pos_ == pattern[pattern_pos][0]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
                elif pattern[pattern_pos][0] != "NOUN":
                    if token.pos_ == pattern[pattern_pos][0]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
                else:
                    if token.pos_ == pattern[pattern_pos][0] and token.lemma_ == pattern[pattern_pos][1]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
        
        
                    
        if len(finds) > 0:
            print(finds)
# Out:
# FOUND MATCH
# [new, investments, in, energy]
# Democrats will fight to make sure these workers and their families get the benefits they have earned and the respect they deserve,and we will make new investments in energy-producing communities to help create jobs and build a brighter and more resilient economic future.
# [[new, investments, in, energy]]
# FOUND MATCH
# [the, clean, energy, superpower]
# Democrats believe that climate change poses a real and urgent threat to our economy, our national security, and our children’s health and futures,and that Americans deserve the jobs and security that come from becoming the clean energy superpower of the 21st century.
# FOUND MATCH
# [the, clean, energy, superpower]
# We will promote collaborative stewardship of our natural resources,while developing clean fuels that will grow our economy, lower our energy bills, combat climate change, and make America the clean energy superpower of the 21st century.
# FOUND MATCH
# [a, clean, energy, economy]
# We will take bold steps to slash carbon pollution and protect clean air at home,lead the fight against climate change around the world,ensure no Americans are left out or left behind as we accelerate the transition to a clean energy economy,and be responsible stewards of our natural resources and our public lands and waters.
# FOUND MATCH
# [their, monthly, energy, bills]
# These efforts will create millions of new jobsand save families and businesses money on their monthly energy bills.
# FOUND MATCH
# [a, clean, energy, future]
# Democrats believe the tax code must reflect our commitment to a clean energy future by eliminating special tax breaks and subsidies for fossil fuel companiesas well as defending and extending tax incentives for energy efficiency and clean energy.
# FOUND MATCH
# [a, clean, energy, economy]
# Democrats believe that carbon dioxide, methane, and other greenhouse gases should be priced to reflect their negative externalities,and to accelerate the transition to a clean energy economy and help meet our climate goals.
# FOUND MATCH
# [our, clean, energy, future]
# We need to make our existing infrastructure safer and cleaner and build the new infrastructure necessary to power our clean energy future.
# FOUND MATCH
# [the, clean, energy, transition]
# During the clean energy transition, we will ensure landowners, communities of color, and tribal nations are at the table.
# FOUND MATCH
# [the, clean, energy, economy]
# We will phase down extraction of fossil fuels from our public lands, starting with the most polluting sources,while making our public lands and waters engines of the clean energy economy and creating jobs across the country.
# [[the, clean, energy, superpower], [the, clean, energy, superpower], [a, clean, energy, economy], [their, monthly, energy, bills], [a, clean, energy, future], [a, clean, energy, economy], [our, clean, energy, future], [the, clean, energy, transition], [the, clean, energy, economy]]

# %% [markdown]
# # Republicans Economy 2016

# %%
term_dictionary = []

text = read_file('C:/Users/Place Holder/Downloads/Republican/61620_201611.txt')

term_dictionary.append("economy")

num_docs = len(text)

contexts = []

analyzed = nlp(text)

lemmas = [token.lemma_.lower() for token in analyzed]
intersect = set(lemmas).intersection(set(term_dictionary))
if len(intersect) > 0:
    context_sentences = [token.sent.as_doc() for token in analyzed if token.lemma_.lower() in term_dictionary ]
    contexts.extend(context_sentences)
        #print(context_sentences)

# %%
patterns = []

def pattern_creator(context):
    print("create pattern")
    pattern = [(token.pos_, token.lemma_.lower()) for token in context]
    print(pattern)

for sentence in contexts:
    for token in sentence:
        if token.lemma_.lower() in term_dictionary:
            #print(token.text, token.i, " - ", token.pos_)
            start_token = token.i - 3
            end_token = token.i + 3
            context = sentence[start_token:end_token]
            print(" -> ", context)
            try:
                new_pattern = pattern_creator(context.as_doc())
            except Exception as e:
                print(e)
            print("*" * 25)
# Out:
#  ->
# division by zero
# *************************
#  ->  strong and healthy economy.
# create pattern
# [('ADJ', 'strong'), ('CCONJ', 'and'), ('ADJ', 'healthy'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  a free market economy that he
# create pattern
# [('DET', 'a'), ('ADJ', 'free'), ('NOUN', 'market'), ('NOUN', 'economy'), ('DET', 'that'), ('PRON', '-pron-')]
# *************************
#  ->  American DreamRebuilding the Economy and Creating
# create pattern
# [('PROPN', 'american'), ('PROPN', 'dreamrebuilding'), ('DET', 'the'), ('PROPN', 'economy'), ('CCONJ', 'and'), ('PROPN', 'creating')]
# *************************
#  ->  of a growing economy that gives
# create pattern
# [('ADP', 'of'), ('DET', 'a'), ('VERB', 'grow'), ('NOUN', 'economy'), ('DET', 'that'), ('VERB', 'give')]
# *************************
#  ->  American DreamRebuilding the Economy and Creating
# create pattern
# [('PROPN', 'american'), ('PROPN', 'dreamrebuilding'), ('DET', 'the'), ('PROPN', 'economy'), ('CCONJ', 'and'), ('PROPN', 'creating')]
# *************************
#  ->  of a growing economy that gives
# create pattern
# [('ADP', 'of'), ('DET', 'a'), ('VERB', 'grow'), ('NOUN', 'economy'), ('DET', 'that'), ('VERB', 'give')]
# *************************
#  ->  vigor of our economy which makes
# create pattern
# [('NOUN', 'vigor'), ('ADP', 'of'), ('DET', '-pron-'), ('NOUN', 'economy'), ('DET', 'which'), ('VERB', 'make')]
# *************************
#  ->  slow-growing economy.
# create pattern
# [('ADV', 'slow'), ('PUNCT', '-'), ('VERB', 'grow'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  our nation's economy has lost
# create pattern
# [('DET', '-pron-'), ('NOUN', 'nation'), ('PART', "'s"), ('NOUN', 'economy'), ('VERB', 'have'), ('VERB', 'lose')]
# *************************
#  ->  impact on our economy's performance
# create pattern
# [('NOUN', 'impact'), ('ADP', 'on'), ('DET', '-pron-'), ('NOUN', 'economy'), ('PART', "'s"), ('NOUN', 'performance')]
# *************************
#  ->  driving the entire economy back to
# create pattern
# [('VERB', 'drive'), ('DET', 'the'), ('ADJ', 'entire'), ('NOUN', 'economy'), ('ADV', 'back'), ('ADP', 'to')]
# *************************
#  ->  in the global economy.
# create pattern
# [('ADP', 'in'), ('DET', 'the'), ('ADJ', 'global'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  of America's economy.
# create pattern
# [('ADP', 'of'), ('PROPN', 'america'), ('PART', "'s"), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  control over the economy by creating
# create pattern
# [('NOUN', 'control'), ('ADP', 'over'), ('DET', 'the'), ('NOUN', 'economy'), ('ADP', 'by'), ('VERB', 'create')]
# *************************
#  ->  to the slow economy we all
# create pattern
# [('ADP', 'to'), ('DET', 'the'), ('ADJ', 'slow'), ('NOUN', 'economy'), ('PRON', '-pron-'), ('DET', 'all')]
# *************************
#  ->  growth to our economy, vigor
# create pattern
# [('NOUN', 'growth'), ('ADP', 'to'), ('DET', '-pron-'), ('NOUN', 'economy'), ('PUNCT', ','), ('ADJ', 'vigor')]
# *************************
#  ->  encourage the sharing economy and on
# create pattern
# [('VERB', 'encourage'), ('DET', 'the'), ('NOUN', 'sharing'), ('NOUN', 'economy'), ('CCONJ', 'and'), ('ADP', 'on')]
# *************************
#  ->  in the global economy.
# create pattern
# [('ADP', 'in'), ('DET', 'the'), ('ADJ', 'global'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  of our new economy.
# create pattern
# [('ADP', 'of'), ('DET', '-pron-'), ('ADJ', 'new'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  lifeblood of our economy,but
# create pattern
# [('NOUN', 'lifeblood'), ('ADP', 'of'), ('DET', '-pron-'), ('NOUN', 'economy'), ('PUNCT', ','), ('CCONJ', 'but')]
# *************************
#  ->  of the app economy cries out
# create pattern
# [('ADP', 'of'), ('DET', 'the'), ('NOUN', 'app'), ('NOUN', 'economy'), ('VERB', 'cry'), ('PART', 'out')]
# *************************
#  ->  of the American economy is the
# create pattern
# [('ADP', 'of'), ('DET', 'the'), ('ADJ', 'american'), ('NOUN', 'economy'), ('VERB', 'be'), ('DET', 'the')]
# *************************
#  ->  of the new economy.
# create pattern
# [('ADP', 'of'), ('DET', 'the'), ('ADJ', 'new'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  a free enterprise economy.
# create pattern
# [('DET', 'a'), ('ADJ', 'free'), ('NOUN', 'enterprise'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  burden on our economy and families
# create pattern
# [('NOUN', 'burden'), ('ADP', 'on'), ('DET', '-pron-'), ('NOUN', 'economy'), ('CCONJ', 'and'), ('NOUN', 'family')]
# *************************
#  ->
# division by zero
# *************************
#  ->  to the digital economy.
# create pattern
# [('ADP', 'to'), ('DET', 'the'), ('ADJ', 'digital'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  today's global economy of constant
# create pattern
# [('NOUN', 'today'), ('PART', "'s"), ('ADJ', 'global'), ('NOUN', 'economy'), ('ADP', 'of'), ('ADJ', 'constant')]
# *************************
#  ->  of the digital economy, it
# create pattern
# [('ADP', 'of'), ('DET', 'the'), ('ADJ', 'digital'), ('NOUN', 'economy'), ('PUNCT', ','), ('PRON', '-pron-')]
# *************************
#  ->  lifeblood of our economy.
# create pattern
# [('NOUN', 'lifeblood'), ('ADP', 'of'), ('DET', '-pron-'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  ,powers our economy,creates
# create pattern
# [('PUNCT', ','), ('VERB', 'power'), ('DET', '-pron-'), ('NOUN', 'economy'), ('PUNCT', ','), ('VERB', 'create')]
# *************************
#  ->  sectors of our economy.
# create pattern
# [('NOUN', 'sector'), ('ADP', 'of'), ('DET', '-pron-'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  rest of the economy, agriculture
# create pattern
# [('NOUN', 'rest'), ('ADP', 'of'), ('DET', 'the'), ('NOUN', 'economy'), ('PUNCT', ','), ('NOUN', 'agriculture')]
# *************************
#  ->  in a free economy without subsidies
# create pattern
# [('ADP', 'in'), ('DET', 'a'), ('ADJ', 'free'), ('NOUN', 'economy'), ('ADP', 'without'), ('NOUN', 'subsidy')]
# *************************
#  ->  no-growth economy.
# create pattern
# [('DET', 'no'), ('PUNCT', '-'), ('NOUN', 'growth'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  ,grow our economy,and
# create pattern
# [('PUNCT', ','), ('VERB', 'grow'), ('DET', '-pron-'), ('NOUN', 'economy'), ('PUNCT', ','), ('CCONJ', 'and')]
# *************************
#  ->  of the American economy is the
# create pattern
# [('ADP', 'of'), ('DET', 'the'), ('ADJ', 'american'), ('NOUN', 'economy'), ('VERB', 'be'), ('DET', 'the')]
# *************************
#  ->  will improve the economy.
# create pattern
# [('VERB', 'will'), ('VERB', 'improve'), ('DET', 'the'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  values strengthens our economy,enriches
# create pattern
# [('NOUN', 'value'), ('VERB', 'strengthen'), ('DET', '-pron-'), ('NOUN', 'economy'), ('PUNCT', ','), ('VERB', 'enrich')]
# *************************
#  ->  Americans, the economy is still
# create pattern
# [('PROPN', 'americans'), ('PUNCT', ','), ('DET', 'the'), ('NOUN', 'economy'), ('VERB', 'be'), ('ADV', 'still')]
# *************************
#  ->  costs to the economy.
# create pattern
# [('NOUN', 'cost'), ('ADP', 'to'), ('DET', 'the'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  with a vibrant economy.
# create pattern
# [('ADP', 'with'), ('DET', 'a'), ('ADJ', 'vibrant'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  impose on the economy in any
# create pattern
# [('VERB', 'impose'), ('ADP', 'on'), ('DET', 'the'), ('NOUN', 'economy'), ('ADP', 'in'), ('DET', 'any')]
# *************************
#  ->  jobs and the economy depend on
# create pattern
# [('NOUN', 'job'), ('CCONJ', 'and'), ('DET', 'the'), ('NOUN', 'economy'), ('VERB', 'depend'), ('ADP', 'on')]
# *************************
#  ->  in a growing economy,where
# create pattern
# [('ADP', 'in'), ('DET', 'a'), ('VERB', 'grow'), ('NOUN', 'economy'), ('PUNCT', ','), ('ADV', 'where')]
# *************************
#  ->  benefit the U.S. economy,U.S.
# create pattern
# [('VERB', 'benefit'), ('DET', 'the'), ('PROPN', 'u.s.'), ('NOUN', 'economy'), ('PUNCT', ','), ('PROPN', 'u.s.')]
# *************************
#  ->  a free market economy, and
# create pattern
# [('DET', 'a'), ('ADJ', 'free'), ('NOUN', 'market'), ('NOUN', 'economy'), ('PUNCT', ','), ('CCONJ', 'and')]
# *************************
#  ->  mocked in an economy based on
# create pattern
# [('VERB', 'mock'), ('ADP', 'in'), ('DET', 'an'), ('NOUN', 'economy'), ('VERB', 'base'), ('ADP', 'on')]
# *************************
#  ->  country's energetic economy.
# create pattern
# [('NOUN', 'country'), ('PART', "'s"), ('ADJ', 'energetic'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************
#  ->  a competitive global economy.
# create pattern
# [('DET', 'a'), ('ADJ', 'competitive'), ('ADJ', 'global'), ('NOUN', 'economy'), ('PUNCT', '.')]
# *************************

# %%
patterns = [
[('DET'),('ADJ', 'global'), ('NOUN','economy'),('PUNCT','.')],
      [('DET'), ('ADJ', 'global'), ('NOUN', 'economy'), ('CCONJ', 'and')],
    [('DET'), ('ADJ','global'), ('NOUN', 'economy'), ('ADP',"***") ]
]
print(patterns)
# Out:
# [['DET', ('ADJ', 'global'), ('NOUN', 'economy'), ('PUNCT', '.')], ['DET', ('ADJ', 'global'), ('NOUN', 'economy'), ('CCONJ', 'and')], ['DET', ('ADJ', 'global'), ('NOUN', 'economy'), ('ADP', '***')]]

# %%
new_contexts = []

analyzed = nlp(text)
lemmas = [token.lemma_.lower() for token in analyzed]
intersect = set(lemmas).intersection(set(term_dictionary))
if len(intersect) > 0:
    for pattern in patterns:
        in_machine = 0
        pattern_pos = 0
        pattern_find = []
        finds = []
        for token in analyzed:
            if in_machine == 0 and token.pos_ == pattern[pattern_pos] :
                in_machine = 1
                pattern_pos += 1
                pattern_find.append(token)
            elif in_machine == 1:
                if pattern_pos == len(pattern):
                    print("FOUND MATCH")
                    print(pattern_find)
                    print(pattern_find[0].sent)
                    finds.append(pattern_find)
                    in_machine = 0
                    pattern_pos = 0
                    pattern_find = []
                if pattern[pattern_pos][1] == "***":
                    if token.pos_ == pattern[pattern_pos][0]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
                elif pattern[pattern_pos][0] != "NOUN":
                    if token.pos_ == pattern[pattern_pos][0]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
                else:
                    if token.pos_ == pattern[pattern_pos][0] and token.lemma_ == pattern[pattern_pos][1]:
                            pattern_pos += 1
                            pattern_find.append(token)
                    else:
                            in_machine = 0
                            pattern_pos = 0
                            pattern_find = []
        
        
                    
        if len(finds) > 0:
            print(finds)
# Out:
# FOUND MATCH
# [the, global, economy, .]
# That equation governs our policies regarding U.S. corporations in the global economy.
# FOUND MATCH
# [the, global, economy, .]
# We encourage public-private partnerships to provide predictable support for connecting rural areasso that every American can fully participate in the global economy.
# FOUND MATCH
# [our, new, economy, .]
# Today they are the entrepreneurs, independent contractors, and small business men and women of our new economy.
# FOUND MATCH
# [the, new, economy, .]
# They are attacking the franchise model of business development, which is essential to the flexibility and creativity of the new economy.
# FOUND MATCH
# [the, digital, economy, .]
# These increased privacy protections have become crucial to the digital economy.
# FOUND MATCH
# [the, digital, economy, ,]
# With the rise of the digital economy, it has become even more critical that we protect intellectual property rightsand preserve freedom of contract rather than create regulatory barriers to creativity, growth, and innovation.
# FOUND MATCH
# [a, vibrant, economy, .]
# Sensible regulations can be compatible with a vibrant economy.
# [[the, global, economy, .], [the, global, economy, .], [our, new, economy, .], [the, new, economy, .], [the, digital, economy, .], [the, digital, economy, ,], [a, vibrant, economy, .]]
# FOUND MATCH
# [a, free, economy, without]
# We support the development of all forms of energy that are marketable in a free economy without subsidies, including coal, oil, natural gas, nuclear power, and hydropower.
# [[a, free, economy, without]]
